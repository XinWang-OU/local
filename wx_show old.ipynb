# %%
import os

other_models_dir = '/home/etica/Project/alloy2vec/alloy2vec/training/models/other_models'  # 替换为您的模型文件目录路径

model_files = [f for f in os.listdir(other_models_dir) if f.endswith('.npy')]
print(f"Found {len(model_files)} model files: {model_files}")
# Out:
# Found 18 model files: ['1model_with_wx_process_parallel_2014_2010.wv.vectors.npy', '1model_with_wx_process_parallel_2018_2015.wv.vectors.npy', '1model_with_wx_process_parallel_2022_2023.trainables.syn1.npy', '1model_with_wx_process_parallel_2009_2004.wv.vectors.npy', '1model_with_wx_process_parallel_2018_2015.trainables.syn1neg.npy', '1model_with_wx_process_parallel_2021_2019.trainables.syn1.npy', '1model_with_wx_process_parallel_2003_1989.trainables.syn1neg.npy', '1model_with_wx_process_parallel_2018_2015.trainables.syn1.npy', '1model_with_wx_process_parallel_2022_2023.wv.vectors.npy', '1model_with_wx_process_parallel_2003_1989.wv.vectors.npy', '1model_with_wx_process_parallel_2009_2004.trainables.syn1neg.npy', '1model_with_wx_process_parallel_2003_1989.trainables.syn1.npy', '1model_with_wx_process_parallel_2021_2019.trainables.syn1neg.npy', '1model_with_wx_process_parallel_2014_2010.trainables.syn1.npy', '1model_with_wx_process_parallel_2022_2023.trainables.syn1neg.npy', '1model_with_wx_process_parallel_2021_2019.wv.vectors.npy', '1model_with_wx_process_parallel_2014_2010.trainables.syn1neg.npy', '1model_with_wx_process_parallel_2009_2004.trainables.syn1.npy']

# %%
# we skip the time-consuming data training
# Let's try on one model that I trained.

#load the model. May take a while, given the model's large size.
from gensim.models import Word2Vec 
w2v_model =Word2Vec.load("alloy2vec/training/models/model_with_wx_process_parallel_all")

# %%
word_to_check = 'heat_capacity'
if word_to_check in w2v_model.wv.vocab:
    print(f"'{word_to_check}' was found in the model")
else:
    print(f"'{word_to_check}' was not found in the model")
# Out:
# 'heat_capacity' was found in the model

# %%
word="heat_capacity"
model_results=w2v_model.wv.most_similar(word)
print(model_results)
# Out:
# [('specific_heat', 0.9218029379844666), ('heat_capacities', 0.8387543559074402), ('specific_heat_capacity', 0.8190459609031677), ('heat_capacity_measurements', 0.8150315284729004), ('specific_heats', 0.810332179069519), ('isobaric_heat_capacity', 0.7995725870132446), ('gruneisen_parameter', 0.7915974855422974), ('debye_temperature', 0.7833778858184814), ('heat_capacity_c-p', 0.7729331254959106), ('debye_temperature_thetaD', 0.7548724412918091)]

# %%
model_results=w2v_model.wv.most_similar(word,topn=10000)
elements_only = [element for element, similarity in model_results]
results_string = '\n'.join(elements_only)
print(results_string)
# Out:
# specific_heat
# heat_capacities
# specific_heat_capacity
# heat_capacity_measurements
# specific_heats
# isobaric_heat_capacity
# gruneisen_parameter
# debye_temperature
# heat_capacity_c-p
# debye_temperature_thetaD
# electronic_specific_heat
# specific_heat_measurements
# debye_temperatures
# linear_thermal_expansion
# electrical_resistivity
# molar_heat_capacity
# temperature_dependences
# debye_model
# heat_capacity_entropy
# c-p
# thermal_expansion
# heat_capacity_cp
# specific_heat_c-p
# specific_heat_coefficient
# thermal_diffusivity
# enthalpy_increment
# entropy
# thermal_expansion_coefficient
# thermodynamic_functions
# C-pT
# gruneisen_parameter_gamma
# thermal_expansivity
# sommerfeld_coefficient
# drop_calorimetry
# magnetic_entropy
# alphaT
# thermophysical_properties
# ThetaD
# electrical_resistivity_rho
# enthalpy
# thermoelectric_power
# sommerfeld_coefficient_gamma
# s-vib
# heat_capacity_thermal_expansion
# dulong_petit_limit
# gruneisen
# debye_temperature_ThetaD
# thermopower
# thermal_conductivity
# gruneisen_ratio
# thermal_conductivity_kappa
# thermodynamic_quantities
# cvT
# specific_heat_C-pT
# sound_velocity
# mJ_K-2_mol-1
# debye
# specific_heat_capacities
# volume_expansion_coefficient
# adiabatic_calorimetry
# vibrational_entropy
# thermodynamic_functions_entropy
# lorentz_number
# c-p_T
# dulong_petit
# heat_capacity_C-V
# volumetric_thermal_expansion
# gruneisen_parameters
# linear_term
# magnetization_electrical_resistivity
# debye_temperature_heat_capacity
# quasi-harmonic_approximation
# helmholtz_free_energy
# aT
# mJ_mol_K-2
# anharmonicity
# phonon_thermal_conductivity
# wiedemann_franz_law
# calorimetry
# calorimetric
# heat_capacity_C-pT
# mJ_K-2_mol
# C-PT
# calorimetric_measurements
# specific_heat_cp
# c-pm0
# c-nu
# phonon_density
# isothermal_magnetization
# magnetic_susceptibility
# isothermal_bulk_modulus
# debye_temperature_theta
# specific_heat_CT
# c-pmo
# electrical_resistivity_rhoT
# thetaD
# quasiharmonic_approximation
# THETA-0
# magnetic_susceptibility_chiT
# calorimetric_data
# entropy_change
# hall_coefficient
# chiT
# isochoric_heat_capacity
# mJ_mol-1_K-2
# PbPd2Yb
# LuSi
# electrical_resistivity_measurements
# bulk_modulus
# phonon_spectrum
# lattice_vibrations
# CGaNb2
# C-pAp
# elastic_constants
# CGaTa2
# Ce1-xLaxCu4Al
# thermoelectric_power_S
# AgCeSn
# debye_gruneisen_model
# 2-300_K
# specific_heat_anomaly
# cpT
# isothermal_compressibility
# C-eT
# excess_entropy
# residual_resistivity
# compressibility
# phonon_spectra
# quasi-harmonic_debye_model
# magnetization_specific_heat
# magnetic_susceptibility_chi
# thermoelectric_power_ST
# magnetic_field_dependence
# Co2EuP2
# HoO4V
# molar_heat_capacities
# ac_calorimetry
# grneisen
# hemispherical_total_emissivity
# griineisen
# heat_capacity_anomaly
# debye_temperature_thD
# thermal_conductivities
# thermopower_ST
# magnetic_susceptibility_electrical_resistivity
# kappaT
# vibrational_contribution
# debye_gruneisen
# heat_capacity_c-v
# rhoT
# t-linear
# schottky_anomaly
# Gd4Mg21Zn25
# thermopower_S
# quasi-harmonic
# drop_calorimeter
# coefficient_alphaT
# inelastic_neutron_scattering_measurements
# phonon_DOS
# vibrational_entropies
# thermal_diffusivity_specific_heat
# gibbs_energy
# delta_s-mag
# isochoric_heat_capacities
# spin_fluctuations
# anomaly
# gruneisen_constant
# PbPd2Y
# specific_heat_thermal_diffusivity
# thermoelectric_power_TEP
# mK
# paramagnetic_susceptibility
# electronic_specific_heat_coefficient_γ
# inelastic_neutron_scattering
# electric_resistivity
# phase_diagram
# phonon_dispersion
# electrical_resistivity_pT
# maxwell_relation
# entropy_enthalpy
# magnetic_ordering
# adiabatic_calorimeter
# elastic_moduli
# anharmonic
# neutron_scattering_experiments
# Mn39Ni48Sn13
# neel_temperature_T-N
# magnetoresistivity
# resistivity
# Pd85Rh153U
# s-m0
# resistivity_rhoT
# Os4P12Sr
# thermal_expansion_coefficient_alphaT
# phonon
# sound_velocities
# AlFe198V102
# Ni50Mn50-xInx
# magnetoresistance_delta_rho_rho
# spin_fluctuation
# magnetization_heat_capacity
# lattice_dynamics
# zero_field
# TlnT
# Er24Pd
# B4Tb
# neutron_inelastic_scattering
# laser_flash_method
# CeGe2Ru2
# specific_heat_electrical_resistivity
# Cp(T)
# Cr3Ge
# enthalpy_entropy
# phonon_densities
# DeltaCT
# absolute_zero
# lambda-type_anomaly
# elastic_constant
# gruneisen_coefficient
# heavy_fermion_behavior
# ac_susceptibility
# debye_temperature_ThD
# C-mT
# range_80-300_K
# quasiharmonic_debye_model
# quasiharmonic
# T-C
# Cu4PdU
# electrical_conductivity_sigmaT
# pauli_susceptibility
# Al4CeNi
# 04-300
# electron_phonon_coupling
# temperature_range_2-300_K
# magnetic_susceptibility_magnetization
# gamma-cerium
# ln_T
# 10-5_K-1
# thetaE
# phonon_dispersion_relations
# melting_curve
# seebeck_coefficient_ST
# phonon_dispersions
# absolute_thermoelectric_power
# electrical_resistivity_magnetic_susceptibility
# phonon_frequencies
# isobar
# bulk_moduli
# electrical_resistivity_seebeck_coefficient
# electronic_specific_heat_coefficient
# inelastic_neutron_scattering_experiments
# heavy_fermion
# spontaneous_magnetization
# enthalpy_increments
# sommerfeld_constant
# capacity_c-p
# neutron_scattering
# thermal_expansions
# CeNiSn
# BLu
# electron_phonon_interaction
# neumann_kopp_rule
# C2LaNi
# GeHo
# T-N
# entropy_changes
# c-el
# temperature_range_5-300_K
# Fe2LaSi2
# magnetic_phase_transitions
# magnetization
# iron-vanadium-aluminum
# chi-T
# coefficient_LTEC
# [rhoT]
# pauli_paramagnetic_susceptibility
# B2CeIr2
# DyNiSb
# C-ijT
# lambda-like
# seebeck_coefficient
# magnetovolume
# Cu5Nd
# electrical_resistivities
# quasiharmonic_approximation_QHA
# grueneisen
# heavy_fermion_compound
# mode_gruneisen_parameters
# transport_coefficients
# thermo_physical_properties
# neel_temperature
# CeRhSn
# magnetic_fields_up
# Fe4P12Y
# below_t-c
# CeRh2
# T-2_dependence
# resistivity_rho
# Co2YbZn20
# linear_thermal_expansion_coefficient
# anharmonic_effects
# molar_entropy
# magnetocaloric_effect
# undercooled_liquid
# AlCoMoNbNi3
# Quasi-Harmonic
# near_absolute_zero
# Ne_el
# anderson_gruneisen_parameter
# S-Mpk
# dTN_dP
# c-4f
# above_T-N
# sommerfield
# neumann_kopp
# residual_resistivity_rho0
# gammath
# magnetic_susceptibility_specific_heat
# magnetic_phase_diagram
# quasi-harmonic_debye
# calorimeter
# M2GaC
# magnetic_susceptibility_kh(T)
# t-c
# linear_expansion_coefficient
# electrical_resistance
# Tl2ThMoO43s
# Jmol-1K-1
# magnetic_susceptibility_heat_capacity
# mJ_mol
# einstein
# alphaLT
# T-3_law
# neel_temperature_TN
# fLM
# mol_K-2
# magnetic_susceptibilities
# T-2_term
# hP24
# 5-300_K
# dc_magnetization
# fermi_liquid_behavior
# entropies
# Ce3Pb
# isobaric
# thermal_expansion_coefficients
# latent_heat
# phase_diagrams
# phase_transitions
# lattice_vibration
# Tl2UO2MoO42s
# electrical_resistivity_magnetoresistance
# grfineisen
# Ga3Np
# kappae
# magnetic_susceptibility_χ
# coefficient_TEC
# Al10Cu18Ni15Ti5Zr52
# shear_moduli
# Co207La207O586
# rln2
# change_delta_t-ad
# hall_constant
# Wiedemann-Franz-Lorenz
# neutron_scattering_measurements
# Ce2RhSi3
# schottky_type_anomaly
# valence_fluctuating
# lorenz_number
# enthalpies
# antiferromagnetic_ordering
# calvet_calorimeter
# mJ_mole
# anharmonic_contributions
# a(T)
# Ge3Lu5
# phonon_dispersion_curves
# beta-Be
# GdMnSi
# PdPrSb
# Ag-Si-Ge
# enthalpy_of_fusion
# ac_magnetic_susceptibility
# applied_magnetic_fields
# thermal_conductivity_kappaT
# seebeck_coefficients
# h-tr
# magnetization_measurements
# ultrasonic_attenuation
# thermophysical
# spontaneous_volume_magnetostriction
# isobaric_expansivity
# Fe4P12Sm
# t-m
# curie_weiss_law
# thermophysical_parameters
# volumetric_heat_capacity
# wilson_ratio
# heat_capacity_anomalies
# AlCNi3
# enthalpy_of_mixing
# Cu4InYb
# 5-370
# hall_effect
# shear_modulus
# Si-Ge-Ag
# applied_magnetic_field
# metamagnetic_transition
# GdInPd2
# entropy_of_fusion
# standard_molar_enthalpy
# inelastic_neutron
# Cp-T
# Dy2FeO7Sb
# BiTeTl
# curie_weiss
# curie_weiss_behavior
# excess_entropies
# J_kg-1K-1
# dT
# J_mol-1
# non-Fermi_liquid_behavior
# sublattice_magnetization
# pauli_paramagnetism
# 2-300K
# order_disorder_transition
# curie_temperature
# gamma-T
# orders_antiferromagnetically
# S(T)
# rho7
# kondo_temperature_T-K
# H15Th4
# ce1_xLaxNiAl4
# J_molK
# alpha4f
# bloch_gruneisen_law
# phonon_density_of_states
# lattice_dynamical
# 298-800
# L_L-0
# isochoric
# J_mol_K-2
# spin_freezing
# emf
# anomalous_thermal_expansion
# chiacT
# CuInYb
# kB_atom
# DSmag
# debye_approximation
# PdSiYb
# mixing_delta_h-mix
# specific_heat_C(T)
# expansivity
# AuCeSn
# spin_susceptibility
# T3lnT
# pauli_paramagnetic
# pauli_paramagnet
# quasi_harmonic
# thermodynamic
# total_hemispherical_emissivity
# CP(T)
# debye_temperature_θ
# phonons
# anomalies
# einstein_model
# rhoP
# kbar-1
# J_mol_K
# magnetovolume_effect
# de_haas_van_alphen_effect
# dc_resistivity
# inelastic_neutron_scattering_spectra
# Al35Pd107Re43
# below_T-C
# Fe10Mo2Y
# Se45Te55Tm
# thermal_hysteresis
# seebeck
# molar_entropies
# AlHfPd2
# used_to_calculate_the_thermodynamic_functions
# negative_thermal_expansion
# kadowaki_woods_ratio
# alpha-Na2NpO4
# C-pC-m
# effective_paramagnetic_moment
# SrRuO3s
# Pd3Tb
# At_ambient_pressure
# seebeck_coefficient_S
# CeCrGe3
# al1_xCux
# heat_capacities_cp
# curie
# thetaP
# magnetization_isotherms
# LaPt2Si2
# weak_itinerant
# thermal_conductivity_κ
# thermal_diffusivities
# superconducting_state
# LTSH
# adiabatic
# susceptibility_chiT
# kondo_lattice
# B6C3ScU2
# above_T-C
# magnetically_ordered_state
# tetraboride
# van_vleck
# CePd2Si2
# x_10-5_K-1
# GeHoPd
# Ge2Pd2Sr
# P-V-T_equation
# under_hydrostatic_pressure
# molar_volume
# third_law
# boson_peak
# x_10-4_K-1
# partial_molar
# molar_enthalpy
# calvet_microcalorimeter
# Co2Np
# rootT
# B12Tm
# Ir3U
# CuMnSb
# expansion_coefficients
# specific_heat_capacity_cp
# shock_hugoniot
# kadowaki_woods
# pressure-volume-temperature
# NPbTi2
# PdSnU
# phonon_frequency_shifts
# c-v
# critical_exponents
# hall_coefficient_R-H
# structural_phase_transitions
# under_hydrostatic_pressures_up
# THETAD
# melting_point
# phonon_calculations
# cohesive_energy
# delta_c-p
# adiabatic_demagnetization
# B15In285Mn7Ni10
# curie_weiss_constant
# state_EOS
# magnetically_ordered_phases
# residual_resistivity_ratio
# local_moment
# dc_magnetic_susceptibility
# Pb3Yb
# t-cstar
# metal_nonmetal_transition
# t-f
# magnetic_entropy_change_DSM
# dc_magnetization_ac_susceptibility
# C-44
# CuGeNd
# VDoS
# paramagnon
# spin_glass_transition
# alphaV
# temperature_range_42-300
# xT
# B50Lu
# BCu2O32Sr
# CeCu2Ge2
# paramagnetic_state
# molar_volumes
# magnetocaloric_effect_MCE
# lattice_thermal_conductivity
# acoustic_velocities
# below_t-f
# above_t-c
# precision_automatic_adiabatic_calorimeter
# magnetic_ordering_down
# electroresistivity
# T-K
# CrCuSe2
# below_T-N
# Ni2Tb
# dependences
# CeGe2Ni2
# AsCrFe
# a+bT
# mJ_molK2
# mixing_enthalpy
# magnetization_MH
# dc_susceptibility
# electron_phonon
# order_antiferromagnetically_at
# kh(T)
# gibbs_energy_enthalpy
# ziman_theory
# superconducting_transition_temperature
# magnon_spectrum
# transverse_magnetoresistance
# knight_shift
# shear_viscosity
# isoperibolic_calorimeter
# GePtYb
# standard_molar_entropies
# Ru2Si2U
# magnetoresistance
# thermal_expansivities
# volume_expansivity
# isentropes
# seebeck_effect
# kondo
# gruneisen_parameter_γ
# kappaph
# UDeltaS-M
# CpT
# bcc-Zr
# 4-300_K
# paramagnetic_curie_temperature
# K
# Cd6Yb
# hugoniot_curve
# sommerfeld_value
# M2SX
# Ge52Rh2Si95Yb
# A3Pt4
# Ru3Si5U2
# below_Tc
# standard_entropies
# internal_friction_Q-1
# CeNiSb
# BTm
# metamagnets
# isobaric_heat_capacities
# DeltaSm
# CuS4Ti2
# superconducting_transition
# P12Ru4Sm
# heavy_fermion_compounds
# BiEr
# dependencies
# tetragonal_Mn12Th_type
# specific_heat_Cp(T)
# itinerant_electron
# spin_wave_excitations
# AlCeCu4
# longitudinal_spin_fluctuations
# clausius_clapeyron_equation
# kondo_lattice_system
# electrical_transport
# CePdSb
# curie_temperature_T-C
# 5-320
# R-MCE
# MFe3N
# phonon_anharmonicity
# around_T-C
# weak_itinerant_electron
# t-x_phase_diagram
# beta-UB2C
# Ho5Si3
# hall_coefficients
# V_V-0
# paramagnetic_down
# DeltaC
# CeGaPt
# 298-1273
# magnetization_curves
# Cd57Yb
# Gd5Ge3
# CeGa
# Wm-1K-1
# critical_exponent
# glasslike
# de_haas_van_alphen
# AC_susceptibility
# ab_initio_calculation
# dependent_resistivity_rhoT
# spin_glass_behavior
# magnetic_field_dependences
# AC_magnetic_susceptibility
# susceptibility_χ
# expansivities
# J_K-1_kg-1
# invar_alloys
# dense_kondo
# negative_paramagnetic_curie
# orders_ferromagnetically_below
# Sr1-xCax3Ru2O7
# c-mag
# Al3Lu
# metamagnetic
# spin_glass
# gamma-Ce
# neutron_diffraction_experiments
# phononic
# anomalously_large
# ferromagnetic_ordering
# yFe2+y
# adiabatic_bulk_modulus
# mixing_enthalpies
# paramagnetic_curie_temperature_theta
# Ce2Sc3Si4
# BixSb100-x
# gibbs_energy_of_formation
# MoU8
# calvet_type_calorimeter
# x_10-3_emu
# integral_enthalpies
# DeltafGTdegrees
# molK-2
# GdT2Al20
# delta_rho_rho
# automatic_adiabatic_calorimeter
# electrical_resistivity_thermopower
# Cu33Zr67
# muV_K
# large_magnetocaloric_effect
# Cr3GeN
# optical_reflectivity
# anti-Invar
# volume_collapse
# Fe2Lu
# NTi2Tl
# Co2Er
# CeRu2Si2
# B2Co2Gd
# CMn2Si
# 10-3T2
# diamagnetism
# intermediate_valence_state
# NMR_knight_shift
# rho0+AT2
# Al7Ge4PdPr2
# lambdaT
# delta_t-ad
# CNb2Si
# alpha-Ce
# Ni2SnZr2
# polytherms
# tian_calvet_calorimeter
# kB
# isoperibol
# magneto_volume
# elastic_stiffness_constants
# neel_points
# DSMmax
# upturn
# Ce3Ge6Pt4
# t-ord
# 0-340
# 2-400_K
# gruneisen_constants
# YFexAl12-x
# spin_gap
# lattice_parameter_bulk_modulus
# NpPdSn
# Mg20Ni
# GaTm
# resistivitiy
# gammaT
# melting
# LaOs4P12
# 80-300K
# caloric
# bulk_modulus_B
# ThD
# T_T-N
# Li1-xZnxV2O4
# modulated_differential_scanning_calorimetry
# B12Ho
# Na4NpO5
# mean_square_amplitude
# LiO4V2
# kelvin
# heat_capacity_Cp(T)
# elastic_neutron_scattering
# PdTb
# AlCMn2
# cop,m
# tm1
# isothermal_compressibilities
# t-o
# DeltamixH_over_bar
# effective_magnetic_moment
# wiedemann_franz
# thermo_electric_power
# mean_square_displacement
# 4Sn13
# within_the_quasi-harmonic_approximation
# neutron_weighted
# Cu3Fe
# cT
# longitudinal_sound_velocity
# Fe13Ni7
# vibrational_anharmonicity
# 4f-electron
# at_infinite_dilution
# Bi4Ce3Pt3
# quadrupolar_kondo
# magnetic_entropy_change
# Pd3U
# CePtSi
# physical_quantities
# T-N_approximate
# As2EuRh2
# NE-F
# c11_c12
# neutron_diffraction_measurements
# gibbs_free_energy
# electrical_conductivity_sigma
# mu_H-0
# pseudobinary
# As2CeCu
# sound_speeds
# xNix2
# sommerfeld_coefficient_γ
# crystal_electric_field_CEF
# 25-300_K
# La07Sr03-xAgxMnO3
# Rh3U
# solid3He
# magnetoresitance
# Dy2Ru2O7s
# delta_h-m
# zr100
# magnetoelastic_coupling
# hall_resistivity
# -lnT
# elastic_softening
# chiab
# Ge3Ho5
# murnaghan
# PuTe
# Gd7Rh3
# EoS
# T-adH
# CeRhSb
# S0298
# drho_dT
# magnetic_entropy_change_-DSM
# thermal_conductance
# omegaS
# zero_kelvin
# canonical_spin_glass
# filled_skutterudites
# griffiths_like_phase
# standard_entropy
# IrZr2
# hydrostatic_pressure_up
# gE
# anomalous
# Cu35Pd15U
# hugoniot
# Al2Lu
# 0-7_T
# spin_glass_freezing
# expansion_coefficient
# T-0
# Ge7Re3
# zero_field_resistivity
# rhoTproportional
# lambda111
# RhSiU
# B2CNi2Yb
# spin_wave_stiffness
# dlnV
# liquidus_curve
# upper_critical_field
# NiTm
# CeCu5
# antiferromagnetic_AFM_ordering
# AsCrNi
# galvanomagnetic
# standard_thermodynamic_functions
# vapor_pressure
# harmonic_approximation
# Al3CeNi2
# negative_magnetoresistivity
# magnetic_moments
# structural_disorder
# Fe2GaV
# kondo_impurity
# inverse_magnetocaloric
# calculated_phonon_dispersion
# stefan_boltzmann_law
# CeRh2Si2
# cohesive_energies
# T-SC
# kappac
# bT
# Rh6Sn18Y5
# D9I
# R-HT
# phonon_softening
# antiferromagnetic
# vibrational
# CoGeU
# GdMn2
# alphath
# relaxation_time
# landau_theory
# solution_calorimetry
# dc_magnetization_measurements
# DELTA-HT
# L12-Al3M
# supercooled
# electrical_resistivity_r(T)
# chi-1T
# partial_molal
# x-T
# curie_temperatures
# delta_rho
# hugoniot_curves
# coefficient
# nonmagnetic_ground_state
# curie_point
# standard_molar_heat_capacity
# 6-300_K
# CexRu100-x
# curie_transition
# available_experimental_data
# enthalpy_of_vaporization
# pair_correlation_entropy
# O11Rb2U4
# t-2-term
# local_magnetic_moments
# pressures_up
# CeMg3
# 55-300
# zero_magnetic_field
# cmag
# icosahedral_Al-Pd-Re
# high_temperature_isoperibolic_calorimetry
# k2mol
# spin_glass_state
# AsSe2Tl
# phonon_linewidths
# J_gK
# resonant_ultrasound_spectroscopy
# fermi_surface_topology
# Ba4Cu3Ge20
# Ga3Np2Pd
# zero-field-cooled_ZFC_magnetization
# short_range_order
# CeRu085Rh0152Si-2
# magnetoresistivity_MR
# T-C3
# quasi-harmonic_approximation_QHA
# DyNi
# tapproximate
# Pd3U2Y8
# GePdYb
# 42-300_K
# martensitic_phase_transition
# latent_heat_of_fusion
# wm-1_K-1
# d_rho_dT
# orders_magnetically
# heat_capacity_per_unit_volume
# Yb_valence
# ErGa3
# As3CaFe4
# gibbs_function
# P-T_phase_diagram
# gibbs_helmholtz_equation
# cp,mo
# PrRhSb
# Cu2Si2U
# dTm_dP
# magnetically_ordered
# LaFexAl1
# Mn2Y
# xRxCo2
# forced_volume_magnetostriction
# AgAlHo
# compressibilities
# valence_fluctuation
# arrott_plot
# isobaric_heat
# CePt2Si2
# NiSiU
# fermi_surface
# xGdxCo2
# gamma-alpha_transition
# S2SnTa
# kmin
# neel_temperature_T-N_approximate
# W_m-1_K-1
# remains_paramagnetic_down
# liquidus_temperatures
# franz_law
# molar_gibbs_energy
# Ge2U
# smoothed_heat_capacities
# kappa-ET2Cu[NCN2]Cl
# thD
# GdPd
# Ce2Ni3Si5
# seebeck_coefficient_electrical_resistivity
# BaNi2P4
# ziman
# CeRu4Sb12
# configurational_entropy
# Rh2Si2Yb
# s-d
# PrxLa1
# Cu2HoSi2
# upon_cooling
# ErNi2
# SiTiY
# c-ij
# FexZr100-x
# mu_SR
# magnetic_moment
# phonon_scattering
# LaT2Al20
# local_magnetic_moment
# TixSi100-x
# 5-(1-adamantyl)tetrazole
# self_consistent_renormalization_SCR
# enthalphy
# NbPS
# 300-600_K
# Nb37Ti63
# non-Fermi_liquid_NFL_behavior
# al1_xGex
# T-C_approximate
# rhoH
# LSCF55
# t-c_approximate
# equilibrium_phase_diagram
# deltaT
# Ag2Al15Cu15Ni2Zr13
# T-3
# Ga3U
# heikes_formula
# magnetovolume_effects
# CuO5Te2
# Gd5K3O46P
# weiss_temperature
# Al2U
# magnetic_entropy_change_DSm
# ZnEtIm2
# T-2
# Cu2PPd2
# paramagnets
# non-Fermi_liquid_behaviour
# magnetisation
# B6Pr
# K-70
# ferromagnetic_ground_state
# Au2CeSi2
# cp,m0
# through_the_quasi-harmonic_debye
# B2Tb
# diffuse_scattering
# enthalpy_change
# normal_spectral_emissivity
# jahn_teller_polarons
# spin_wave_dispersion
# VDOS
# long_range_magnetic_ordering
# CeRu1-xRhx2Si-2
# xB30
# electrical_transport_properties
# are_curie_weiss_paramagnets
# AlTm
# g-cerium
# principal_hugoniot
# -Delta_S-M
# clapeyron_clausius_equation
# debye_waller
# static_magnetic_susceptibility
# 0-50_GPa
# kondo_like
# soft_phonon_modes
# thermomagnetic
# Cu2Ge2Pr
# heavy_fermions
# hall_coefficient_RH
# linear_expansion_coefficients
# integral_enthalpy
# antiferromagnetic_ground_state
# CePtZn
# CeCoGe
# curie_weiss_type
# xC2
# paskin
# CeRhSn3
# magneto_resistance
# rotation_mu_SR
# N5S2
# birch_murnaghan_equation
# specific_heat_jump
# RMnxGe2
# standard_enthalpy
# electron_phonon_scattering
# elastic_stiffnesses
# In3Mn7Ni10
# laser_flash_technique
# independent_elastic_constants
# Cs-8[UO24WO44WO52]
# muon_knight_shift
# Nb14Ni11
# S-2980
# density_functional_perturbation_theory
# xHo
# DC_magnetization
# generalized_vibrational
# electrical_resistivity_ρ
# compressibilites
# magnetoresistance_MR
# second_order_elastic_constants
# within_the_quasiharmonic_approximation
# J_mol
# K-2
# bean_rodbell
# CaIr2
# La3Ni4Si4
# e-dis
# 300-800_K
# a-Na
# sign_reversal
# shomate
# 300-623
# PrPt2Si2
# itinerant_antiferromagnet
# Fe7Pt3
# automated_adiabatic_calorimeter
# TbT4P12
# martensitic_transition
# Fe2VAI
# delta_S-MT
# electromotive_force
# Al2CePd2
# EXAFS_cumulants
# Fe-V-Al
# CuHo
# states_VDOS
# ferromagnetic_spin_waves
# Mn2RuSi
# a-Gd
# t-c3
# pulsed_magnetic_fields
# dM_dT
# sublattice
# 293-1273
# CoHo3
# heat_capacity_C(T)
# congruently_melting
# 2TN
# phonon_excitations
# curie_weiss_behaviour
# PdSbY
# magnetocaloric
# l(T)
# isothermal_magnetic_entropy_change
# T
# liquid_3He
# paramagnet
# resistivity_rho0
# thermodynamical
# electron_phonon_coupling_constant
# mean_square_displacements
# FeGes
# DC_magnetic_susceptibility
# CeFe11Ti
# T-P
# Fe4P12Tb
# thetaCW
# non-Fermi_liquid
# K-1
# sign_change
# AuYb
# LnCl2
# isothermal_magnetization_M(H)
# d-Al-Cu-Co
# latent_heats
# CeCu6
# AlHo
# change_DTad
# surface_tension
# betath
# reentrant
# above_TN
# CeCoGe3
# AgEuGe
# antiferromagnetism
# HoNi2
# sound_attenuation
# Tb-Mg-Zn
# highly_frustrated
# 15-300_K
# fermi_liquid
# fermi_liquid_regime
# In13Mn41Ni46
# muon_spin_relaxation
# states_DOS
# 5f-electron
# NFL_behavior
# lattice_constants_bulk_modulus
# born_von_karman_model
# isobaric_heat_capacity_cp
# ferromagnets
# standard_molar_entropy
# saturation_moment
# magneto_resistivity
# CrCs2O4
# partial_molar_enthalpy
# sommerfeld
# T_T-C
# -dSM
# Al3AuCe
# polycrystalline_elastic_moduli
# RhYb_2Si
# T-Cinter
# T-M1
# magnetic_hysteresis
# U-Ga-Al
# ordered_magnetic_moment
# seebeck_coefficient_electrical_conductivity
# curie_weiss_paramagnetic_behavior
# B-T
# CrCuS
# Si3Tb5
# available_literature_data
# PtU
# B4La
# magnetic_torque
# thermomagnetization
# phonon_drag
# Al2CW3
# lamb_mossbauer_factor
# TA2_phonon_branch
# Ni2+xMnGa1-x
# compositional_dependence
# Cp,mo(T)
# Al-Fe-Ge
# Bi2Te3111
# metamagnetic_transitions
# 10-300_K
# FeHOSe
# CCr3Ge
# ising_antiferromagnet
# miedema_et_al
# Mn3P
# quantum_critical_point
# partial_enthalpies
# lnT
# rhomag
# non-isoelectronic
# 14-300_K
# tian_calvet
# muK
# HTSCs
# Y-Mg-Zn
# lattice_thermal_conductivities
# curie_weiss_law_above
# entropy_change_-Delta_S-M
# pressure_derivative
# Fe2V1+xAl1-x
# uranoborates
# pair_correlation_function
# isoperibolic
# MgNDC
# bT2
# delta_S-Mmax
# 0-5T
# Ir2O7Pr2
# curie_weiss_like
# Co2Lu
# Co2Ho
# Ni21Ti395Zr395
# intermediate_valence
# Ca18La82MnO3
# magnetic_excitations
# PbYb
# chiAC
# reversible_MCE
# isothermal_magnetization_curves
# itinerant_ferromagnet
# rhoT_proportional
# CeOs4Sb12
# Se8TlV5
# metamagnetic_phase_transitions
# electrical_resistivity_thermoelectric_power
# T_-->
# As2BaRh2
# Mie-Gruneisen-Debye
# BaF6Th
# 1K-1
# ordinary_hall_coefficient
# ferromagnetic_paramagnetic
# LTEC
# g(T)
# SnSe-Bi2Se3
# spin_glass_like
# GdNi2
# dependence
# mean_field_theory
# bloch_law
# ErNi
# heavy_fermion_state
# xNi2
# W_m-1K-1
# CeGePt3
# spin_wave_spectrum
# T-SF
# MnNi2Sn
# CrReTe
# gibbs_energies
# HfZn2
# DeltaHM
# third_order_birch_murnaghan_equation
# volumetric_thermal_expansion_coefficient
# Ti-50-xNi-xFe
# ferrimagnet
# GdxLa1
# spin-density-wave
# heisenberg_model
# CuIr2Se4
# s-mo
# geometrically_frustrated
# MHyFe
# Al3Yb
# matthiessen_'s_rule
# spin_excitations
# antiferromagnet
# dilatometric
# NiSnTb
# mol_K2
# nonmagnetic
# murnaghan_equation
# local_moments
# solid_3He
# 300-711
# diamagnetic_susceptibility
# |DSMmax|
# crystalline_electric_field_CEF
# Ag4Gd3Sn4
# paramagnetic_curie_weiss
# intinerant
# Ni4P2Yb
# P-V-T
# Ga2U
# measured_by_adiabatic_calorimetry
# korringa_constant
# J_kg*K
# precision_adiabatic
# X(T)
# Co5Y
# A1Y
# condensed_excitonic_phase
# neisen
# tetraborides
# Ni2MnZ
# As12LaOs4
# CoLu
# 10-340
# power_law_divergence
# partial_derivative_T
# QHA
# shastry_sutherland
# AuSi3Sr
# gammaHT
# CuSc
# K-2[UO22MoO4O-2]
# H-2980
# GeU
# B12Lu
# Al1513Fe85La
# superconducting_transition_temperature_Tc
# BaO3U
# V)T
# 18-300_K
# cp,m
# metamagnetism
# 42-500
# excess_enthalpy
# AC_susceptibility_measurements
# Cu2PrSn2
# Ga7Ge3Yb3
# Cu2Si2Tb
# FE90
# phonon_phonon_scattering
# giant-unit-cell
# inelastic_scattering
# mol_cm3
# s-d_scattering
# kg-1_K-1
# low-T
# Al2NdNi3
# dodecaborides
# 5f-shell
# superconducting_critical
# curie_temperature_TC
# Ag8GeSe6
# 4f_electrons
# antiferromagnetic_long_range
# dS_dT
# negative_magnetoresistance
# tetragonal_Cr2Si2Th_type
# bloch_gruneisen
# Ac_susceptibility
# K2NpO4
# TCapproximate
# 2kB
# MgSi2Yb2
# ultrasonic_velocity
# GdGeMn
# METAMAGNETIC
# B12Yb
# melting_point_t-m
# As4U3
# CuS4V2
# Al2Tb3
# epsilon-Fe
# Al8Fe4Sc
# unit_cell_volume
# rho-T
# BaP2Rh2
# nuclear_resonant_inelastic_x-ray
# rattling
# theta-TaN
# C-11_C-12
# BaTiO3-delta
# magnetization_curve
# MnNi2Sb
# McMillan_formula
# neutron_diffraction_data
# anti-ferromagnet
# lindemann_criterion
# thermoelectric_transport
# mol-K-2
# Ge2Rh2U
# Ga2Y
# electrostatic_levitation_ESL
# CuNiSb2-AP
# O6Os2Rb
# cp(T)
# heavy_quasiparticles
# mole-K
# AgCeSb2
# random_magnetic_anisotropy
# ordinary_hall
# mictomagnetic
# magnetic_fields
# OsTi
# Sm(T)
# rhoT_curve
# InYb
# metallic_character
# phonon_renormalization
# spin_fluctuation_theory
# thermo_emf
# lindemann
# critical_exponent_beta
# surface_tensions
# paramagnetic_curie
# KO3U
# derivative_of_bulk_modulus
# quasi-binary
# Ga3Tm
# magnetic_entropy_change_DS
# b'infinity
# korringa
# xDyCl3
# Smo(T)
# powder_neutron_diffraction_measurements
# thermal_expansion_CTE
# CeIn5Ir
# RCo2_compounds
# elastic_wave_velocity
# isobars
# C60CsNa2
# InPtU
# gomega
# AuGe2In3Yb3
# DFEI
# ge-13
# hdegreesm
# degrees29815
# UTX_compounds
# Ge-Te-Se
# lattice_dynamical_properties
# gammaMn
# AgCu4Yb
# heat_flow
# 100-300_K
# Nd4Ni3O10
# itinerant
# CaRh2
# s-xy
# spontaneous_magnetostriction
# degrees29815_K
# magnetocaloric_properties
# AlCe8Pd24
# xR
# moment
# thermopowers
# localized_magnetic_moments
# heavy_fermion_HF
# callaway_model
# equiatomic_ternary
# electrical_resistivity_hall_coefficient
# quantum_oscillations
# vapour_pressure
# Gd3Pd4
# log1_T
# elastic
# range_5-300_K
# T-M
# S-CC0
# antiferromagnetic_order
# mictomagnetism
# neel
# differential_scanning_calorimeter
# C2NdNi
# TM-Sc
# CeGa2Ni
# neel_transition
# YbZn2
# excess_molar_volumes
# ferromagnetic_moment
# kondo_insulator
# rhoxyT
# NiSnU
# vibrational_spectrum
# TA2[xi
# isothermal_entropy_change
# rhoac
# Ca98Dy2MnO3
# near_room_temperature
# H-298
# Cpo(T)
# spin_reorientation
# bulk_modulus_debye_temperature
# green_kubo
# heavy_fermion_systems
# itinerant_electron_metamagnetism
# CeCuxAl4-x
# URU2SI2
# RB12
# pauli_paramagnetic_behavior
# spin_dynamics
# AsMnRh
# HgO3Pb
# ferromagnetic_spin_fluctuations
# molar_magnetic_susceptibility
# Ce7Ni3
# thermoelectrical
# HoT2Al20
# gibbs_energy_functions
# Bi125Lu15O245Re
# EOS
# -DSM
# statistical_moment_method
# dTc_dP
# N2S5
# calvet
# kJg
# or_equal_to015
# electrons_per_atom
# Cu2Si2Yb
# transverse_acoustic_modes
# conduction_electrons
# spectral_hemispherical_emissivity
# Cu5Yb
# SmxGd1-x2Zr2O7
# temperature_range_4-300_K
# poisson_'s_ratio
# zero-field-cooling_ZFC
# MRIM
# order_disorder_transitions
# inverse_magnetocaloric_effect
# sigmamu_H-0
# xFexGe3
# baric
# ErIn3
# Ho2PdSi3
# fermi_level_NE-F
# neel_temperatures
# CdGdPd
# young_'s_modulus_shear_modulus
# laser_flash
# BaFe1-xCox2As-2
# In3Ru
# xAgxGaTe2
# ambient_pressure
# magneto_caloric_effect
# betael
# nernst_coefficient
# single_crystal_elastic_constants
# absolute_values
# NpOs2
# hyperfine_fields
# Al2Ge2Ho
# landau
# resistivity_anomaly
# GeV3
# phonon_density_of_states_DOS
# r(T)
# Mn47Ni43Sn11
# paramagnetism
# absolute_value
# anisotropy_constants
# STm
# melt_solution_calorimetry
# FeXMn1-XS
# DyNi4Si
# debye-
# hexagonal_AlNiZr
# {Go(T)-Ho(0)}
# chidc
# DTad
# MHyMn
# Ni2Sc
# C2CoGd
# first_order_magnetostructural_transition
# x_10-4_emu
# positive_magneto_resistance
# al1_xSix
# electrostatic_levitation_technique
# point_defect_scattering
# electron_magnon_scattering
# magnetic_field_h-c2
# RhYb
# TM-A
# inelastic_x-ray_scattering
# pauli_like
# configurational
# As2Fe2Yb
# DyNiSn
# nonmonotonic_behavior
# Ce3Cu3Sb4
# 80-300_K
# dR_dT
# PrFeAsO1-y
# paramagnetic_moment
# acoustic_mode_gruneisen_parameters
# long_range_magnetic
# T_t-c
# curie_like
# HT_H298.15
# nFl
# de_gennes_factor
# upper_critical_field_h-c20
# gamma0
# H-c2T
# Cu2Tm
# pressure
# CTc2
# clapeyron_equation
# phonon_branches
# nearly_half_metallic
# t-l
# Ge2Mn2Sm
# deltarho
# AsRuV
# C-11-C-12
# b-c0
# Co2Tb
# B4Tm
# Nd2O7Ru2
# magnon
# DCp
# magnetization_ac_susceptibility
# nEF
# moelwyn
# xVxSi
# BCS_superconductivity
# antiferromagnetic_fluctuations
# gatom-1
# MnNi2Tb
# anharmonic_phonon
# elastic_constants_cij
# Al3Tm
# liquid_Ge3Te17
# non-Fermi_liquid_state
# FeHf
# K-1957
# CexLa1
# internal_friction
# Co7Er12
# rhodes_wohlfarth
# gamma-delta
# gammal
# Ni17Ti415Zr415
# Co5Gd
# AmN
# cv(T)
# orders_ferromagnetically
# Li61Na39
# EXAFS_debye_waller_factor
# metal_insulator_transition
# superzone
# hyperconductor
# concentrational
# primitive_cell
# Co6Er3Sn5
# self_diffusion_coefficient
# H-T
# shastry_sutherland_lattice
# CurieWeiss
# isoenthalpy
# adam_gibbs
# Fe1-xVx3Al
# phonon_phonon
# La15Mn2O7Sr15
# TmZn
# coefficients
# delta-epsilon
# GdT
# molar_gibbs_free
# atomic_displacements
# rhoop
# fu-1
# B2CeRh3
# Mn6Nd
# modified_arrott_plots
# calorimetrical
# Mn7Ni10Sn3
# susceptibility_chi
# thermal_conductivity_k(T)
# Cu2Ge2Yb
# an_electrostatic_levitator
# J*kg-1*K-1
# DsubHm
# main_crystallographic_directions
# Au4V
# Bi2Eu2F4S4Sr
# iron_pnictide_superconductor
# CeCoGe2
# delta_S-M
# isoperibol_calorimetry
# AlRu2V
# PdYb
# coefficient_of_thermal_expansion
# melting_points
# CuPrSi
# CeGa2
# xScxNi2
# K'T0
# e-Fe
# magnetic_field
# BiPtYb
# Fe18Pt7
# 0(T)
# As2BaMn2
# interatomic_interaction
# dc_electrical_resistivity
# Pd2Si2Yb
# phonon_anomalies
# Hg2O7Os2
# AgAlEr
# Mn2Si2Tm
# magnon_drag
# Al7Fe5U
# scaling_law
# SiTa4Te4
# sub-room
# T-CP
# magnetically_ordered_states
# standard_molar_heat_capacities
# T)V
# degreesT
# GdSi
# hyperfine_field
# spin_wave_excitation
# DELTArho
# W_mK
# Ge2LaNi2
# phononic_effects
# isobaric_expansion_coefficient
# x-independent
# 2D-Ising
# polytherm
# brillouin
# ac_susceptibility_measurements
# Mn88NdSb2
# M(m0H)
# isentropic
# excess_gibbs_energy
# Bi05Sb15Tex
# anti-invar
# B12Zr
# upper_critical_field_hc2
# 673-1373
# clapeyron_slope
# cpo
# hemispherical_total
# lambdax
# B3Re7
# kappalatt
# muon_spin_rotation
# standard_molar_thermodynamic_functions
# magnetostriction
# DeltaCp
# cexp
# shear_modulus_g
# thermoelectric_power_seebeck_effect
# partial_molar_entropies
# magnetostructural_transition
# kbar
# helmholtz_free_energies
# isothermal_compressibility_kT
# delta_T
# GaU
# diamond_anvil_cells
# at_megabar_pressures
# betax
# temperature_independent_paramagnetism
# non-magnetic
# J*K_-1*mol
# giant_magnetocaloric_effect
# ln8
# off_stoichiometry
# AuBe5_type
# kJ_kg-1_K-1
# DSM-2M
# H-T_phase_diagram
# DH(T)
# pseudogap
# standard_molar
# thermoelectric
# rho42_K
# -T
# GaMn81Ni219
# curie_temperatures_Tc
# clapeyron_clausius
# frustrated_spins
# B-2T
# Al2NpPd5
# nonmagnetic_singlet_ground_state
# dimensionless_figure_of_merit
# Al2Yb
# J*g-1*K-1
# magnetisation_measurements
# resistance_TCR
# magneto_striction
# kondo_effect
# JK-1_mol-1
# emu_mol-1
# mJ_K-2
# eliashberg_spectral_function
# FeO7SbY2
# ferromagnetic
# hydrostatic_pressures_up
# cnu
# induced_metamagnetic_transition
# valence_fluctuations
# GammaT
# t-mp
# debye_waller_factor
# anisotropic_magnetostriction
# LaMnSi2
# elastic_anisotropy
# range_10-300_K
# 300-14
# JK-1mol-1
# T-Cx
# pseudo-gap
# H(T)
# lnrho
# betaT
# Cd2O7Os2
# CePt3Si
# T-Curie
# xSnx3
# Ce3Ge11Pt23
# dilatometry
# Ce2In8Pd
# force_constant
# D298.15
# Au8Ba4P15
# differential_scanning_calorimetry
# frustration
# hmo(298.15
# DT298.15
# isothermal_compressibility_thermal_expansivity
# miedema_'s_semi-empirical_model
# khT(T)
# curie_temperature_Tc
# electrical_resistivity_rho_seebeck_coefficient_S
# magnetization_versus
# K-T0
# below_the_neel_temperature
# Al-Mn-Pd
# cubic_AgAsMg_type
# invar
# Fe11Ho
# phonon_modes
# s-mmax
# moments
# isobaric_specific_heat
# frustrated_pyrochlore
# neel_temperatures_T-N
# T-1-1
# vanishing
# dcij
# isochor
# melting_point_Tm
# 80-370
# inelastic_neutron_scattering_experiment
# DeltafG_degrees
# heats_of_fusion
# quasielastic
# isofield
# elastic_wave_velocities
# phasons
# localized_moments
# CoGd3Ni
# Ga100Mn81Ni219
# FeSbV
# Al2Cu5Ni2Zr11
# RNiAl
# J_·_K-1_·_mol-1
# clausius_clapeyron
# 0-K
# s-tr
# U-08
# As12PrRu4
# incommensurability
# neutron_scattering_cross_sections
# Ag2InPr
# Ge2Mn2Y
# solidus_temperatures
# -logT
# antiferromagnetically_ordered
# Ru2U
# below_TN
# magnetization_M(T)
# Cu2Y
# WII-A
# temperature_range_10-300_K
# TeU
# critical_point
# magnetic_entropy_change_|DSM|
# EtMe3Sb[Pddmit2]2
# hypercooling_limit
# molH2-1
# ThetaT
# mu_omega_m
# magnetoresistivity_measurements
# s-mpeak
# deviates_from
# narrow_gap_semiconductor
# Cu5U_xPdx
# diamond-anvil-cell
# Ce2CuGe6
# refrigerant_capacity
# joule_thomson_coefficient
# rho-T-2
# CeIrSn
# RET2Al20
# deviations_from
# isobaric_thermal_expansion
# staggered_magnetization
# lindemann_law
# acoustic_modes
# UCu4+xAl8-x
# derivativeP
# frustrated_antiferromagnet
# S-T0
# CuSi2Zr
# high-T
# used_to_calculate_standard_thermodynamic_functions_namely
# large_reversible_MCE
# Al2NdPd5
# tauep
# CoTb3
# finite
# below_T-MI
# DHm
# dTMI
# t-range
# cp(T
# vortex_lattice
# hcp_bcc
# supercooling
# partial_derivative_P
# spin_wave
# magnetic_susceptibility_data
# mJ_mol_K2
# ThM2Al20
# As12LaRu4
# fcc_FeHx
# Cu4GdIn
# fluctuating_valence
# 2CuSi3
# Gd2Hf2O7
# electron_phonon_interactions
# optical_conductivity_sigmaomega
# pauli
# ferromagnetic_correlations
# positive_magnetoresistance
# As2CaPd2
# cp{ring
# calvet_calorimetry
# S298
# Al3CoGd3Ge2
# critical_exponents_beta
# semi-classical_boltzmann_theory
# interatomic_forces
# intermediate_valent
# c-p_T-3
# hc2(0)
# K-250
# thermoelectricity
# structure_factor_sq
# ordered_moment
# CdCe
# calculated_elastic_constants
# c44
# dynamically_unstable
# Ba3Te2O9s
# T1T
# semiadiabatic
# large_magnetoresistance
# quasibinary
# CrLaSb
# enthalpy_delta
# Ba6Ge25
# p)S
# Pu-Ce
# BaBkO3
# W_m-K
# vapor_pressures
# antiferromagnetic_below_T-N
# DeltaT
# gammae
# high_temperature_isoperibolic_calorimeter
# SrRuO3(s)
# CaN2Zn2
# AlRh3
# spin_phonon_coupling
# griffiths_like
# birch_equation
# b-ytterbium
# c15b
# Lu2Fe17-xMnx
# cr
# ferromagnetic_kondo_lattice
# amorphous_fe90
# CuTm
# Al2Tm
# LaRh
# inelastic_x-ray
# rho25
# GammaK
# r_Tb_Dy_Ho
# 10-20K
# P-T
# pT
# congruent_melting_point
# 17+/-
# DySi
# isothermal_compressibility_bT
# BaCoNa2O42P
# commensurate_antiferromagnetic
# liquidus_temperature
# momentum_transfer
# HoNi
# 2-700
# Bi2Ho6Mn
# So(T)
# Bi2Pd3S2
# elastic_constants_c-ij
# magnetic_entropy_change_-DSm
# t-t
# c-e
# Pd5Tb3
# O2722W
# reversible_magnetocaloric_effect
# sesquicarbide
# MnPd2Sn
# MnO3Yb
# T-2-Al2MgC2
# GdInPd
# non-centrosymmetric_superconductor
# lattice_relaxation_time
# x_10-6_K-1
# antiferromagnetic_ordering_below
# miedema_'s
# residual_resistivity_ratio_RRR
# Hf2Ni2Sn
# kappaL
# spin_susceptibility_χ
# rhoxxB
# superconducting_transition_temperatures
# degreesT-H
# AgAlDy
# electrical_transport_measurements
# renormalization
# curie_constant
# anomalous_hall_conductivity
# Er2Fe17
# CECU6
# Gd5Si4
# thermoelectric_power_factor
# xcsimilar
# HdegreesmT
# dTc_dp
# khT
# curie_paramagnetic
# alpha-plutonium
# 10-4T
# Cu2Dy2O5
# NiSbSc
# resistivity_minimum
# jump
# resisitivity
# rhoT_curves
# heisenberg
# AlCoU
# C2CeNi
# zero_point
# Cp,m(T)
# CeInPd
# SbVZn
# mn100
# isothermal_compressibility_isobaric_expansivity
# de_haas_van_alphen_oscillations
# thermoelectric_properties
# entropy_change_delta
# in-plane_resistivity
# O11Tl2U4
# dTC_dp
# -Delta_s-m
# liquid_helium
# delta_H
# ROBiS2
# bloch_'s
# copyright_C_EPLA
# spin_wave_theory
# thermo_physical
# lattice_parameters_bulk_moduli
# thermoelastic
# isobaric_thermal_expansion_coefficient
# BeLi
# neutron_diffraction
# acoustic_branches
# Fe2Ge2Y
# B4Er
# S2980
# ternaries
# poisson_ratio
# incoherent_kondo
# temperature
# 0-50_kOe
# rho4
# solidus
# Pb3U
# mol-1K
# antiferromagnetic_insulating_state
# inelastic-neutron-scattering
# integral_enthalpy_of_mixing
# second_order_phase_transitions
# standard_gibbs_energy
# spin_fluctuation_scattering
# hexagonal_GaGeLi_type
# g-atom-1
# glass_transition
# rhoT_rho0
# power_factor
# rho
# ST-S298.15K
# calorimeters
# Ir2O7Tl2
# enthalpies_of_mixing
# Pr3Rh4Sn13
# antiferromagnets
# NdY
# CeInRh
# SiC-AC
# GeSb2Te20
# m-0s
# Ce2GeRh3
# kappa0
# murnaghan_equation_of_state
# magnetoconductance
# anisotropic_thermal_expansion
# thermodynamic_description
# polynomials
# Al8Ge17
# BaNi2P2
# ln_rho
# CuU_sub
# K-300_K
# Ce5Cu19P12
# 0-100_GPa
# GeNdSc
# Ga2MnSb2
# smoothed_molar_heat_capacities
# gibbs_free_energy_enthalpy
# 0-20_GPa
# CALPHAD_assessment
# REPdSn
# AgLi2Sb
# Ge6La3Pd20
# partial_thermodynamic_functions
# thermodynamic_parameters
# AlCoCr2
# thermo_elastic
# Ga2HfMn
# InxCo4Sb12
# approximant
# 155Gd_mossbauer
# b-metamag
# AlFe2V
# zero_applied_magnetic_field
# pulse_echo_technique
# gibbs_energies_of_formation
# Al-Pd-Fe
# NbHx
# longitudinal_acoustic
# pseudo-binary
# Na2ThF6(s)
# a-Cu2As2O7
# magneto_elastic_coupling
# ac_magnetic_susceptibility_measurements
# chi0
# GdGe2Mn2
# Hmo(T)
# small_polaron_hopping_model
# Bi2Se3_Bi2Te3
# Ca5Si3
# a-YbAlB4
# CeCu6_xAux
# partial_molar_enthalpies
# B2CDyNi2
# isothermal_bulk_moduli
# range_2-300_K
# Cu6Pr
# AlPr
# electrical_conductivity_seebeck_coefficient
# heptacopperII
# Ga215Mn294Ni491
# Cr19V
# T_thetaD
# FeSc
# precision_automated_adiabatic_calorimeter
# paramagnetic_PM
# antiferromagnetic_AF
# long_range_ordering
# h-c0
# paramagnetic
# FeGa2Hf
# Cu-15[FeCN6]zH2O
# Y1_xUxPd3
# nonzero
# third_law_entropies
# curie_–_weiss
# or_equal_toTless_than
# jarl
# theta_d
# anharmonic_correlated
# AlCuTb
# DHf
# DELTAT
# 2H-CrTe2
# magnetoelastic_interaction
# AlRu2Ta
# hall_conductivity
# heavy_fermion_metals
# La9MnO3Te
# BNbRu
# adiabatic_scanning_calorimeter
# solid_solutions
# bulk_modulus_young_'s
# M3CeBr6
# alpha-function
# CoFeSnTi
# rate_T-1-1
# Fe-Fe3S
# CoGaU
# 5-325
# CrFeTe
# states_NE-F
# DeltafG
# M-I_transition
# HT-HP-Tb3O5
# CoDy3
# rho0T
# heavy_fermion_superconductor
# pade_approximants
# K-0T
# measurement_system_PPMS
# Bi3Gd4
# BaBiKO
# Mn1-xPrxAs
# neutron_depolarization
# umklapp_scattering
# dynamical
# lambda-type
# BiPtSc
# m{ring
# Ge2Ni2Tb
# orders_antiferromagnetically_below
# CrRuTe
# CeRu_sub
# As2Ta
# order_disorder
# SQomega
# xFexB6
# chimol
# As2Cu2Sr
# short_range_ferromagnetic
# relative_partial_molar
# average_sound_velocity
# magnetoconductivity
# anti-ferromagnetic
# GdIn
# Eu4Ga8Ge15
# mg-51
# a2F(o)
# delta_h-f
# Bi11MnYb14
# Ir2Nd2O7
# Cd57Yb10
# Tc
# i-Al-Pd-Re
# AIMD
# glassy_state
# curie_weiss_fit
# electronic_correlations
# Cd2EuSb2
# yosida
# neat_MOF-5
# universal_curve
# enthaply
# metamagnetic_behavior
# magnetothermopower
# hall_resistance
# Be13U
# dTm
# T-Csimilar
# excitation_spectrum
# Sb59Zn41
# phonon_subsystem
# normal_boiling_point
# semimetallic
# S298.15
# electrical_conductivity_s(T)
# tetragonal_Cr2Si2Th
# pair_correlation_functions
# delta_s-m
# cyclotron_masses
# mode_gruneisen_parameter
# 300-1000_K
# Co3Er
# 3-300_K
# T)P
# short_range_correlations
# antiferromagnetic_AFM
# thermoelectric_figure
# Al-Li-Zn
# lindemann_index
# Non-Fermi_liquid
# Cu2Sm
# RhU
# electrical_resistivity_ρ_seebeck_coefficient_S
# rho0
# Ge4La3Ni4
# standard_gibbs_energies
# zero
# few_kelvins
# anharmonic_lattice
# subregular_solution
# MMSMA
# mu_V_K-1
# correlation_functions
# xAl2
# lattice_parameters_elastic_constants
# field_cooled
# In3Pr
# phenomenological_percolation_model
# SDW_state
# orthorhombic_NiSiTi_type_structure
# ac_magnetization
# nuclear_spin_lattice_relaxation
# mixing_enthalpy_of_liquid
# h-m
# Si-Ga-Y
# muon_relaxation
# T-MI
# phonon_dispersion_calculations
# paramagnetic_to_ferromagnetic_transition
# dfG
# SbY
# modulus_shear_modulus
# powder_neutron_diffraction
# Fe11GdRe
# excess_heat_capacities
# kondo_lattice_compound
# K4Si23
# resistivity_upturn
# Sb10Yb11
# AsCeRh
# CeCoSb
# z-method
# qij-1
# AlCrNi2
# born_von_karman
# clausius
# B12U
# x-dependence
# curie_weiss_paramagnetic
# J_kg-K
# lattice_relaxation_rate_T-1-1
# transverse_phonons
# order_antiferromagnetically_below_TN
# delta_h-vap
# phonopy
# Al10Ru2U
# boson_peak_height
# Fe-RE
# muB
# CeGePt
# redlich_kister_type_equation
# PbTe_PbSe
# Al4Fe5Mn
# hugoniot_adiabat
# C15Rb
# BNi4Sm
# pseudobinary_alloys
# GaGeYb
# RuU
# to-T
# CTaTiZr
# EuO_EuS
# δ_f_g
# vinet_equation
# magnetism
# RNiGe3
# Zr-Te
# metal_insulator_MI_transition
# alpha-ZrW2O8
# FeGe2LiO6
# NSLR
# kauzmann_temperature
# lattice_parameter
# Ca2CrO6Sb
# DOS
# Ho5Sn3
# SeTm
# Ho(T)
# B2CoFe7
# PPt3Sr
# TA1[110]
# gnu
# 4f-electrons
# chiH
# xCox2
# RFe4Sb12
# rhom
# rhoalpha
# mean_square
# magnetocaloric_effects
# GaPu3
# t-str
# B6Na
# dodecaboride
# dTC_dP
# J_K-1_mole-1
# Be3Zr7
# melting_enthalpy
# Mn2Pr
# h-c1
# Fe-Ni_invar_alloys
# NiSnTi
# Mn4O15Sr7
# Y1_xCaxTiO3
# liquid3He
# T-OO
# TMTTF2Br
# ThetaE
# Ga8Ge15Sr4
# computed_elastic_constants
# diverges_logarithmically
# atom-1
# GVDOS
# factor_s2s
# CeCuGa
# sound_wave_velocities
# LuNiSb
# delta_t-admax
# 20-300_K
# megabar_pressure
# Co2SnU2
# superconducting_fluctuations
# P12PrRu4
# magnetocrystalline_anisotropy
# figure_of_merit_ZT
# rhoproportional
# r_Y_Lu
# H34LiN
# T-CPr
# Sb2Te3-xSex
# f_electrons
# invar_alloy
# rho273
# h-c2t
# 77-600
# itinerant_magnetism
# semi-empirical_miedema
# 0-30_GPa
# 19-300_K
# microinhomogeneous
# H-CT
# magnetothermal
# chi-1
# differential_thermal_analysis
# -Tc
# CePPd
# enthalpies_of_sublimation
# zOsz
# NiSbYb
# ErFe2D31
# C15_laves_phase
# C2GdNi
# at-1
# Mn74NiSn26
# excess_thermodynamic_functions
# extrapolates
# Ho(T)_ho(0)
# Al-Ni-X
# Ce1-xLaxRu2Si2
# Cd-Pr
# thermopower_S(T)
# NdNi5Sn
# 119Sn_mossbauer_spectroscopy
# field_cooled_FC
# subsystem
# T_c
# a-site_cation_radius
# quantum_criticality
# h-fus
# superconductive
# we_calculate
# Bi2CoSe3
# HfOs
# GdxSi1-x
# 1-108
# phonon_umklapp_scattering
# density_of_states
# FeGe2
# P)s
# As2BaCr2
# acoustic_phonons
# Al229Ni771
# elastic_constants_C-11
# negative_MR
# FeSbTa
# bulk_modulus_shear_modulus_young_'s_modulus
# arrot
# h-fmo
# numerical_calculations
# YbMn6Ge6-xSnx
# resistivity_rhoabT
# dP_dT
# anti-ferromagnetism
# Fe91Si9
# 10-6_K-1
# internal_frictions
# liquidus
# PtSnZr
# eu1_xLaxB6_x
# spontaneous_magnetic_moment
# icosahedral_quasicrystal
# emu_mol
# Cu11Fe11S2
# gruumlneisen
# rho300
# cij
# slater
# NpTe
# AuEuGe
# boltztrap
# CeNi2Si2
# orthomanganites
# rho295
# Bi7Cu11
# In3Ir
# CuGaTe2
# screened_coulomb_repulsion
# 4-800
# mu0H
# extrapolated
# redlich_meyer
# non-Fermi_liquid_NFL
# moDH
# liquid_rubidium
# varies_linearly
# Al15LaNi35
# redlich_kister_polynomial
# longitudinal_magnetoresistance
# f-electron
# phmo
# enthalpy_increment_measurements
# DCp(T)
# BNi4Y
# 10-5K-1
# LaP12Ru4
# K-1273
# gK
# Al8Fe4U
# r_La_Ce_Pr
# MnNd6O3Sr4
# heat_capacity_cp,m
# xCrxSi
# t-t0
# inverse_MCE
# quasiternary
# bT0
# binary_phase_diagrams
# UEOS
# itinerant_ferromagnetism
# Ni2Si2U
# Ho2O7Ti2
# ZrCr2Hx
# Co2Y
# Ce5Si3
# long_range_antiferromagnetic
# iso-field
# linear-muffin-tin-orbital_method
# derivative_of_the_bulk_modulus
# Cu30Ni10P21Pd39
# electronic_band
# DyO6RuSr2
# Ce3Te4
# absolute_seebeck_coefficient
# Al-Nb-Ti
# mu0Delta_H
# a-Na2U2O7
# large_nonsaturating
# strongly_anisotropic
# sublattices
# LuO4Ta
# optical_phonons
# 4.2-70
# cluster_spin_glass
# elastic_constants_elastic_moduli
# inelastic_x-ray_scattering_IXS
# NiS4V2
# zero-magnetic-field
# GdMn6Sn6
# Al-Ge
# resitivity
# quasi-adiabatic_calorimeter
# T-cT
# AuCeSb2
# lattice_relaxation_rate
# DE-F
# zT
# DeltamixH
# nonmonotonic
# CoGa8Ho2
# Redlich-Kister-Muggianu
# VDx
# second_order_birch_murnaghan_equation
# deviation
# l-type_anomaly
# Cu5Mg13Tb2
# Al8CeFe2
# multiphase_equation
# splat_cooled
# AsFeOTb
# partial_molar_entropy
# dT0
# Voigt-Reuss-Hill_approximation
# tcis
# RAgSn2
# korringa_relation
# broad_peak
# small_polaron_hopping_conduction_mechanism
# CeRh
# vibrating_reed_technique
# RMC_simulations
# umklapp
# paramagnetic_to_ferromagnetic
# jkg-1
# lambdaep
# bhf
# Ge10Rh4Yb5
# equilibrium_lattice_constants
# unusually_large
# ordering
# J_kg-1_K-1
# physical_properties
# EuGa2Ge4
# Lu-H
# copyright_c_EPLA
# -DSmpeak
# per_atom
# thermoelectric_figure_of_merit
# kondo_scattering
# T-SDW
# Cu2Gd
# mean_field
# CePb3
# magnetostructural_transformation
# -linear
# ising_like
# Ge3Te17
# kondo_semiconductor
# sb-x
# relaxation_times
# cpa
# Mg2Rh4+O4
# rhoHT
# Gd-Si-Ge
# deduced_from
# spin_peierls
# Na28PtSi
# galvanomagnetic_properties
# effective_magnetic_moment_mueff
# Ni5Pr
# acoustic_phonon
# upper_critical_field_h-c2
# D0THmo
# mu_VK-1
# CuIr2
# m0H
# metalliclike
# precision_adiabatic_vacuum
# dvap
# AgGeYb
# merit_ZT
# resistivity_rhocT
# ultrasonic_pulse_echo
# partial_molar_heat_capacity
# alpha-Hf
# molar_gibbs_energies
# gammabcc
# thermoelectric_powers
# europium_chalcogenides
# lattice_parameters
# OsTM
# 298-600
# DyRh
# coefficient-gamma
# nernst_ettingshausen
# re-entrant_spin_glass
# emf_measurements
# spin_fluctuation_spectrum
# Pt4U3
# NaO4Rh2
# vertical_bar_delta_S-M
# GdGe
# arrott_plots
# anti-ferromagnetic_ordering
# j*mol-1
# Cu44Yb
# beta-pyrochlore
# T-PM
# h-x
# a-FexZr100-x
# linear_magnetoresistance
# electron_scattering
# ttrs
# dHc2
# gilvarry
# phonon_phonon_interaction
# U1-xThxPd2Al3
# saturated_vapor_pressure
# ferrornagnetic
# AlCo2V
# K-473
# elastic_constants_C11_C12
# -DSmmax
# exchange_constants
# Hm(T)
# ehrenfest_relation
# Bi22Sb3
# bulk_modulus_B0
# critical_concentration_xc
# Dy5Pd2
# peltier
# Cl6NbRb2
# B3Ru7
# logarithmic_divergence
# atomic_displacement
# diffuse_x-ray_scattering
# gruneisen_constant_γ
# Al10Fe2U
# Cs-K
# stoner
# MxTiSe2
# AlRhU
# h-0c20
# neel_temperatures_TN
# quasiparticle_lifetime
# LH_DAC
# dP
# As11Eu14Mn
# 0(T)-H
# berman
# levitation
# Hf025Zr025Ta025Sc025B-2
# order_ferromagnetically
# dT|Tc
# magnon_phonon
# static_bomb
# first_principles_electronic_structure
# cpo(298.15
# precision_adiabatic_vacuum_calorimetry
# 42-0066
# partial_molal_volume
# independent_pauli
# moriya
# long_wavelength_limit
# spin_reorientation_transitions
# a-CoV2O6
# prefactor
# Al-Fe-Gd
# metallic_ferromagnet
# 30-300_K
# InPdTm
# LaRhSn
# diamond_anvil_cell
# Ga3Zr
# morse_potential
# conduction
# colossal_magnetoresistance
# Co2Dy7Tb3
# cauchy_pressure
# T-AFM
# experimental_data
# RCoO3
# Pr1-yYy07Ca03CoO3
# ac_susceptibilities
# bulk_modulus_B-0
# hyperfine_field_bhf
# AFM-PM
# lindemann_melting
# polarized_neutron_diffraction
# Mn6Ni19
# gamma-FeH
# CoV3
# entropies_of_fusion
# quasi-two_dimensional
# hard_sphere_model
# h-ext
# Cu5U
# SDW
# CeNi
# non-Debye
# IrSbZr
# EuNi2P2
# Gd7Pd3
# negative_weiss
# anharmonic_vibrational
# Dr(T)
# Non-Fermi_liquid_behavior
# enthalpy_of_sublimation
# omegaTO
# alpha-Be
# BaCo2O55Tb
# transverse_spin_freezing
# 1T-VSe
# CeRu
# Pb3Pr
# configurational_entropies
# T-D
# giant_negative_magnetoresistance
# CeSix
# thermoreflectance
# Fe12P7U2
# semiclassical_boltzmann_transport_theory
# J_mol-1K-1
# delta_h-f_degrees
# hydrostatic_compression
# UTX
# toT2
# electrical_conductivity_σ
# Cu6S8SnW
# diamond_anvil_cell_DAC
# simon_glatzel
# heat_conduction
# standard_molar_gibbs_energy
# GaRu2V
# C44
# hugoniot_data
# va_n't_hoff_plots
# frustration_parameter
# p-V-T
# c(T)
# FeGd5Ge19Si2
# exchange_coupling_J
# p-c_approximate
# AlCo4Pr
# refrigeration_capacity
# peff
# complete_set
# Cd-Pb-Sn
# R2Mo2O7
# Ni-Mn-Ti
# m-sp
# n-H-2
# superconductivity
# NiSnYb
# xTixSb2
# gibbs
# Ce_LIII_edge
# gammaa
# self_consistent_renormalization_theory
# extraordinary_hall_effect
# electrostatic_levitation_furnace
# chiq
# antiferromagnetic_ordering_below_TN
# hoch_arpshofen
# zero-field-cooled_magnetization
# relaxation
# 300-1100_K
# AuCeCu59
# 10-2T2
# miedema_model
# antiferromagnetic_ordering_below_T-N
# magnetic
# ErFe_sub
# gamma-Fe80-xNixCr20
# mWm-1
# W_K-1_m-1
# degrees298
# heavy_fermion_antiferromagnet
# Gd-Si
# CeOs4P12
# interatomic_force_constants
# second_virial_coefficient
# C2NiPr
# deltah
# Cd-Na
# ground_state
# Fe8Tm
# Mg2Si1-xSnx
# K'0
# MoO6Sr2Ti
# 45-300_K
# GeNiU
# itinerant_electron_magnet
# YMn2Hx
# dHvA_oscillation
# LuPdSb
# BDy
# ClHo
# r(T
# lindeman
# BoltzTraP_code
# linear_thermal_expansion_coefficients
# ferrimagnetic_ordering
# fermi
# gibbs_free_energies
# T-IC
# CeP12Ru4
# gamma-Fe_precipitates
# Fe4MnSi3
# xLaxNi2
# externally_heated_diamond_anvil_cell
# solid_solubilities
# resistivity_r(T)
# CeGe2Mn2
# RBa2Cu4O8
# phonon_dispersion_relation
# gibbs2
# Cp0(T)
# muon_spin_precession
# calorimetrically_measured
# enhanced_pauli_paramagnet
# degrees0
# As12Fe4La
# transverse_magnetoresistance_MR
# deltamix
# [Pdtmdt2]
# gapless
# insulator_transition
# se-4
# h-TiAl2
# CrTh_2Si2
# AlBiCu
# upward_curvature
# fully_gapped
# anomalous_hall_effect
# x-dependent
# gijr
# Mn2Si2Tb
# bloch_'s_law
# ueff
# muB_per
# Ir2Si2Yb
# 10-6T2
# single_impurity_kondo
# isochors
# QMD_simulations
# RCo2
# BiLuPd
# K'0T
# sound_speed
# spin_waves
# superconducting_transitions
# xLax
# FeHo_sub
# Ru6Sc5Sn18
# mie_gruneisen
# freezing_point
# t-rho
# wave_vector
# Ru2SiV
# 1.5ReO
# orders_antiferromagnetically_at_TN
# polynomial
# SrxBi2Se3
# phase_equilibria
# long_range_order
# TN_≈
# KKR_CPA
# Al9Ce11
# ClCs_type
# K2[(UO2)2(MoO4)O2]
# still_awaits_experimental_confirmations
# B-HF
# order_antiferromagnetically_at_TN
# Fe-Ni-Co-Ti-Cu
# dispersion_curves
# SQUID_magnetometer
# magnetoquantum
# rhoxx
# magnetic_hyperfine_field
# CePd3
# curie_weiss_paramagnet
# phonon_mean_free_path
# DeltafGo
# standard_enthalpy_of_formation
# M2InC
# temperature_range_15-300_K
# In8Mn17Ni25
# AgPr
# Cu24O41Sr14
# compounds_order_antiferromagnetically
# equation
# NiYb
# type-II_superconductivity
# pyrometric
# literature_data
# lattice_anharmonicity
# W_cm-1_K-2
# tcomp
# large_reversible_magnetocaloric_effect
# enthalpies_of_formation
# local_pseudopotential
# magnetotransport
# T)p
# CoSnU
# Ga-Li
# DfusSm
# heusler_type
# pseudo_gap
# substitutional_disorder
# Co2LaP2
# Cu3Pd39Si8
# YFe2Dx
# xL
# CoEr
# fermi_energy
# CePdSn
# FM-PM_transition
# heusler_L21
# H0(298.15
# AuGe3Yb2
# DHmix
# coqblin_schrieffer_model
# LnTa2O6
# a-CuMoO4
# T_T-P
# LaFe116xSi14B01
# magneto_crystalline_anisotropy
# cp,m{ring
# DSM(T)
# negative_thermal_expansion_NTE
# molar_enthalpy_of_vaporization
# JANAF
# Ge2LaMn2
# configuration_entropy
# spin-density-wave_SDW
# lattice_thermal_conductivity_kappaL
# t-linear_term
# dependences_of_the_hall_coefficient
# curie_weiss_paramagnets
# static_displacements
# Co9Zr
# DeltafGmo
# weak_localization
# positive_sign
# Mg-Cu-Ag-Gd
# beta-Sc
# BiPdSc
# FeU
# CeMn2Si2
# mu_omega_cm
# Pr5Si3
# 3Y2
# DFT_DMFT
# NTE
# BeH3Li
# -uranium
# 08Tm
# four_probe
# slow_relaxation
# kappa-BEDT-TTF2CuNCS2
# CeGe2Ni
# Ca2Si
# boltzmann_transport_theory
# RCuAl
# TCHEA1
# J_g-1
# Ag)2S
# Gamma-N
# K)-
# DI-DCNQI
# h-c2
# state_EoS
# meta-magnetic
# clausius_clapeyron_relation
# epsilonTT
# ferromagnetic_ordering_below_TC
# DySb
# multiextreme
# itinerant_magnet
# Er-Y
# incommensurate_commensurate
# curie_law
# excess_molar_enthalpy
# SMmax
# kBT
# weiss_constant
# disordered
# large_positive_magnetoresistance
# dT_dP
# speed_of_sound
# 16-300
# As2BaFe2
# thermoelectric_figure_of_merit_ZT
# As2Cd9GeZn
# DeltamixHmo
# anisotropy
# spin_correlations
# 300-900_K
# rho300_K
# SeTl2
# DT0Sm
# isenthalpic
# M(T)
# accuratly
# non-superconducting
# sructural
# khM
# high-pressure-synthesized
# so(298.15_K
# Cu-Fe-V
# (Fe1-xVx)3Al
# derivativePP
# upper_critical_field_hc2(0)
# SbSc
# PtSnTi
# standard_integral_thermodynamic_functions
# normal_spectral_emittance
# thetap
# non-configurational
# paramagnetic_moments
# MCE
# Ce3In11Pt
# freezing
# states_DOSs
# Co2CsSe2
# caloric_curve
# kaneyoshi
# FeH5Zr2
# Al13Cu4Ru3
# dTx
# Ce2In8Pt
# hfg
# exothermic_enthalpy
# quasihydrostatic
# Go(T)_ho(0)
# f(T)_curves
# EAM_potential
# RhZr2
# birch_murnaghan_equation_of_state
# reentrant_spin_glass_RSG
# canting_angle
# boltzmann_transport_equation
# KD2_pro
# alphav
# RTiGe
# xCoxSb12
# itinerant_ferromagnets
# cal_per_mole
# b-YbAlB4
# magnetic_frustration
# strong_electron_phonon
# ISbTe
# magnetic_entropy_change_-DSMmax
# s(T)
# electric_field_gradient
# elastic_constants_bulk_modulus
# DOS_at_the_fermi_level
# liquid_fragility
# spin_glass_SG
# Bi-Sb_alloys
# T*_≈
# CaO4Sc2
# AuPbY
# Bi2EuF4S4Sr2
# -DSmaxm
# Mn2-xFexAs05P05
# CePt2
# decreases_almost_linearly
# magnetization_M-T
# canted_AFM
# AIRE
# ultrasonic_wave_velocity
# Al23Mn25Ni2
# vant_hoff
# La2-xSrxCuO4-delta
# spin_lattice_relaxation
# superconducting_transition_temperature_T_c
# K_GPa-1
# S-2_sigma
# quasicrystals
# magnetoelasticity
# WF_law
# bulk_modulus_shear_modulus_young_'s_modulus_poisson_'s_ratio
# GaNiU
# quasielastic_neutron_scattering
# CeCu2Si2
# Fe1-xMnx75P16B6Al3
# very-low-temperature
# pseudobinary_system
# bredig
# calorymetry
# T-SRO
# 8Ga16Ge30
# weak_electron_phonon
# CdCr2Se4
# saturated_vapour_pressure
# calorimetric_studies
# DeltamixHm_degrees
# zener_anisotropy
# shubnikov-de
# kgK
# AlB4Cr3
# small-polaron-hopping
# triple_axis_spectrometer
# RMn6Ge6
# J_kg_K
# la1_xKxMnO3
# Ho2O7Sn2
# BiHo
# 10-300K
# Ga2La
# CuNpOP
# excess_partial_molar
# kappaxy
# self_diffusivity
# Mo2O8Th
# thermometer
# 151Eu_mossbauer_spectroscopy
# CrInO3
# augmented_plane
# phonon_dispersion_curve
# CrO3Tl
# birch_'s_law
# rho-T_curve
# polyamorphic_transition
# RAuGe
# fe85
# SbYb
# F7Li3Th
# spin_wave_stiffness_constants
# cr29815
# CuYb
# Cr-Ir
# refrigeration_capacity_RC
# b-m
# volume
# chiTIP
# miscibility_gap
# magnon_dispersion
# Fe17N3Nd2
# canted_magnetic
# Yb1+xMg1
# Cu13Sn7
# GaPr
# K)3
# S-2_rho
# Er5Si4
# levitated
# large_MCE
# PdPrSn
# AsNbRu
# burakovsky
# dTN
# cpl
# order_ferromagnetically_below
# Gd24Ge11ScSi9
# McMillan_equation
# quasi-ternary
# reentrant_spin_glass
# PDOS
# BiCo5Gd12
# vary_non-monotonically
# Al3Ni2U
# relative_partial_molar_enthalpy
# ho(0)
# self_diffusion_coefficients
# C15-Fe2Zr
# tfus
# 10-290
# antiferromagnetic_ordering_at_TN
# strongly_anharmonic
# glass_forming
# Cr2Si2Th_type
# Ce3M4Sn13
# alpha-TaB2-x
# Sn3Yb
# dc_ac
# magnetotransport_measurements
# curie_temperatures_T-C
# t-con
# ZrO2-Gd3NbO7
# x_10-3_K-1
# ab_initio_calculations
# FOMT
# excess_molar_heat_capacity
# superfluid_density
# ...
# CuO_sub_4-d
# Williams-Landel-Ferry_WLF
# xVO3
# structure_factor_S(Q)
# TMDSC
# CoGaMnNi
# 105T-2
# dielectric_anomaly
# C-33
# alkane-a,o-diols
# sub-Kelvin_temperatures
# TLIESST
# incoherent_scattering
# hyperfine_parameters
# Fe4Sb12Yb
# low-T-C
# low-omega
# fragility_parameter
# BaBi2Mn2
# Ba3Te2O9(s)
# xCo5
# sign_inversion
# linearized_augmented-plane-wave
# mueff
# Fe25Te23
# Gd5(SixGe1-x)4
# phase_coherence_length
# q-range
# quasiparticle_bands
# U-Al
# landau_coefficients
# lattice
# yNiy
# excess_molar_volumes_VmE
# T2_term
# 05-42
# cm-1center
# ferrimagnetically
# heavily_doped_semiconductors
# antiferromagnetic_insulating_AFI
# finite-T
# x-ray_powder_diffraction
# magnetic_compton_profile
# quantum_critical_point_QCP
# In5La3
# 5-295
# theT
# antiferro-
# phenomenological_percolation
# M2Te
# ZHC-1
# alpha-PtAl
# Ag-Al-Cu
# CdNa
# isostructural_compounds
# ferromagnetic_resonance_linewidth
# tless_than_or_equal
# som(g
# Fe-Ni-Ti
# 4-320
# adiabatic_approximation
# brillouin_zone_center
# P-V-T-x
# quenched_disorder
# RMn2Ge2
# AgBiSr
# co-efficient
# T-SE
# eutectic_point
# kondo_necklace_model
# intrinsic_coercivity_hci
# Gd-Y
# kappa-BEDT-TTF2CuSCN2
# restudied
# dilute_magnetic
# local_lattice_distortion
# Be13Yb
# quantum_monte_carlo
# transverse_sound_velocities
# vS
# Ga-Sb
# As2CaCo2
# HoO4P
# maximum_entropy
# nanocalorimetric
# pressure-volume-
# Ba8AlxSi46-x
# track_radii
# susceptibilities_χ
# linear_muffin_tin_orbital_LMTO_method
# Cl3Dy
# gammaS
# conduction_mechanism
# AsNp
# Sn-9Zn-05Ag-1In
# AlGd
# A-AFM
# Os-Pt
# semi-empirical_model
# zeno_line
# non-Boltzmann
# 42-40
# Cd2O7Tc2
# Mo3P
# isoperibol_solution_calorimeter
# premartensitic_transition
# transient_hot_wire_THW
# DFT+DMFT
# 160-270
# thermal_inertia
# LDA+DMFT
# R11Ni4In9
# superconducting_SC
# B4Sm
# remanent_magnetization
# xVxS
# bragg_reflections
# SeTl
# oscillate_periodically
# MnTb
# alpha0
# B2C2Dy
# BH44KSc
# muDy
# chi
# mott_VRH
# solidification_interval
# DH(m)
# RuSr
# J.C._baltzer_scientific
# electric_field_gradients_EFG
# MFe12O19
# BoltzTraP
# MnO3Pr5Sr5
# universality_class
# BiCuChO
# pr1_xCaxMnO3
# triple_axis
# kph(T)
# magnon_scattering_processes
# CZTGeSe
# doped_manganites
# h0o
# diagonal_disorder
# x-ray_scattering
# Al27Cu64Mn9
# CuEuNdS3
# (ZrTi)(V1-xAlx)2
# assessed_by_means_of_the_CALPHAD
# r(p,T)
# occurrence_of_superconductivity
# zintl_compound
# O7Zr2
# subregular
# lZ
# frustrated_magnets
# multivalley
# Co10Na9O20
# two_magnon_scattering
# DSmaxM
# CoSr6
# mono-pnictides
# DSC-1B
# AgSeTl
# dcrg_hm{ring_operator
# angle_resolved_photoemission_spectroscopy_ARPES
# CuW3
# kinetically_arrested
# NSiTi2
# nearly_constant
# below_T-N_approximate
# collisional_radiative
# mDTA
# moial
# 10-350
# interval
# coupling_EPC
# Tc_almost-equal-to
# fcc-fct
# BiSbSeTe
# InNiTi2
# iQC
# B2'
# xCo2
# glass_formers
# formalism_CEF
# cubic
# gigapascals
# la1_xBaxMnO3
# B315Co43Fe20Ta55
# NaCl+H2O
# xFexSi
# cuprates
# d-wave_superconducting_gap
# linearized_muffin_tin_orbital
# quantum_monte_carlo_QMC
# B4HoRh4
# Ge5Ti6
# quadrupole_interaction
# GaRh
# c_axes
# p-p-T
# uniaxial_stress
# nd90
# synchrotron_diffraction
# discrepancies
# dimensionless_thermoelectric_figure
# chiomega
# t-s
# nuclear_inelastic_scattering
# DmixHm
# Fe2R
# re-determination
# critical_exponents_β
# weak_localization_correction
# VmE
# Co-3AlW
# logarithmic_divergences
# 290-340
# kh'(T)
# hubbard_hamiltonian
# reverse_monte_carlo_modelling
# magnetic_bragg_peaks
# C20K
# harmonic
# incoherent_inelastic
# T\T_-->
# Ca3Rh4Sn13
# 1,1'-dibenzoylferrocene
# Pu-Al
# Ag4Al3Cu3Ni4Zr26
# antisite_disorder
# Ni12P7Yb2
# non-parabolicity
# co-magnetic
# BiGd
# kadowaki
# predominant_antiferromagnetic_interactions
# co-volume
# hp-RESn3-x
# insulating_side
# ungapped
# xFexB
# ising_ferromagnet
# C-ET
# tvib
# electronphonon_coupling
# Debye-Waller
# m0Hc
# sr1_xCaxRuO3
# Cu3NiW20
# Cd-Sb
# terminal_solid_solutions
# activation_enthalpy
# CVM
# warm_dense_matter_WDM
# 300-1700
# TC)g
# Ag2CrO2
# itinerant_electron_metamagnetic_transition
# charge_ordered
# -Ga2Se3
# Sc-B
# clathrate
# VHDA
# conductance
# casimir_force_between
# C-V
# ZMGO
# high-T-c_cuprates
# prTx
# shear_modulus_young_'s_modulus_poisson_'s_ratio
# hasselman
# BiDyPd
# tetragonal_Mn12Th
# 5In
# tf(
# defectons
# kaptay
# magnetic_propagation_vector
# liquiclus
# g-factor
# insulator
# Co7Y2
# C2Cl4CuH12N2
# shubnikov-de_haas_SdH_oscillations
# VITROVAC
# thermodiffusion_coefficient
# dT_dp
# bulk_modulus_K-0
# 10-3_omega_cm
# hund_'s_coupling
# sensitivity_s-r
# Zn-2C8H4O42center
# heat_losses
# within_the_generalized_gradient_approximation_GGA
# B3Fe90Zr7
# nonmonotonous
# incoherent_inelastic_neutron_scattering
# xSb2
# pcan
# 5-300K
# non-spin-flip
# xSbxTe
# R3+
# magnetostrictions
# spin_seebeck
# oln
# elastic_stiffness_tensor_components
# spectral_weight_transfer
# parachor
# statistical_thermodynamics
# hP6_AlAs
# CuGeO3
# cpv
# maki
# subtracting
# 70-300
# nb1
# co80
# excess_isentropic_compressibility
# hubbard_model
# ph{symbol}V
# mott_hubbard_insulator
# xSrxMnO3
# BrPr
# CEF_splitting
# magnetohistory
# Mo2O7Sr3
# yttrium_dihydride
# lead_borate
# spincrossover
# CoGeMnZr
# Te2U
# isotropic_heisenberg
# calculation_of_phase_diagrams
# excellent_agreement
# TMTSF2ReO4
# band_overlap
# conductivites
# drude_term
# Ho_Tm
# T-CM
# range_hopping_conduction
# T-CA
# mole(
# TECs
# K-Tl
# localized_states
# ac
# TMAl3
# freeenergy
# xRuxSb2
# Fe-Zr
# density_of_states_DOS_at_the_fermi
# O18SrV13
# CuSbSe2
# RTAl
# X3Y
# mugm
# TiT2
# cooled_magnetization
# collinear_antiferromagnetic_structure
# RMn2Si2
# CoGeNi
# d-wave_superconductivity
# demagnetizing
# data_available_in_the_literature
# elastic_scattering
# G298.15
# wavevector
# r_Pr_Nd_Sm
# degree_of_undercooling
# hall_coefficient_RH(T)
# commensurate_antiferromagnetic_structure
# amorphousized
# 200-300_K
# oscillation_amplitude
# U1-yNdyO2-x
# DSm(T
# capcity
# ballistic_regime
# XSAS
# CGeTi2
# jij
# exact_diagonalization
# MW_m2K
# gamma-values
# manganites_RMnO3
# Al5H3Zr5
# sigmaOmega
# FP_LMTO_method
# xMnSb
# BaNbO3
# GdMnO3
# isosteric_heats
# quasicrystalline
# gru''neisen
# BCu2GaO5
# x_10-6K-1
# negative_thermal_expansion_coefficient
# ioffe_regel
# effective_hamiltonian
# BeSiZr
# cubic_approximant
# B7Fe2
# quantitative_agreement
# lm3m
# 1-xLa
# gallides
# ab_initio_plane_wave_pseudopotential_density_functional_theory
# infinitely_dilute
# fiolhais
# LiNbO3Yb3+
# logX
# interchain_interactions
# sc1-x
# thermomagnetic_history
# T-{C}
# resonant_ultrasound
# Al71Cr24Fe5
# incompressible
# baber
# BiCo2Fe98O3
# RuSiZr
# LIII_edges
# quasiperiodic_fibonacci
# BiMn2SbYb
# xCaxMnSb11
# 298-423
# fe82
# Ce(Fe1-xCox)2
# Cu2NiZn
# CeIn
# HoMnO3
# phonovoltaic
# PRhSc
# far_above
# InRh
# 1pyr
# 4-filled
# quasilocal
# augmented_spherical_wave
# Cu3SbSe4
# EuPd2Si2
# bulk
# gutzwiller
# hvap
# CuGd
# doublet_ground_state
# ising_models
# Au11Cu5Si4
# i-AlCuFe
# pseudogap_regime
# CALPHAD_CALculation_of_PHAse_diagram
# ClFSr
# AlN289Ti4
# variable_range_hopping_mechanism
# quenched-in
# la1_xNaxMnO3
# s2r-1
# epsilon11
# CuKMnS2
# FOPT
# Cu6Pd775Si165
# nearest_neighbors
# microcanonical_entropy
# neutron_powder_diffraction_NPD
# p,m
# Nd2Fe17-xTx
# orthoperovskite
# 273-363
# antiferromagnetic_kondo
# upper_critical_fields_hc2
# Co2SnZr
# excitation_spectra
# laser_flash_apparatus
# BiLa
# thermo_electromotive_force
# CaZn2
# AITPA
# omegaL
# oC-
# three-omega
# drude_contribution
# heat_convection
# liquid
# gaussian_approximation
# Al20Cu3380Tm67
# Li10O11Si5
# grover
# l-BEDT-TSF
# tetragonal
# pulsed_magnetic_field
# Cu28Gd11Mg61
# Cu6Sm
# t-cm
# MEAM_potentials
# aptekar
# MnTe2
# u-parameter
# volume_piezometer
# thermal_conductivity_TC
# paramagnons
# solubility_limit
# t-t'-J_model
# SC-I
# B12Hf
# phonon_group_velocities
# Ihm-Song-Mason
# sigma_tau
# strongly_correlated_fermi
# optical_pyrometry
# b-c_plane
# CoLa85O3Sr15
# C60H3K3N
# relaxation_time_t0
# mot-1
# interconfiguration
# FeAl-Pv
# mJ
# 870-970
# antiferromagnetic_exchange_interactions
# CaIrSi3
# Ti-25Ni-25Cu
# Pt-2dta4I
# volumes_VE
# Ba5CoLa5O3
# fixed_spin_moment
# scattering_NRIXS
# Cux+yBi5
# binary_phase_diagram
# entropy_term
# CuNi44
# s-wave_superconductivity
# tetrahedrally_bonded_semiconductors
# tunneling_spectroscopy
# pyrochlore_iridate
# J_kg
# just_above
# endothermic_peak
# fullerite
# hexagonal_CaCu5_type
# nd-4f
# entropically_stabilized
# bethe_ansatz
# Mn12Y
# thermoanalysis
# a-FeSi
# Cd2Pu
# thermoremanent
# AFM_ordering
# mucal
# FeS7Sb3Sc
# 2Cd
# apparent_molar_compressibility
# F7LuZr
# ab_initio_simulations
# quantum_monte_carlo_simulations
# LRO_parameter
# Tb-Bi
# kJ_molH2
# Fe-S_liquids
# BiGdPt
# time_differential_perturbed_angular_correlation
# coulomb_correlation
# kJ_·_mol-1
# U-Ga
# Br3Nd
# B4Na
# peltier_effect
# mu_W_cm-1_K-2
# suppression_of_spin_fluctuations
# gd6
# Fe3Ga4
# supercooled_liquid_region_DeltaTx
# theta-BEDT-TTF2CsZnSCN4
# RMnGe
# NiTaTe5
# meta-stability
# stopping_power
# subsecond
# PdZr2
# semiempirical
# mott_hubbard_transition
# delta0_kBTc
# pbaOH
# nuclear_quadrupole_resonance_NQR
# speromagnetic
# special_quasi-random_structures
# biquadratic_exchange
# under_nonhydrostatic_compression
# mean_free_path
# calorlmetry
# sn3
# previous_assessments
# ho(0)'
# e-ZrHx
# limiting_partial_molar_volumes
# quasi-crystals
# t-square
# normal_state
# DyNi3
# ab_initio_molecular_dynamics_simulation
# DOSs
# ground_state_doublet
# 2Zn17
# augmented_plane_wave_FPLAPW
# e-Mo
# BYb_sub
# body-centered-cubic
# ijk
# ISDW
# aerodynamic_levitation
# La4Ni3O10
# curie_temperature_TC_≈
# near_half_filling
# dielectric_function_refractive_index_extinction_coefficient
# Gibbs-Di
# 151Eu_mossbauer
# S-MMaxvertical
# DU4+
# lanthanide_orthophosphates
# avrami_exponent_n
# RMn12
# spontaneous_magnetizations
# CaO-AlO1.5-CeO1.5
# invars
# EXCITATIONS_IN
# APW_band
# NiU
# EHDAC
# ho3+_ions
# virial_theorem
# dSmax
# crystallize_in_the_hexagonal
# 3-Te
# j*g
# cm_K-2
# a-AlMnSi
# laser_heated_diamond_anvil_cells
# ferromagnetic_exchange_interaction
# gibbs_duhem_relation
# H-a1H
# Al63Co24Cu13
# omegaLO
# sc1
# coherence_length
# 1-xFx
# gamma4g
# RAl2
# cmma
# Y(Fe
# AlHoPd
# RT2X2
# nonstoichiometric
# reciprocal_space
# ab_initio_lattice_dynamical
# localized_4f_electrons
# SQUID_susceptometer
# dielectric_function_epsilonomega
# potential_linear_muffin_tin_orbital
# CeNi9
# 2Sr1_2MnO3
# Ruderman-Kittel-Kasuya-Yosida
# bulk_moduli_shear_moduli
# 4LiGe
# OsSiTa
# LEK94
# antiferromagnetic_resonance_AFMR
# oP12
# Vogel-Tammann-Fulcher_equation
# IN20
# clarke_glew
# s-electron
# AsRuZr
# magneto_structural
# de_gennes_scaling
# exact_muffin_tin_orbitals_method
# carrier_density
# d2I_dV2
# PdFex
# stevels
# scattering_vector
# 6+x_sub
# Co_2CrAl
# chiparallel
# csat
# BaSb2Zn2
# jm-3
# formula_unit
# kelvins
# Nd-Cd
# Al62Cu255Fe125
# PbSe2
# mean-square-amplitude
# p-pc
# alpha-YHx
# VZhM-4
# 2bp
# hirai
# m-spin
# 2hJ
# PrxNd1
# onsite_coulomb_interaction
# sharp_cusp
# Ba2NaO6Os
# LiP15
# 10-310
# C(T
# degreesf
# positive_magnetoconductance
# C3Y2
# pseudo-binary_system
# CeGa2Rh2
# cumulant
# CoGa5Pu
# brittleness
# gap-wise
# LaPb3
# 1673-1873
# ginzburg_landau
# monodeuteride
# cp,298
# NiSbTi
# TDTR
# Tl-Te
# T)r
# Fe-B-Si-C
# PPMS-9
# ySnyTe
# s-f_exchange
# enthalpy_delta_H
# alpha-transition
# p,V,T
# As2Pt2Sr
# mol-1_K-1
# DsolHmth
# rule_of_additivity
# Hg89Mn11Te100
# plane_wave_pseudo-potential
# CALPHAD_approach
# Fe-Ni-V
# ZFC-FC
# AFe2As2
# IrX
# gamma1d
# fxc
# mu_eff
# absolute_seebeck
# fe-15wt
# dr_ρ
# CeMgSn
# knudsen_effusion_mass_spectrometry
# fe-57_mossbauer_spectra
# downward_shift
# DeltaM
# quasicrystalline_phases
# aT+b
# curie_–_weiss_law
# beta-Zn4Sb3
# LMTO_calculations
# CeNiSi
# C2ScSnV2
# ↔_C2
# partial_molal_volumes
# zTs
# -/+delta
# magneto_elastic
# gammacb
# EuPPt
# gammaFeO
# renormalisation
# BULLK-1
# RD496
# DeltaTx
# anderson_localization
# SLNWs
# sub-regular_solution_model
# AuCuI
# photoionization_cross_sections
# efg
# semi-classic
# debye_–_callaway
# CaSb2
# heat_fluxes
# phonon_roton
# just_above_tg
# fitted_to_a_redlich
# d-O2
# TiZrNbCu1-xNi-x
# 25-900_degrees_C
# hysteresis_loss
# CeIn5Rh
# DSC-2C
# negative_deviations_from_the_ideal
# Al29Co38Ni33
# supercooled_liquid_region_DTx
# NixTiSe2
# susceptibilities
# CrSb2
# gibbs_free_energy_DG
# EMFP
# BRh3Sc
# martensitic_phase
# EuFe
# Ce2Fe
# AIIBIVC
# 0-108
# neel_point_TN
# Ni-Pr
# exchange_couplings
# jex
# Nb-Au
# P-V_curve
# mol-1
# Co6Ge6Y
# P-T-x
# T_almost-equal-to
# Np-Zr
# cubic_symmetry
# Quasi-One_dimensional
# invariant_reactions
# alpha'-BEDT-TTF2IBr2
# epsilonlambdasolid
# BCoCuFeNb
# C-11'
# J*mol-1*K-1
# alpha-Np
# BiCePd
# sn-flux
# TM-SC
# mW_cm-1_K-2
# 298-500
# DcH
# drag_coefficient
# brillouin_zone
# bond_ionicity_lattice
# electronically_driven
# Ga5PtU
# In3La
# NaTl
# non-collinear
# VIII_clathrate
# 5-xGa
# TbX
# DHmin
# magnetization-
# inelastic
# range_hopping
# augumented
# atomic_mobilities
# tracer_diffusivities
# m-IrN2
# intermetallic_clathrates
# DHfus
# vitreous_selenium
# va_n't_hoff_plot
# FMII
# impurity
# f.u.-1
# curie_constants
# Eu2Ir2O7
# 4f_moments
# minority_spins
# h-c
# t-cr
# oxygen_deficiency
# anderson_localized
# ab_initio_plane_wave
# self_consistent_spin_polarized
# CeFeSi_type
# polaron
# DC_magnetic_susceptibility_measurements
# heavy-rare-earth
# kissinger_method
# AlCo2Cr
# T-MIT
# to075
# critical_exponents_β_γ
# Bi91Sb9
# alpha-relaxation
# CFe8
# gmo
# -1K-2
# similar_or_equal
# adjustable_parameters
# rosenfeld
# torque_magnetometer
# ofthermal
# AsCe
# tco
# S(Q_omega
# CoMnSb
# isothermal_annealing
# r-T
# far_infrared_reflection_spectra
# incompressibility
# RE2Pd2Cd
# Fe80-xCoxP13C7
# lambdaC
# KZnX
# electromagnetic_levitator
# kr1
# FeSi2Tb_type
# GPa2
# vicinity_of_the_fermi_level
# Ba-Si
# chalcogenide_superconductors
# magnetocrystalline_anisotropies
# |S|
# RNi4B
# 298-1173
# AsCuSiZr
# radial_distribution_functions
# scaling
# sn-119_mossbauer
# 3d-sublattice
# asphericity
# LPCBMO
# 60-K
# kT(T)
# narrow_gap_semiconductors
# pressure_transmitting_medium
# m-s
# CoFK
# M-PUCOT
# 3R-MoN2
# 2O7)2
# relaxation_time_τ
# TCof
# skew_scattering
# FeIO33
# below_tf
# PNTNPHATCD
# Se80-xTe20Sbx
# isotropic-smectic-A
# asperomagnetic
# M-T_curve
# giant_reversible_MCE
# r_La_Ce_Pr_Nd
# vertical_bar_delta
# peng_robinson_equation
# La0.7Sr0.3Mn1-xCoxO3
# MnZ
# merit
# E-06
# cI16
# sub-binary_systems
# hexachloroelpasolite
# La2CuO4-y
# k2m
# ScZn6
# fee
# FexMn1
# boiling_point_elevation
# phonon_coupling_parameter
# x(y)
# fe8
# bogoliubov_inequality
# charge-density-wave_CDW
# fluorite-pyrochlore
# FeNb8SbTi2
# 0*027
# hc2
# j*kg-1
# density-functional-theory_DFT_calculations
# 77-300K
# mott_hubbard_gap
# nonquasiparticle
# CrFe15
# msand
# 300-870
# lead_telluride
# nanothermodynamic
# Fe2Pu
# CuLaOSr
# metamagnetic_shape_memory_alloy
# T-
# ErxNi100-x
# KSb5V3
# MgO3Si_ilmenite
# weak_antiferromagnetic_exchange_coupling
# superfluid_3He
# x)c-C6H12'
# T-cT-
# K3MoO3
# Yb-Cd
# logarithmic_corrections
# Sr-Cu-O
# wave_LAPW
# ErN
# soft_coulomb_gap
# phases_coexist
# itineracy
# exothermic_peak
# TEC
# n-acetylglycinamide
# elastic_constants_C11
# V(T)
# thermoelectric_figure_of_merit_zT
# k-lat
# V1-xCrx2O-3
# 2Ca2Cu3Oy
# phonon_linewidth
# magnetodielectric_effect
# cuprate_superconductors
# carrier_concentration
# I4_mmm
# MS(T)
# charge_density_wave_CDW
# infrared_absorption
# phonon_boltzmann_transport_equation
# rigid_rotator
# damping
# nondiverging
# r_Sm_Gd
# t-BC
# HEB
# Eu-Yb
# warm_dense_matter
# viscosity_deviations_de
# epsilon10
# tensor
# Fe22Ni3
# re-entrant_spin
# occupation_numbers
# Dy_Ho
# AlRE
# magnetic_hyperfine_field_b-hf
# dominant_antiferromagnetic_interactions
# orbital_moment
# Hc2T
# kJ_kg
# NaCl-B1
# Te3U2
# BFeO4Pb
# tetragonal_symmetry
# Si3W5
# compressiblities
# BeS_BeSe
# MPCM_slurry
# Tl2Ba2CuO6+x
# crossovers
# RFe2
# TDPAC
# localized_spins
# nonmetal_transition
# resolution_neutron_powder_diffraction
# mott_variable_range_hopping
# bi-content
# kappal
# imaginary
# energy_MAE
# BTb
# dimensionless
# iron_monosilicide
# beta-Na033V2O5
# CU-AL-BE
# hubbard_U
# YMn2Dx
# t-m2
# asymptotic_expressions
# magnetocaloric_materials
# K5-xCo1-xSn9
# Fe-Si-S
# FHx
# MTi2O5
# non-acoustic
# difference_between
# –_entropy_compensation
# Fe-Mn-Ga
# t-x
# uB
# EuInRh
# AgGdGe
# As10F3Fe10O7Sm10
# delta_t-max
# ITS-90
# DSfus
# In2Pd8Se
# Ca2MnO3Pr8
# spins
# millidegree
# electromotive_force_emf_measurements
# mKs
# calculation_of_phase_diagrams_CALPHAD_method
# copper-oxygen_planes
# DeltaS_over_bar
# 77-300_K
# berry_phase
# AlCePt
# thermodynamic_reassessment
# FP_LAPW_method
# formalism
# rocksalt_structure
# DSf
# nd1_xSrxMnO3
# pseudopotentials
# retrograde_solubility
# magnon_magnon
# quasiternary_system
# DWF
# electromagnetically_levitated
# critical_isochore
# Fe17Pr2
# butler_'s_equation
# hall_angle
# crystallizing_in_the_hexagonal
# Al15Cu3V2
# polaronic
# designer_diamond_anvils
# sub-lattice
# fermi_pockets
# T-To
# Zn-Yb
# 5f_electrons
# cluster_expansion
# GeS2(cr)
# t-mi
# ternary_molybdenum_sulfides
# h-sublattice
# non-Arrhenius
# valence_band_electronic_structure
# ternary_system
# kTE
# small_angle_neutron_scattering_experiments
# Co3Ho
# V0(T)
# Te_5p
# d-electrons
# carrier_effective_masses
# vapour-liquid_equilibrium
# AS2Se3
# BaO7Si2Zn2
# path_integral_molecular_dynamics
# microcalorimetric
# qmax-1
# high-spin-low-spin
# Co2NbSn
# FeSe1-x
# paris_edinburgh
# dkh
# R3(Fe
# electronic-
# GdH
# DsubH
# jumpwise
# ultralow_thermal_conductivity
# extended_miedema_model
# tg,1
# Mn2U
# synchrotron_x-ray_diffraction_measurements
# magnetic_float_densimeter
# Cu2Fe1-xCoxSnS4
# pug
# thermoelectric_cooler
# broadening
# B2CuO4
# solidus_liquidus
# RedlichKister
# fermi_momentum
# P-C_isotherms
# 3-q
# 300-430
# arrhenius_relation
# +/-31
# Er-Sb
# d-stabilized
# DMET2I-3
# 2-110
# Al3Fe4Gd13
# classical_drude
# Co-Nd
# Ca2La7Mn10O30Sr
# kJ_molH
# FexSi1-x
# c-T
# Co2Nd
# DfHmo(298.15_K
# LaNiSn
# reverse_monte_carlo_RMC_simulations
# GYYZO
# rhoaT
# P4Tc
# g(r,t)
# van_hove_singularity
# pseudobinary_join
# resistivity_ρ
# rational_approximant
# systematic_errors
# I-M_transition

# %% [markdown]
# **Filter Metals, Properties, 3D_print**

# %%
# use_full_file_alloy = False

# use_full_file_thermal_properties = False
# use_full_file_mechanical_properties = False
# use_full_file_process_general = False
# use_full_file_process_melt_ded = False
# use_full_process_melt_general= False
# use_full_process_melt_pbf = False
# use_full_process_solid_binder = False
# use_full_process_solid_cold_spray = False
# use_full_process_solid_extrusion = False
# use_full_process_solid_field_assisted = False
# use_full_process_solid_friction_based = False
# use_full_process_solid_general = False


use_full_file_alloy = True
use_full_file_thermal_properties = True
use_full_file_mechanical_properties = True
use_full_file_process_general = True
use_full_file_process_melt_ded = True
use_full_process_melt_general= True
use_full_process_melt_pbf = True
use_full_process_solid_binder = True
use_full_process_solid_cold_spray = True
use_full_process_solid_extrusion = True
use_full_process_solid_field_assisted = True
use_full_process_solid_friction_based = True
use_full_process_solid_general = True

def read_keywords(file_paths, use_full):
    first_word_set = set()
    other_words_set = set() if use_full else None  # 仅当use_full为True时才初始化

    for file_path in file_paths:
        with open(file_path, 'r') as file:
            for line in file:
                words = line.strip().replace('$@$@$', '_').split()
                first_word_set.add(words[0])  # 总是添加第一个词
                if use_full and len(words) > 1:
                    # 如果use_full为True且存在除第一个词以外的其他词，则添加到other_words_set
                    other_words_set.update(words[1:])  # 添加除第一个词以外的所有词

    return (first_word_set, other_words_set) if use_full else first_word_set


# 使用新函数和独立的开关读取关键词列表
#processed_alloy_words = read_keywords('/home/etica/Project/alloy2vec/keywords/similar_alloy.txt', use_full_file_alloy)
#thermal_properties_words = read_keywords('/home/etica/Project/alloy2vec/keywords/similar_thermal_properties.txt', use_full_file_thermal_properties)
#mechanical_properties_words = read_keywords('/home/etica/Project/alloy2vec/keywords/similar_mechanical_properties.txt', use_full_file_mechanical_properties)

alloy_files = [
    '/home/etica/Project/alloy2vec/new_keyword/similar_AA_family_all.txt',
    '/home/etica/Project/alloy2vec/new_keyword/similar_alloy.txt'
]
alloy_words = read_keywords(alloy_files, use_full_file_alloy)

thermal_properties_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_thermal_properties.txt']
thermal_properties_words = read_keywords(thermal_properties_file, use_full_file_thermal_properties)

mechanical_properties_file = ['/home/etica/Project/alloy2vec/new_keyword/mechanical_properties.txt']
mechanical_properties_words = read_keywords(mechanical_properties_file, use_full_file_mechanical_properties)

#process words
process_general_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_general.txt']
process_general_words = read_keywords(process_general_file, use_full_file_process_general)

process_melt_ded_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_melt_ded.txt']
process_melt_ded_words = read_keywords(process_melt_ded_file, use_full_file_process_melt_ded)

process_melt_general_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_melt_general.txt']
process_melt_pbf_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_melt_pbf.txt']
process_solid_binder_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_solid_binder.txt']
process_solid_cold_spray_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_solid_cold_spray.txt']
process_solid_extrusion_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_solid_extrusion.txt']
process_solid_field_assisted_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_solid_field_assisted.txt']
process_solid_friction_based_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_solid_friction_based.txt']
process_solid_general_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_solid_general.txt']

process_melt_general_words = read_keywords(process_melt_general_file, use_full_process_melt_general)
process_melt_pbf_words = read_keywords(process_melt_pbf_file, use_full_process_melt_pbf)
process_solid_binder_words = read_keywords(process_solid_binder_file, use_full_process_solid_binder)
process_solid_cold_spray_words = read_keywords(process_solid_cold_spray_file, use_full_process_solid_cold_spray)
process_solid_extrusion_words = read_keywords(process_solid_extrusion_file, use_full_process_solid_extrusion)
process_solid_field_assisted_words = read_keywords(process_solid_field_assisted_file, use_full_process_solid_field_assisted)
process_solid_friction_based_words = read_keywords(process_solid_friction_based_file, use_full_process_solid_friction_based)
process_solid_general_words = read_keywords(process_solid_general_file, use_full_process_solid_general)



ELEMENTS = ["Li", "Be", "Na", "Mg", "Al", "K",
            "Ca", "Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga",
            "Rb", "Sr", "Y", "Zr", "Nb", "Mo", "Tc", "Ru", "Rh", "Pd", "Ag", "Cd", "In", "Sn", "Sb",
            "Cs", "Ba", "La", "Ce", "Pr", "Nd", "Pm", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb",
            "Lu", "Hf", "Ta", "W", "Re", "Os", "Ir", "Pt", "Au", "Hg", "Tl", "Pb", "Bi", "Po",
            "Ra", "Ac", "Th", "Pa", "U", "Np", "Pu", "Am", "Cm", "Bk", "Cf", "Es"]

ELEMENT_NAMES = ["Lithium", "Beryllium", "Sodium", "Magnesium", "Aluminium", "Potassium",
"Calcium", "Scandium", "Titanium", "Vanadium", "Chromium", "Manganese", "Iron", "Cobalt", "Nickel", "Copper", "Zinc", "Gallium",
"Rubidium", "Strontium", "Yttrium", "Zirconium", "Niobium", "Molybdenum", "Technetium", "Ruthenium", "Rhodium", "Palladium", "Silver", "Cadmium", "Indium", "Tin", "Antimony",
"Cesium", "Barium", "Lanthanum", "Cerium", "Praseodymium", "Neodymium", "Promethium", "Samarium", "Europium", "Gadolinium", "Terbium", "Dysprosium", "Holmium", "Erbium", "Thulium", "Ytterbium",
"Lutetium", "Hafnium", "Tantalum", "Tungsten", "Rhenium", "Osmium", "Iridium", "Platinum", "Gold", "Mercury", "Thallium", "Lead", "Bismuth", "Polonium",
"Radium", "Actinium", "Thorium", "Protactinium", "Uranium", "Neptunium", "Plutonium", "Americium", "Curium", "Berkelium", "Californium", "Einsteinium"]

#THREE_D_PROCESSING = ["3D_print", "3D_printing", "3D_printed", "3D_printing_technology", "3D-printed", "3D_printer", 
#              "three_dimensional_3D_printing", "3D_printing_3DP", "3D-printing", "3DGP","BJ3DP","3D_printers",
#              "3DP", "3-D_printing", "SLA-3D", "T3DP", "FDM_3D_printing", "three_dimensional_(3D)-printed", 
#              "3D-Printed", "3-D_printed", "3D_printable", "3D-plotted", "3D-printers", "3DPP", "3D_scanner", 
#              "3D_bioprinting", "i3DP", "3DTP", "3D", "three_dimensional_3D_printed", "3D_double-U", 
#              "3-D_printing_technology", "3Shape", "bio-printing", "3D-printable", "3DPMD", "three_dimensional_printing",
#              "three_dimensional", "threedimensional", "three_dimensionally", "3d"]

# Split the string into items by line
items = results_string.split("\n")

# Create empty lists to store filtered and unfiltered items
metal = []
thermal_property = []
mechanical_property = []
process_general = []
process_melt_ded = []
process_melt_general= []
process_melt_pbf = []
process_solid_binder = []
process_solid_cold_spray = []
process_solid_extrusion = []
process_solid_field_assisted = []
process_solid_friction_based = []
process_solid_general = []

unfiltered_item = []

#three_d_process_items = []

# Iterate through each item and add items that meet the criteria to the respective lists in their original order
for item in items:
    # Find the item and its similarity in model_results
    similarity = next((sim for word, sim in model_results if word == item), None)
    
    # Step 2: Keep items which contain elements (partial match)
    if any(element in item for element in ELEMENTS):
        metal.append((item, similarity))
    elif any(element in item for element in ELEMENT_NAMES):
        metal.append((item, similarity))
    # Step 3: Keep metal items that contain any word from alloy words (full match)
    elif item in alloy_words:
        metal.append((item, similarity))
    # Step 3: Keep metal items that contain both letters and digits （是否需要？）
    elif any(char.isalpha() for char in item) and any(char.isdigit() for char in item):
        metal.append((item, similarity))
    # Step 4: Keep metal items that contain "alloy"
    elif "alloy" in item:
        metal.append((item, similarity))
    elif "steel" in item:
        metal.append((item, similarity))
    
    #Step 1: Keep items that contain process keywords (partial or full match?)
    elif any(word in item for word in process_general_words):
        process_general.append((item, similarity))
    elif any(word in item for word in process_melt_ded_words):
        process_melt_ded.append((item, similarity))
    elif any(word in item for word in process_melt_general_words):
        process_melt_general.append((item, similarity))
    elif any(word in item for word in process_melt_pbf_words):
        process_melt_pbf.append((item, similarity))
    #elif any(word in item for word in process_solid_binder_words):
        #process_solid_binder.append((item, similarity))
    elif any(word in item for word in process_solid_cold_spray_words):
        process_solid_cold_spray.append((item, similarity))
    elif any(word in item for word in process_solid_extrusion_words):
        process_solid_extrusion.append((item, similarity))
    elif any(word in item for word in process_solid_field_assisted_words):
        process_solid_field_assisted.append((item, similarity))
    elif any(word in item for word in process_solid_friction_based_words):
        process_solid_friction_based.append((item, similarity))
    elif any(word in item for word in process_solid_general_words):
        process_solid_general.append((item, similarity))
    
    # elif item in process_general_words:
    #     process_general.append((item, similarity))
    # elif item in process_melt_ded_words:
    #     process_melt_ded.append((item, similarity))
    # elif item in process_melt_general_words:
    #     process_melt_general.append((item, similarity))
    # elif item in process_melt_pbf_words:
    #     process_melt_pbf.append((item, similarity))
    elif item in process_solid_binder_words:
        process_solid_binder.append((item, similarity))
    # elif item in process_solid_cold_spray_words:
    #     process_solid_cold_spray.append((item, similarity))
    # elif item in process_solid_extrusion_words:
    #     process_solid_extrusion.append((item, similarity))
    # elif item in process_solid_field_assisted_words:
    #     process_solid_field_assisted.append((item, similarity))
    # elif item in process_solid_friction_based_words:
    #     process_solid_friction_based.append((item, similarity))
    # elif item in process_solid_general_words:
    #     process_solid_general.append((item, similarity))

    
    # Step 5: Keep property items that contain properties keywords    
    # elif any(word in item for word in thermal_properties_words):
    #     thermal_property.append((item, similarity))
    # elif any(word in item for word in mechanical_properties_words):
    #     mechanical_property.append((item, similarity))
    elif item in mechanical_properties_words:
        mechanical_property.append((item, similarity))
    elif item in thermal_properties_words:
        thermal_property.append((item, similarity))


    # Step 7: unfiltered items
    else:
        unfiltered_item.append((item, similarity))
        
print("Thermal Properties Keywords:", thermal_properties_words)
#print("Mechanical Properties Keywords:", mechanical_properties_words)

# 输出分类结果
print("\nThermal Properties:")
for item, sim in thermal_property:
    print(f"{item}: {sim}")

print("\nMechanical Properties:")
for item, sim in mechanical_property:
    print(f"{item}: {sim}")

print("\nProcess general:")
for item, sim in process_general:
    print(f"{item}: {sim}")

print("\nProcess Melt General:")
for item, sim in process_melt_general:
    print(f"{item}: {sim}")

print("\nProcess Melt Ded:")
for item, sim in process_melt_ded:
    print(f"{item}: {sim}")

print("\nProcess Melt PBF:")
for item, sim in process_melt_pbf:
    print(f"{item}: {sim}")

print("\nProcess Solid General:")
for item, sim in process_solid_general:
    print(f"{item}: {sim}")

print("\nProcess Solid Binder:")
for item, sim in process_solid_binder:
    print(f"{item}: {sim}")

print("\nProcess Solid Cold Spray:")
for item, sim in process_solid_cold_spray:
    print(f"{item}: {sim}")

print("\nProcess Solid Extrusion:")
for item, sim in process_solid_extrusion:
    print(f"{item}: {sim}")

print("\nProcess Solid Field Assisted:")
for item, sim in process_solid_field_assisted:
    print(f"{item}: {sim}")

print("\nProcess Solid Friction Based:")
for item, sim in process_solid_friction_based:
    print(f"{item}: {sim}")

print("\nMetal:")
for item, sim in metal:
    print(f"{item}: {sim}")

print("\nNon-Filtered Items:")
for item, sim in unfiltered_item:
    print(f"{item}: {sim}")
# Out:
# Thermal Properties Keywords: {'glass_transition_temperature_tg', 'heat_losses', 'crater_depths', 'heat_sinks', 'thermal', 'ferroelectric', 'kirkendall', 'thermal_stresses', 'thermal_expansion', 'thermal_inertia', 'glass_transition', 'spectral_emissivity', 'heat_transfer', 'thermal_conductivities', 'emissivity', 'electrical', 'latent_heat_storage', 'temperature', 'stresses', 'heat_storage', 'waste_heat', 'thermal_decomposition', 'thermals', 'latent_heat', 'specific_heat', 'specific_heat_measurements', 'kirkendall_voids', 't-dec', 'stabilities', 'melting_temperatures', 'electrical_insulation', 'heat_reaction', 'ferroelectricity', 'PCM', 'thermodynamically_stable', 't-g', 'solidus_temperature', 'hollow', 'convective_heat_transfer', 'pyroelectric', 'flashpoint', 'biodiesel', 'kinematic_viscosity', 'excellent_thermal_shock_thermal', 'coefficient_of_thermal_utilization', 'thermal_admittance', 'emittance', 'thermal_decomposition_temperatures', 'thermal_expansion_coefficients', 'low_melting_point', 'melting_point', 'bulk_modulus', 'cSt', 'debye_temperatures', 'WC-10Ni-5Cr', 'heat_sink', 'thermal_conductance', 'spontaneous_polarization', 'effective_thermal_conductivity', 'glass_transition_temperature', 'heat_capacity', 'characteristics', 'thermal_decomposition_temperature', 'sensible_heat', 'thermodynamic_properties', 'heat_transfer_coefficients', 'stress', 'melting_temperature', 'thermal_shock_thermal', 'specific_heat_capacity', 'elastic_constant', 'nanoscale_kirkendall_effect', 'CNTOH', 'pyroelectricity', 'zirconia_toughened', 'thermal_insulation', 'thermal_shock_damage', 'W_mK', 'W_m-1_K-1', 'thermal_barrier_coatings', 'laser_flash_method', 'heat_capacities', 'effective_thermal_conductivity_ETC', 'heat_dissipation', 'gruneisen_parameter', 'effusivity', 'crater_depth', 'thermodynamic_stability', 'thermophysical_properties', 'thermal_shock_resistance', 'heat_insulation', 'heat_flux', 'liquidus_temperature', 'heat_penetration', 'phase_change_material_properties', 'expansion_coefficient', 'thermal_expansion_CTE', 'PCMs', 'metal_hydride_tank', 'heat_capacity_measurements', 'glass_transition_temperature_t-g', 'normal_spectral_emissivity', 'vapor_pressures', 'thermal_effusivity', 'thermoreflectance', 'vaporization', 'radiative_conductivity', 'thermal_cycling_resistance', 'heat_transfer_coefficient', 'heat', 'heat_fluxes', 'thermal_shocks', 'thermodynamic_stabilities', 'penetration_depth', 'boiling_point', 'emissivities', 'electronic_specific_heat', 'kirkendall_effect', 'natural_convection', 'elastic_constants', 'thermal_diffusivity', 'absorptivity', 'ammonium_perchlorate_AP', 'pour_point', 'convective_heat_transfer_coefficient', 'thermal_conductivity', 'hollow_nanostructures', 'debye_temperature', 'thermodynamically', 'phonon_transport', 'heat_conduction', 'thermal_expansion_coefficient', 'flash_point', 'thermal_stress', 'glass_transition_temperatures', 'thermal_shock', 'Wm-1K-1', 'ablation_resistance', 'CTE', 'melting_points', 'thermal_boundary_conductance', 'boiling_points', 'latent_heats', 'ferroelectrics', 'thermal_management', 'building_temperature', 'open_cell', 'vapor_pressure', 'insulation', 'interfacial_thermal_conductance', 'photopyroelectric'}
#
# Thermal Properties:
# specific_heat: 0.9218029379844666
# heat_capacities: 0.8387543559074402
# heat_capacity_measurements: 0.8150315284729004
# gruneisen_parameter: 0.7915974855422974
# debye_temperature: 0.7833778858184814
# electronic_specific_heat: 0.7462236285209656
# specific_heat_measurements: 0.7459147572517395
# debye_temperatures: 0.7457664608955383
# thermal_diffusivity: 0.7172986268997192
# thermophysical_properties: 0.6869237422943115
# elastic_constants: 0.6376450061798096
# thermal_conductivities: 0.6245148777961731
# laser_flash_method: 0.603339433670044
# elastic_constant: 0.5995908975601196
# thermal_expansion_coefficients: 0.5766600370407104
# latent_heat: 0.5764042139053345
# thermal_conductance: 0.5307801365852356
# expansion_coefficient: 0.5299129486083984
# vapor_pressure: 0.5286393165588379
# normal_spectral_emissivity: 0.5203152298927307
# latent_heats: 0.5149549245834351
# vapor_pressures: 0.48848795890808105
# liquidus_temperature: 0.4877909719944
# temperature: 0.48507994413375854
# glass_transition: 0.4847276508808136
# thermoreflectance: 0.46924200654029846
# heat_conduction: 0.4689489006996155
# emissivities: 0.4561552405357361
# emissivity: 0.4508139491081238
# heat_transfer_coefficient: 0.44553911685943604
# thermodynamic_stability: 0.44149941205978394
# thermal: 0.4394482374191284
# kinematic_viscosity: 0.4371999502182007
# photopyroelectric: 0.4364132583141327
# effective_thermal_conductivity: 0.4353655278682709
# glass_transition_temperature: 0.434986412525177
# vaporization: 0.4287235140800476
# spectral_emissivity: 0.4278009533882141
# effusivity: 0.42625877261161804
# glass_transition_temperature_t-g: 0.42214134335517883
# t-g: 0.42190390825271606
# phonon_transport: 0.4218387007713318
# heat_flux: 0.41938477754592896
# heat: 0.4168230891227722
# boiling_point: 0.41569003462791443
# solidus_temperature: 0.41112858057022095
# convective_heat_transfer_coefficient: 0.4098314642906189
# thermal_inertia: 0.4028468132019043
# heat_losses: 0.4016380310058594
# heat_fluxes: 0.39831990003585815
#
# Mechanical Properties:
# specific_heat_capacity: 0.8190459609031677
# thermal_expansion_coefficient: 0.7046962380409241
# thermal_conductivity: 0.6763865947723389
# bulk_modulus: 0.6386549472808838
# shear_modulus: 0.5692576169967651
# pressure: 0.498588502407074
# moduli: 0.4421130418777466
# elasticity: 0.40787220001220703
# vickers_hardness: 0.40590643882751465
# brittleness: 0.3987768888473511
#
# Process general:
#
# Process Melt General:
# melt_solution_calorimetry: 0.49971356987953186
# melts: 0.4342834949493408
# undercooled_melts: 0.42637673020362854
# t-melt: 0.4256364405155182
# melts_congruently: 0.42232444882392883
# melts_incongruently: 0.40689408779144287
#
# Process Melt Ded:
#
# Process Melt PBF:
#
# Process Solid General:
#
# Process Solid Binder:
#
# Process Solid Cold Spray:
#
# Process Solid Extrusion:
#
# Process Solid Field Assisted:
# electrostatic_levitation_furnace: 0.4682687222957611
#
# Process Solid Friction Based:
# internal_friction: 0.49744996428489685
# internal_frictions: 0.47518813610076904
# internal_friction_peak: 0.4355948269367218
#
# Metal:
# thermal_expansion: 0.721187174320221
# C-pT: 0.7015161514282227
# ThetaD: 0.6864481568336487
# debye_temperature_ThetaD: 0.6806776523590088
# specific_heat_C-pT: 0.670991063117981
# mJ_K-2_mol-1: 0.6684605479240417
# heat_capacity_C-V: 0.6618505120277405
# mJ_mol_K-2: 0.6543734073638916
# heat_capacity_C-pT: 0.6520634293556213
# mJ_K-2_mol: 0.651860237121582
# C-PT: 0.6518446207046509
# c-pm0: 0.6509549021720886
# specific_heat_CT: 0.6451929807662964
# THETA-0: 0.643448531627655
# mJ_mol-1_K-2: 0.6397107243537903
# PbPd2Yb: 0.6396400332450867
# LuSi: 0.6392728090286255
# CGaNb2: 0.6377695202827454
# C-pAp: 0.6376787424087524
# CGaTa2: 0.635046660900116
# Ce1-xLaxCu4Al: 0.6349700093269348
# thermoelectric_power_S: 0.6345808506011963
# AgCeSn: 0.6335644125938416
# 2-300_K: 0.6329217553138733
# C-eT: 0.6320558786392212
# thermoelectric_power_ST: 0.6283745765686035
# Co2EuP2: 0.6274473667144775
# HoO4V: 0.6271455883979797
# thermopower_ST: 0.624109148979187
# Gd4Mg21Zn25: 0.6209513545036316
# thermopower_S: 0.6205933690071106
# phonon_DOS: 0.619615912437439
# PbPd2Y: 0.6154968738555908
# thermoelectric_power_TEP: 0.6145356297492981
# mK: 0.614499032497406
# 273-363: 0.40044569969177246
# antiferromagnetic_kondo: 0.40044474601745605
# excitation_spectra: 0.40043705701828003
# laser_flash_apparatus: 0.40043485164642334
# thermo_electromotive_force: 0.40042978525161743
# omegaL: 0.40042346715927124
# three-omega: 0.4004174768924713
# drude_contribution: 0.4004140794277191
# heat_convection: 0.40041401982307434
# liquid: 0.40041401982307434
# gaussian_approximation: 0.4004133641719818
# grover: 0.4003967046737671
# tetragonal: 0.40038180351257324
# pulsed_magnetic_field: 0.40038174390792847
# t-cm: 0.40037453174591064
# MEAM_potentials: 0.4003724157810211
# aptekar: 0.400360107421875
# u-parameter: 0.40035173296928406
# volume_piezometer: 0.40033265948295593
# paramagnons: 0.4003005027770996
# solubility_limit: 0.4002973139286041
# t-t'-J_model: 0.40028977394104004
# phonon_group_velocities: 0.400271475315094
# sigma_tau: 0.4002665877342224
# strongly_correlated_fermi: 0.40026146173477173
# optical_pyrometry: 0.4002590477466583
# b-c_plane: 0.4002336263656616
# interconfiguration: 0.4001919627189636
# mJ: 0.4001721441745758
# 870-970: 0.40016278624534607
# antiferromagnetic_exchange_interactions: 0.4001579284667969
# fixed_spin_moment: 0.40010717511177063
# binary_phase_diagram: 0.4000972509384155
# entropy_term: 0.4000961482524872
# s-wave_superconductivity: 0.4000849723815918
# tetrahedrally_bonded_semiconductors: 0.4000633955001831
# tunneling_spectroscopy: 0.4000617265701294
# pyrochlore_iridate: 0.40003204345703125
# J_kg: 0.4000280201435089
# just_above: 0.40002742409706116
# endothermic_peak: 0.40000560879707336
# fullerite: 0.3999907374382019
# entropically_stabilized: 0.3999823033809662
# bethe_ansatz: 0.3999696373939514
# thermoanalysis: 0.39996394515037537
# thermoremanent: 0.3999391198158264
# mucal: 0.39993178844451904
# apparent_molar_compressibility: 0.3999004662036896
# ab_initio_simulations: 0.39987343549728394
# quantum_monte_carlo_simulations: 0.39987075328826904
# time_differential_perturbed_angular_correlation: 0.39984557032585144
# coulomb_correlation: 0.39984387159347534
# peltier_effect: 0.39982324838638306
# suppression_of_spin_fluctuations: 0.39979127049446106
# supercooled_liquid_region_DeltaTx: 0.3997596204280853
# meta-stability: 0.3997379243373871
# stopping_power: 0.399734765291214
# subsecond: 0.39972901344299316
# semiempirical: 0.3997144401073456
# mott_hubbard_transition: 0.399713933467865
# speromagnetic: 0.3997058868408203
# special_quasi-random_structures: 0.39970582723617554
# biquadratic_exchange: 0.3997029662132263
# under_nonhydrostatic_compression: 0.3996972441673279
# mean_free_path: 0.399684876203537
# calorlmetry: 0.39967405796051025
# previous_assessments: 0.3996625244617462
# quasi-crystals: 0.3996366262435913
# t-square: 0.3996317386627197
# normal_state: 0.3996236026287079
# ab_initio_molecular_dynamics_simulation: 0.39962130784988403
# ground_state_doublet: 0.39961421489715576
# body-centered-cubic: 0.3995763063430786
# ijk: 0.39957594871520996
# aerodynamic_levitation: 0.39956343173980713
# near_half_filling: 0.3995051980018616
# Gibbs-Di: 0.39950430393218994
# lanthanide_orthophosphates: 0.3994567096233368
# avrami_exponent_n: 0.3994543254375458
# spontaneous_magnetizations: 0.399446040391922
# invars: 0.39943817257881165
# virial_theorem: 0.39938607811927795
# crystallize_in_the_hexagonal: 0.3993750512599945
# j*g: 0.39935195446014404
# laser_heated_diamond_anvil_cells: 0.3993211090564728
# ferromagnetic_exchange_interaction: 0.39931243658065796
# gibbs_duhem_relation: 0.399308443069458
# coherence_length: 0.39927372336387634
# cmma: 0.39925581216812134
# nonstoichiometric: 0.39922213554382324
# reciprocal_space: 0.39921626448631287
# ab_initio_lattice_dynamical: 0.39919722080230713
# dielectric_function_epsilonomega: 0.39917290210723877
# bulk_moduli_shear_moduli: 0.3991287648677826
# clarke_glew: 0.39907753467559814
# s-electron: 0.39907631278038025
# magneto_structural: 0.3990649878978729
# de_gennes_scaling: 0.3990527093410492
# carrier_density: 0.3990482985973358
# stevels: 0.39902567863464355
# scattering_vector: 0.3990227282047272
# chiparallel: 0.3990006148815155
# csat: 0.39899685978889465
# formula_unit: 0.398975670337677
# kelvins: 0.3989722728729248
# mean-square-amplitude: 0.3989544212818146
# p-pc: 0.39895033836364746
# hirai: 0.39890649914741516
# m-spin: 0.3988986015319824
# onsite_coulomb_interaction: 0.3988848030567169
# sharp_cusp: 0.39888057112693787
# 10-310: 0.39887282252311707
# degreesf: 0.3988456726074219
# positive_magnetoconductance: 0.39881834387779236
# pseudo-binary_system: 0.3988143503665924
# cumulant: 0.39880701899528503
# gap-wise: 0.39876872301101685
# 1673-1873: 0.39876359701156616
# ginzburg_landau: 0.39876314997673035
# monodeuteride: 0.39876288175582886
# TDTR: 0.3987499177455902
# T)r: 0.3987424075603485
# s-f_exchange: 0.39871859550476074
# alpha-transition: 0.3987075090408325
# rule_of_additivity: 0.39867016673088074
# plane_wave_pseudo-potential: 0.3986682593822479
# fxc: 0.3986389935016632
# mu_eff: 0.39863693714141846
# absolute_seebeck: 0.39863643050193787
# dr_ρ: 0.3986165523529053
# knudsen_effusion_mass_spectrometry: 0.3985797166824341
# downward_shift: 0.3985697627067566
# DeltaM: 0.3985651731491089
# quasicrystalline_phases: 0.3985599875450134
# aT+b: 0.39855995774269104
# curie_–_weiss_law: 0.398542582988739
# partial_molal_volumes: 0.39851871132850647
# -/+delta: 0.39848071336746216
# magneto_elastic: 0.3984709680080414
# gammacb: 0.39846187829971313
# renormalisation: 0.39843127131462097
# DeltaTx: 0.39841529726982117
# anderson_localization: 0.3984002470970154
# sub-regular_solution_model: 0.3983880281448364
# photoionization_cross_sections: 0.39838069677352905
# efg: 0.39834147691726685
# semi-classic: 0.39833864569664
# debye_–_callaway: 0.3983379006385803
# phonon_roton: 0.3983153700828552
# just_above_tg: 0.3983117640018463
# fitted_to_a_redlich: 0.39830639958381653
# hysteresis_loss: 0.3982555866241455
# negative_deviations_from_the_ideal: 0.3982416093349457
# supercooled_liquid_region_DTx: 0.39822715520858765
# susceptibilities: 0.39820411801338196
# gibbs_free_energy_DG: 0.39820000529289246
# 0-108: 0.39814016222953796
# exchange_couplings: 0.39811497926712036
# jex: 0.3981085419654846
# T_almost-equal-to: 0.39808282256126404
# cubic_symmetry: 0.3980647921562195
# invariant_reactions: 0.3980642557144165
# epsilonlambdasolid: 0.39804622530937195
# sn-flux: 0.3979929983615875
# 298-500: 0.39798614382743835
# drag_coefficient: 0.39796605706214905
# brillouin_zone: 0.3979656398296356
# bond_ionicity_lattice: 0.39795637130737305
# electronically_driven: 0.39795005321502686
# non-collinear: 0.39793625473976135
# magnetization-: 0.39791491627693176
# inelastic: 0.3979108929634094
# range_hopping: 0.397910475730896
# augumented: 0.3978992998600006
# atomic_mobilities: 0.3978942334651947
# tracer_diffusivities: 0.39789173007011414
# intermetallic_clathrates: 0.3978831470012665
# va_n't_hoff_plot: 0.39785224199295044
# impurity: 0.3978407084941864
# curie_constants: 0.3978158235549927
# minority_spins: 0.3978003263473511
# h-c: 0.3978000283241272
# t-cr: 0.3977964520454407
# anderson_localized: 0.3977853059768677
# ab_initio_plane_wave: 0.3977729082107544
# self_consistent_spin_polarized: 0.39777275919914246
# polaron: 0.39775124192237854
# heavy-rare-earth: 0.39774587750434875
# kissinger_method: 0.39773717522621155
# critical_exponents_β_γ: 0.3977101445198059
# alpha-relaxation: 0.39769622683525085
# gmo: 0.39768141508102417
# similar_or_equal: 0.3976457715034485
# adjustable_parameters: 0.39763686060905457
# rosenfeld: 0.39763450622558594
# torque_magnetometer: 0.39762866497039795
# ofthermal: 0.39762839674949646
# tco: 0.39758962392807007
# isothermal_annealing: 0.3975543677806854
# r-T: 0.3975442349910736
# far_infrared_reflection_spectra: 0.3975317180156708
# incompressibility: 0.3975284695625305
# electromagnetic_levitator: 0.3974928855895996
# vicinity_of_the_fermi_level: 0.3974757194519043
# chalcogenide_superconductors: 0.3974725604057312
# magnetocrystalline_anisotropies: 0.3974687457084656
# 298-1173: 0.39744240045547485
# radial_distribution_functions: 0.3974178731441498
# scaling: 0.3974115252494812
# asphericity: 0.39739078283309937
# kT(T): 0.39737746119499207
# narrow_gap_semiconductors: 0.39737480878829956
# m-s: 0.39735695719718933
# relaxation_time_τ: 0.39733970165252686
# skew_scattering: 0.39733609557151794
# below_tf: 0.39731812477111816
# isotropic-smectic-A: 0.39730730652809143
# asperomagnetic: 0.3973052203655243
# M-T_curve: 0.3973027169704437
# vertical_bar_delta: 0.3972952663898468
# peng_robinson_equation: 0.3972935378551483
# merit: 0.39728403091430664
# sub-binary_systems: 0.39726775884628296
# hexachloroelpasolite: 0.3972553610801697
# fee: 0.39723607897758484
# boiling_point_elevation: 0.39721742272377014
# phonon_coupling_parameter: 0.3972168564796448
# x(y): 0.39721202850341797
# bogoliubov_inequality: 0.3972102701663971
# fluorite-pyrochlore: 0.3972068428993225
# 0*027: 0.39718130230903625
# mott_hubbard_gap: 0.3971572518348694
# nonquasiparticle: 0.3971533179283142
# msand: 0.39715081453323364
# 300-870: 0.3971503973007202
# nanothermodynamic: 0.3971370458602905
# T-: 0.3970794677734375
# weak_antiferromagnetic_exchange_coupling: 0.3970318138599396
# high-spin-low-spin: 0.3960423767566681
# paris_edinburgh: 0.3960384726524353
# dkh: 0.39603349566459656
# electronic-: 0.39602723717689514
# jumpwise: 0.39601898193359375
# ultralow_thermal_conductivity: 0.39601781964302063
# extended_miedema_model: 0.3960173428058624
# synchrotron_x-ray_diffraction_measurements: 0.39600884914398193
# magnetic_float_densimeter: 0.3959908187389374
# pug: 0.3959897458553314
# thermoelectric_cooler: 0.39598187804222107
# broadening: 0.39597994089126587
# solidus_liquidus: 0.39596784114837646
# fermi_momentum: 0.39595654606819153
# 300-430: 0.3959415555000305
# arrhenius_relation: 0.3959338366985321
# +/-31: 0.3959328830242157
# d-stabilized: 0.39591726660728455
# 2-110: 0.3959065079689026
# classical_drude: 0.3958890736103058
# c-T: 0.39586156606674194
# rhoaT: 0.3958142101764679
# g(r,t): 0.39580056071281433
# van_hove_singularity: 0.3957968056201935
# pseudobinary_join: 0.39579638838768005
# resistivity_ρ: 0.3957963287830353
# rational_approximant: 0.39579322934150696
# systematic_errors: 0.3957887887954712

# %% [markdown]
# **

# %%
context_words_list = ['high','ultimate_tensile_strength']
topn = 1000
predicted_words = w2v_model.predict_output_word(context_words_list, topn=topn)
print(predicted_words)
# Out:
# [('MPa_UTS', 0.0018726196), ('ultimate_tensile_strength', 0.0011191847), ('elongation_EL', 0.0010844474), ('elongation', 0.00089310046), ('MPa', 0.00087718235), ('yield_strength_tensile_strength', 0.0008431511), ('tensile_strength_yield_strength', 0.0007401115), ('ultimate_tensile_strength_UTS', 0.00073574984), ('YS', 0.00070960674), ('UTS', 0.0007061203), ('yield_strength_YS', 0.0005908911), ('tensile_yield_strength', 0.00055149593), ('yield_strength', 0.00055137515), ('ultimate_tensile_strength_UTS_yield_strength', 0.00050492055), ('tensile_strength', 0.00040299515), ('ductility_balance', 0.0003955146), ('uniform_elongation', 0.00038714602), ('elongation_el', 0.00037860268), ('ductility', 0.00037123333), ('sigmaYS', 0.00036402902), ('TYS', 0.0003471223), ('yield_strength_ultimate_tensile_strength', 0.00033446585), ('sigmaUTS', 0.00032300717), ('international_annealed', 0.0003079983), ('elongation_TE', 0.00030528655), ('copper_standard_IACS', 0.0003015099), ('yield_strength_YS_ultimate_tensile_strength', 0.0003002125), ('impact_toughness', 0.00029827165), ('ultimate_tensile_strength_yield_strength', 0.00029758678), ('ultimate_tensile_strengths', 0.00029701425), ('UTS_ultimate_tensile_strength', 0.00028407562), ('ultimate_tensile_stress', 0.0002832071), ('yield_strength_sigma02', 0.00027886825), ('strength_YS', 0.0002689031), ('ultimate_tensile_strength_sigmaUTS', 0.00025999904), ('compressive_yield_strength_CYS', 0.0002542336), ('tensile_strength_sigmab', 0.00025004378), ('UTS_YS', 0.00024935065), ('YS_UTS', 0.00024605857), ('strength_ductility_synergy', 0.00024569873), ('compressive_yield_strength', 0.00023770992), ('epsilonf', 0.00023330723), ('sigmau', 0.0002266365), ('elongation_PSE', 0.00022599428), ('tensile_elongation', 0.00022194574), ('ultimate_tensile_strengths_UTS', 0.0002153528), ('sigmab', 0.0002114083), ('elon_gation', 0.00021057803), ('tensile_ductility', 0.00020473704), ('nano-sized_CTi_particles', 0.00020465085), ('ductility_synergy', 0.00020431115), ('compressive_yield_strengths', 0.00020232845), ('center_dot_m1', 0.00019637194), ('strength_sigma02', 0.0001957828), ('TYS_ultimate_tensile_strength', 0.00019427763), ('ultimate_strength_UTS', 0.00018641092), ('ultimate_compressive_stress', 0.00018584947), ('uniform_elongation_UE', 0.00018439366), ('charpy_v-notch_impact_energy', 0.00018413448), ('4TiC_5AlN', 0.00017861366), ('N_mm2', 0.00017751123), ('sigmay', 0.00017596393), ('ultimate_compressive_strength', 0.00017121024), ('room_temperature_RT', 0.0001705715), ('sigma02', 0.00017030383), ('HEAp_AMCs', 0.00016700957), ('ultimate_compression', 0.00016598006), ('as-extruded_alloy_exhibits', 0.0001641376), ('yield_strength_sigmay', 0.000164072), ('r-m', 0.00016023236), ('peak_aged', 0.00015894554), ('pct', 0.0001582004), ('yield_strengths', 0.00015779493), ('Ti-30Mo-05TiC', 0.00015344375), ('Mg-1Mn', 0.00015068136), ('yield_strength_ultimate_strength', 0.00014996582), ('Cu-20Ni-20Mn-03Nb-03Cr-01Zr', 0.00014971459), ('ultimate_tensile', 0.0001487724), ('hardness', 0.00014754872), ('ATZ731', 0.00014730377), ('EK30-20Ag', 0.00014729885), ('strength_-ductility', 0.00014727065), ('Al-Cu-Mg-Si', 0.00014702418), ('CoCrNi_MEA_DED', 0.00014634758), ('ultimate_tensile_strength_sigmab', 0.00014530351), ('K-JIc', 0.00014409152), ('precipitation_strengthening', 0.00014388724), ('W-05_wt_CTa', 0.00014277436), ('MSm-1', 0.000141981), ('HV', 0.00014130503), ('sigmaf', 0.0001412172), ('mm_min', 0.00013951195), ('strengthUTS', 0.0001386843), ('fracture_toughness_K-Q', 0.00013809325), ('tensile_strengths', 0.00013786931), ('Mg-05Gd-xMn', 0.00013668882), ('XMNdAZ', 0.00013608497), ('yield_asymmetry', 0.00013603533), ('index_erichsen_value', 0.00013582395), ('cryogenic_impact_toughness', 0.00013580975), ('AlMg25Si35', 0.00013491462), ('ultimate_strength', 0.00013421556), ('Al-10Ce', 0.00013407276), ('thixoformed-T6', 0.0001340086), ('ZTM641-02Ca-2Al', 0.00013394153), ('bimodal_grain_structure', 0.00013361257), ('post-HPT_annealing', ...

# %% [markdown]
# **Input: PROCESS**
# **Output: Metals**

# %%
use_full_file_alloy = True
use_full_file_thermal_properties = True
use_full_file_mechanical_properties = True
use_full_file_process_general = True
use_full_file_process_melt_ded = True
use_full_process_melt_general= True
use_full_process_melt_pbf = True
use_full_process_solid_binder = True
use_full_process_solid_cold_spray = True
use_full_process_solid_extrusion = True
use_full_process_solid_field_assisted = True
use_full_process_solid_friction_based = True
use_full_process_solid_general = True


process_item_example = "annealing"

similar_words = w2v_model.wv.most_similar(process_item_example, topn=500)

metal = []
unfiltered_item = []
temperature = []
atmosphere = []

# Filter similar words
for item, similarity in similar_words:
    if "degree" in item and "C" in item:
        # If both 'degree' and 'C' are in the item, classify it as temperature
        temperature.append((item, similarity))
    elif "atmospher" in item:
        # If 'atmospher' are in the item, classify it as atmosphere
        atmosphere.append((item, similarity))
    elif any(element in item for element in ELEMENTS):
        metal.append((item, similarity))
    elif any(element in item for element in ELEMENT_NAMES):
        metal.append((item, similarity))
    elif item in alloy_words:
        metal.append((item, similarity))
    elif any(char.isalpha() for char in item) and any(char.isdigit() for char in item):
        metal.append((item, similarity))
    elif "alloy" in item:
        metal.append((item, similarity))
    elif "steel" in item:
        metal.append((item, similarity))
    else:
        unfiltered_item.append((item, similarity))


print("Metals:")
for item, sim in metal:
    print(f"{item}: {sim}")

print("\nTemperature:")
for item, sim in temperature:
    print(f"{item}: {sim}")

print("\nAtmosphere:")
for item, sim in atmosphere:
    print(f"{item}: {sim}")
# Out:
# Metals:
# cold_rolling: 0.701994776725769
# N-2_ambient: 0.6836350560188293
# heat_treating: 0.6685843467712402
# pt]18: 0.6078654527664185
# heating: 0.5929631590843201
# CexAlyOz: 0.5876709818840027
# DEGC: 0.58498615026474
# post-dealloying: 0.5806818604469299
# CoCrFeNiZr: 0.5799477100372314
# Fe-Hf-N: 0.5782273411750793
# cryoECAPed: 0.5739969611167908
# BCoFeZr: 0.5730574131011963
# thermal_processing_RTP: 0.5688943862915039
# beta-FeSi2_precipitates: 0.5686500072479248
# B6CuFe86Zr7: 0.5664728283882141
# alpha-Fe_nanocrystals: 0.566301167011261
# post-deposition_annealing_PDA: 0.5651348233222961
# post-deformation_annealing_PDA: 0.5649203062057495
# GaIn2O-3: 0.5637692809104919
# Post-Deformation: 0.5634335279464722
# HPTD: 0.5621023178100586
# L10_ordering: 0.5605828762054443
# MwPA: 0.5602442622184753
# Fe51Pt49: 0.5578996539115906
# MZTO: 0.556723952293396
# Co16Fe15W19: 0.5552180409431458
# InOA: 0.5539861917495728
# Fe-6Si: 0.5536763072013855
# alpha-Fe: 0.5524082183837891
# FeNi23B-6: 0.5516443848609924
# NKBT-Mn: 0.5515457987785339
# Al6Ni19: 0.5515311360359192
# alloy: 0.55138099193573
# B6Co486CuFe6Hf7: 0.5511702299118042
# Mg4OZn6: 0.5507906675338745
# B5CuFe745Nb2Si175: 0.5499793887138367
# Co61Si9Sm: 0.5485319495201111
# after_HPT_processing: 0.5481329560279846
# Cu-Mn-Dy: 0.54727703332901
# URA: 0.5464662313461304
# BFe8Zr: 0.5440389513969421
# muOmega-cm: 0.5427591800689697
# InMnPZn: 0.5418804287910461
# upon_heating: 0.5411543250083923
# Pr-Co: 0.540966272354126
# FARTA: 0.5408454537391663
# Ti-Nb-Ni: 0.5407049655914307
# Hf-Ti-O: 0.5381675362586975
# alpha-FeSi: 0.5377861857414246
# K: 0.5377185344696045
# reheating: 0.5377071499824524
# W-N-Ni: 0.5376391410827637
# Fe-Pt-B: 0.5375518798828125
# x_10-3_Pa: 0.5370640754699707
# HPT_processing: 0.5368231534957886
# fcc-Zr2Cu: 0.5352887511253357
# Ar_ion_beam: 0.5351680517196655
# 650degreesC: 0.5803679823875427
# 900-degrees-C: 0.5772864818572998
# 340-degrees-C: 0.5761821866035461
# 400-600_degrees_C: 0.572433590888977
# 550-degrees-C: 0.5700477957725525
# 700-degrees-C: 0.5700245499610901
# 750degreesC: 0.5616253614425659
# 400-500_degrees_C: 0.5614994168281555
# 800-1100degreesC: 0.5594322085380554
# 200-500_degrees_C: 0.5585361123085022
# 300-degrees-C: 0.5552432537078857
# 1000degreesC: 0.5549848675727844
# 300-400_degrees_C: 0.5546146631240845
# 550degreesC: 0.5530559420585632
# 500-700_degreesC: 0.5509172081947327
# 400-700_degrees_C: 0.5476189255714417
# 300-400-degrees-C: 0.5465517640113831
# degrees_C-100: 0.5460964441299438
# 900-1000_degrees_C: 0.54522705078125
# 1050-degrees-C: 0.5449961423873901
# 300-700_degrees_C: 0.5446686148643494
# 500-550degreesC: 0.5440605282783508
# 500-1000_degrees_C: 0.5414634943008423
# 600-900_degrees_C: 0.5407015681266785
# 200-300_degrees_C: 0.540109395980835
# 850degreesC: 0.5391929149627686
# 600-700_degrees_C: 0.5390122532844543
# 400-800_degrees_C: 0.5353847146034241
# 350-degrees-C: 0.5344303846359253
# 950-degrees-C: 0.5335155725479126
# 950degreesC: 0.5332947969436646
# 500-800_degrees_C: 0.53227698802948
# degrees_C-600_degrees_C: 0.5266809463500977
# 200-400_degreesC: 0.5263174176216125
# 620-degrees-C: 0.5246910452842712
# 525-degrees-C: 0.5242112874984741
# 700-800_degrees_C: 0.5240212082862854
#
# Atmosphere:
# Ar_atmosphere: 0.6543598175048828
# H-2_atmosphere: 0.6372252106666565
# argon_atmosphere: 0.6185950040817261
# nitrogen_atmosphere: 0.6078190803527832
# N-2_atmosphere: 0.6042876839637756
# ambient_atmosphere: 0.5805414319038391
# O-2_atmosphere: 0.5780662894248962
# reducing_atmosphere: 0.5719071626663208
# an_inert_atmosphere: 0.571614682674408
# under_Ar_atmosphere: 0.5601873993873596
# an_argon_atmosphere: 0.5574331283569336
# air_atmosphere: 0.5560545921325684
# inert_atmosphere: 0.5452414751052856
# N-2-H-2_atmosphere: 0.5206025838851929

# %% [markdown]
# **Input: PROPERTIES**
# **Output: Metals**

# %%
use_full_file_alloy = True
use_full_file_thermal_properties = True
use_full_file_mechanical_properties = True
use_full_file_process_general = True
use_full_file_process_melt_ded = True
use_full_process_melt_general= True
use_full_process_melt_pbf = True
use_full_process_solid_binder = True
use_full_process_solid_cold_spray = True
use_full_process_solid_extrusion = True
use_full_process_solid_field_assisted = True
use_full_process_solid_friction_based = True
use_full_process_solid_general = True

properties_item_example = "elongation"

similar_words = w2v_model.wv.most_similar(properties_item_example,topn=500)

thermal_property = []
mechanical_property = []
metal = []
unfiltered_item = []
no_metal_terms = ['UTS', 'YS', 'MPa', 'TYS', 'CUTS', 'sigmaYS', 'sigma02', 'sigmaUTS', 'rp02', 'YTS']

# Filter similar words
for item, similarity in similar_words:
    if any(word in item for word in no_metal_terms):
        continue
    elif any(word in item for word in thermal_properties_words):
       thermal_property.append((item, similarity))
    # elif any(word in item for word in mechanical_properties_words):
    #     mechanical_property.append((item, similarity))
    # elif item in thermal_properties_words:
    #     thermal_property.append((item, similarity))
    elif item in mechanical_properties_words:
        mechanical_property.append((item, similarity))
    elif any(element in item for element in ELEMENTS):
        metal.append((item, similarity))
    elif any(element in item for element in ELEMENT_NAMES):
        metal.append((item, similarity))
    elif item in alloy_words:
        metal.append((item, similarity))
   # elif any(char.isalpha() for char in item) and any(char.isdigit() for char in item):
        #metal.append((item, similarity))
    elif "alloy" in item:
        metal.append((item, similarity))
    elif "steel" in item:
        metal.append((item, similarity))
    else:
        unfiltered_item.append((item, similarity))


print("Metals:")
for item, sim in metal:
    print(f"{item}: {sim}")

print("\nThermal Properties:")
for item, sim in thermal_property:
    print(f"{item}: {sim}")

print("\nMechanical Properties:")
for item, sim in mechanical_property:
    print(f"{item}: {sim}")

print("\nNon-Filtered Items:")
for item, sim in unfiltered_item:
    print(f"{item}: {sim}")
# Out:
# Metals:
# ultimate_compressive_strength_UCS: 0.6966140270233154
# uniform_elongation_UE: 0.6950035095214844
# Mg-4Zn-05Sr-05Ag: 0.6776790022850037
# tensile_testing: 0.6661475300788879
# AZ31-10Ca-02Ce: 0.6554461717605591
# IACS: 0.6459885239601135
# HV: 0.6454230546951294
# as-extruded_alloy: 0.636986255645752
# tensile_strength_TS: 0.6367088556289673
# BHN: 0.6291600465774536
# N_mm2: 0.62687748670578
# as-cast_alloy: 0.6262640953063965
# T6_treatment: 0.6236147284507751
# WZY: 0.6204185485839844
# IACS_respectively: 0.618232011795044
# KJ_m2: 0.6179448366165161
# Al-Cu-Li-Mn: 0.6166607141494751
# Mg-6Al-2Nd-xCa: 0.6121400594711304
# sigmaY: 0.6117584705352783
# HV10: 0.6102496385574341
# WE43-A-6P: 0.607664942741394
# SPS-65W-25Cu-10Ni: 0.6075676083564758
# Mg-3A1-1Zn: 0.604671061038971
# MgAlB4w: 0.6046459078788757
# peak_aged: 0.6026621460914612
# Mg-12Gd-3Y-05Zr: 0.6020092368125916
# 7055-Y-Sc: 0.6006527543067932
# ZM-035Li: 0.5961634516716003
# Mg-6Al-2Ca-2Sm: 0.5960304737091064
# AZ91-15Si-04Ca: 0.5955212116241455
# HVDC-AE44-2: 0.5927129983901978
# Al-49Zn: 0.5910819172859192
# ECAP_passes: 0.5896540284156799
# Mg-6Al-6Nd: 0.5892782807350159
# Mg-7Sn-2Al: 0.5850840210914612
# ECAPed: 0.5834423303604126
# B400H: 0.582145094871521
# Ti-Al-V-Mo-Zr: 0.5817149877548218
# Ti-465Al-2Cr-2Nb-025Nd: 0.5798471570014954
# Mg-4Sn-2Al: 0.5798026919364929
# sigmaU: 0.5792503356933594
# K-JIc: 0.5786953568458557
# AlMgMnSi7: 0.5779633522033691
# Cu-104Cr-016Zr: 0.5755805373191833
# W-W_contiguity: 0.5742433071136475
# Ni-19Si-3Nb-015B-01C: 0.5735499262809753
# Al-45Mg: 0.5727598071098328
# IN718-2: 0.5721640586853027
# yield_stress: 0.7365094423294067
# tensile_tests_at_room_temperature: 0.6563725471496582
# compressive_yield_stress: 0.6453455686569214
# T6_heat_treated: 0.6210197806358337
# yield_stress_sigmay: 0.5927727818489075
# after_T6_heat_treatment: 0.5874244570732117
# stress_rupture_life: 0.5857886075973511
# room_temperature_tensile_test: 0.5843980312347412
# stress_rupture_lives: 0.5755188465118408
# ductile_brittle_transition_temperature_DBTT: 0.5724394917488098
# ductile_brittle_transition_temperature: 0.5702613592147827
# T6_heat_treatment: 0.5643270015716553
# room_temperature_tensile_ductility: 0.5622469186782837
# room_temperature_ductility: 0.5609715580940247
# compressive_flow_stress: 0.5599098205566406
#
# Mechanical Properties:
# tensile_strength: 0.8818727731704712
# yield_strength: 0.8642846941947937
# ultimate_strength: 0.8492770195007324
# ductility: 0.793877899646759
# strength: 0.7077591419219971
# toughness: 0.6559909582138062
# hardness: 0.6520184874534607
# compressive_strength: 0.6445521712303162
# vickers_hardness: 0.6440364122390747
# fracture_toughness: 0.636283278465271
# work_hardening_rate: 0.6333873867988586
# creep_resistance: 0.6130632162094116
# flexural_strength: 0.5927595496177673
# rockwell_hardness: 0.5899063944816589
# flexural_modulus: 0.588609516620636
# fatigue_limit: 0.571357250213623
# shear_strength: 0.5634326934814453
# modulus: 0.5611892938613892
# strain_hardening: 0.555856466293335
# fatigue_strength: 0.5481895208358765
# work_hardening: 0.5459908843040466
# brittleness: 0.5422199368476868
#
# Non-Filtered Items:
# ultimate_tensile_strength: 0.9212783575057983
# total_elongation: 0.8612945079803467
# fracture_elongation: 0.8571982979774475
# yield_strength_ultimate_tensile_strength: 0.8456565737724304
# tensile_yield_strength: 0.8399883508682251
# tensile_elongation: 0.8386691808700562
# elongations: 0.8205201625823975
# tensile_strengths: 0.8183069825172424
# yield_strength_tensile_strength: 0.8131723403930664
# uniform_elongation: 0.8076772093772888
# tensile_strength_yield_strength: 0.8065066337585449
# elongation_EL: 0.803918182849884
# ultimate_tensile_strength_yield_strength: 0.7960840463638306
# yield_strengths: 0.7912271022796631
# elongation_el: 0.7890525460243225
# percentage_elongation: 0.7753528952598572
# ultimate_tensile_strengths: 0.772297739982605
# percent_elongation: 0.7714909911155701
# tensile_ductility: 0.7581547498703003
# compressive_yield_strength: 0.7452980279922485
# offset_yield_strength: 0.7439374327659607
# sigmauts: 0.7436497211456299
# tensile_strength_elongation: 0.7422547936439514
# ultimate_tensile: 0.7400199770927429
# ultimate_compressive_strength: 0.7398519515991211
# tensile_properties: 0.7285298109054565
# elongation_to_failure: 0.7238200902938843
# tensile: 0.70914626121521
# tensile_test: 0.7036496996879578
# tensile_fracture: 0.7031372785568237
# impact_toughness: 0.702775776386261
# tensile_strength_sigmab: 0.7026747465133667
# compressive_yield_strengths: 0.7009093165397644
# elongation_to_fracture: 0.7006783485412598
# breaking_elongation: 0.695086658000946
# sigmab: 0.6938022971153259
# compressive_ductility: 0.6896582245826721
# strength_ductility_balance: 0.6874191761016846
# compressive_fracture: 0.6845546960830688
# mpa: 0.6776517033576965
# yield_strength_tensile_strength_elongation: 0.6772013306617737
# tensile_strength_r-m: 0.673637866973877
# yield_strength_ultimate_strength: 0.6735906004905701
# sigmay: 0.6731727719306946
# total_elongation_TE: 0.6701605319976807
# r-p02: 0.6677582263946533
# maximum_elongation: 0.667101263999939
# epsilonf: 0.6651450395584106
# yield_strength_sigmay: 0.6641400456428528
# tensile_property: 0.6639565825462341
# ultimate_elongation: 0.6605445146560669
# strain_hardening_exponent: 0.659540057182312
# ultimate_compression_strength: 0.6590085029602051
# bending_strength: 0.658302903175354
# charpy_v-notch_impact_energy: 0.6581001877784729
# AT42: 0.6558584570884705
# fracture_epsilonf: 0.6515567302703857
# elon_gation: 0.6515538692474365
# tensile_yield_strengths: 0.6501225233078003
# sigmaf: 0.6486597061157227
# tensile_tests: 0.6469298005104065
# peak_aged_condition: 0.6444904804229736
# sigmau: 0.6443319916725159
# ultimate_strengths: 0.6441383361816406
# R-02: 0.642959713935852
# total_elongations: 0.6427302360534668
# T6_treated: 0.6421695351600647
# ultimate_tensile_strength_elongation: 0.6398409008979797
# strain_hardening_capacity: 0.6389163136482239
# brinell_hardness: 0.6386456489562988
# compressive_yield: 0.6365258693695068
# as-rolled: 0.6349184513092041
# ductile_fracture_mode: 0.634522020816803
# charpy_impact_energy: 0.6298771500587463
# as-aged: 0.6293731331825256
# T6_condition: 0.6292346715927124
# strain_hardening_rate: 0.6291528344154358
# young_'s_modulus: 0.6291366219520569
# ksi: 0.6278221607208252
# center_dot_m1: 0.6250497102737427
# charpy_impact_value: 0.623826265335083
# extruded-T6: 0.6228975057601929
# fracture: 0.6219758987426758
# mechanical_properties: 0.6219524145126343
# work_hardening_capacity: 0.6219215393066406
# charpy_v-notch_impact_toughness: 0.6215695738792419
# tensile_modulus: 0.6207791566848755
# deformability: 0.6206343173980713
# extruded: 0.6203812956809998
# plasticity: 0.6174373626708984
# TAZ711: 0.6145983338356018
# elastic_modulus: 0.6142004728317261
# grain_boundary_strengthening: 0.6128541231155396
# strengthening_dislocation_strengthening: 0.6112682223320007
# uniform_elongations: 0.6096633672714233
# 8-passes: 0.6092531681060791
# compressive_strengths: 0.608719527721405
# as-extruded: 0.6085131168365479
# precipitation_strengthening: 0.6079626679420471
# ultimate_tensile_strength_sigmab: 0.6078855395317078
# ultimate_shear_strength: 0.6077346801757812
# strain_hardening_ability: 0.607420027256012
# work_hardening_exponent: 0.6069433689117432
# charpy_impact_toughness: 0.6064140200614929
# as-cast_condition: 0.6063894629478455
# ultimate_shear: 0.6063525080680847
# fracture_mode: 0.6049039363861084
# tofailure: 0.6027946472167969
# brittle_fracture_mode: 0.6026992797851562
# sigmays: 0.602174699306488
# work_hardening_exponent_n: 0.6020244359970093
# pre-strain: 0.6017704606056213
# strength_ductility: 0.6004427075386047
# ductilities: 0.6002005338668823
# 4-pass: 0.5970932841300964
# compressive_plastic_strain: 0.5970053672790527
# upper_shelf_energy: 0.5968927145004272
# stength: 0.5966626405715942
# tensile_elongations: 0.5959388613700867
# sigma_delta_epsilon: 0.5620136857032776
# after_T6_treatment: 0.5616746544837952
# micro-hardness: 0.5615708231925964
# grain_refinement: 0.5615522265434265
# strengths: 0.5613588094711304
# elongation_at_break: 0.5613003969192505
# T6: 0.5612605810165405
# as-welded_joint: 0.5605260133743286
# pct: 0.5602686405181885
# pre-tensile_deformation: 0.5599531531333923
# multi-passed: 0.5598621368408203
# bend_strength: 0.559357762336731
# strengthening_mechanism: 0.5592304468154907
# quasi-superplasticity: 0.5587392449378967
# rolled: 0.5582634210586548
# strengthening: 0.558260440826416
# ti60_composites: 0.5582406520843506
# longitudinal_direction: 0.5581889748573303
# w-state: 0.5576947331428528
# erichsen_value: 0.5575501322746277
# work_hardening_capability: 0.557303249835968
# strain_hardening_exponent_n: 0.5569533109664917
# ductile_dimple_fracture: 0.5568193197250366
# notch_toughness: 0.5565125346183777
# asextruded: 0.5562145709991455
# static_tensile_tests: 0.5559055805206299
# forged: 0.55589759349823
# hot_rolled: 0.5552456378936768
# as-hot-rolled: 0.5551251173019409
# tensile_test_specimens: 0.5551238656044006
# R1063: 0.5550870299339294
# notch_impact_toughness: 0.55503249168396
# impact_toughnesses: 0.5549536943435669
# incline_angle: 0.5546638369560242
# increment: 0.5543590784072876
# elongation_to_failure_ef: 0.5538058280944824
# thixoformed-T6: 0.5536848306655884
# longer_creep_life: 0.5533696413040161
# ductility_synergy: 0.5529440641403198
# rupture: 0.5528545379638672
# 8-pass: 0.5523985028266907
# rupture_strength: 0.5515977740287781
# TAZ1031: 0.5513476133346558
# bend_strengths: 0.5506550073623657
# solution_strengthening: 0.5504153966903687
# charpy_v-notch_impact: 0.5500975251197815
# t-temp: 0.5500973463058472
# after_eight_passes: 0.5497162938117981
# ultrahigh_yield_strength: 0.5490587949752808
# mo-14: 0.5490499138832092
# x_10-1_s-1: 0.5489495396614075
# compression_test: 0.5485923290252686
# vickers_'s_hardness: 0.5484199523925781
# charpy_absorbed_energy: 0.5483542680740356
# elongations_to_failure: 0.5481972694396973
# total_elongation_TEL: 0.5476133823394775
# fractograph: 0.547491192817688
# transverse_direction: 0.5473283529281616
# as-swaged: 0.5470985174179077
# v-notch: 0.546879768371582
# -extruded: 0.5468125343322754
# direction_ED: 0.5467569828033447
# AX73: 0.5466499328613281
# indentation_hardness: 0.5463086366653442
# strain_rate: 0.5461792349815369
# quasi-cleavage_fracture: 0.5461757183074951
# tensile_strenght: 0.5461472272872925
# transverse_rupture: 0.5455341935157776
# bend_ductility: 0.5454672574996948
# extrusion_direction: 0.5454429388046265
# as-built_specimen: 0.5454033017158508
# AMJ300: 0.5451610684394836
# DQT600: 0.5448931455612183
# charpy_impact_strength: 0.5447760224342346
# erichsen: 0.5446960926055908
# necking: 0.5444357395172119
# precipitation_hardening: 0.5444107055664062
# uniaxial_tensile_tests: 0.5442876815795898
# strength_ductility_synergy: 0.5439174175262451
# izod_impact_strength: 0.5438868999481201
# fractured: 0.5438374876976013
# plastic_deformability: 0.5436435341835022
# cryorolled: 0.5434376001358032
# 10-4_s-1: 0.5430275201797485
# charpy_impact_test: 0.5429115891456604
# area_fraction: 0.5422168374061584
# plastic_strain: 0.5418804883956909
# TZX621: 0.541786789894104
# mechanical_proper_ties: 0.5416367650032043
# tensile_ductilities: 0.5409435629844666
# strain_hardening_capability: 0.5408867597579956
# 10-1_s-1: 0.5408042073249817
# grain_size_refinement: 0.5401931405067444
# along_the_extrusion_direction: 0.5400572419166565
# unnotched_charpy_impact: 0.5398459434509277
# as-extruded_condition: 0.5396605134010315
# weibull_modulus: 0.5389319062232971
# pre-torsional: 0.5386824607849121

# %% [markdown]
# **Input: PROCESS+METALS**
# **Output: PROPERTIES included in thermal_properties_words_set and mechanical_properties_words_set**

# %%
use_full_file_alloy = True
use_full_file_thermal_properties = True
use_full_file_mechanical_properties = True
use_full_file_process_general = True
use_full_file_process_melt_ded = True
use_full_process_melt_general= True
use_full_process_melt_pbf = True
use_full_process_solid_binder = True
use_full_process_solid_cold_spray = True
use_full_process_solid_extrusion = True
use_full_process_solid_field_assisted = True
use_full_process_solid_friction_based = True
use_full_process_solid_general = True

process_item_example = "annealing"
metal_item_example = "steel"

examples = [process_item_example, metal_item_example]

similar_words = w2v_model.wv.most_similar(positive=examples, topn=90000)

thermal_properties = [(word, similarity) for word, similarity in similar_words if word in thermal_properties_words]
mechanical_properties = [(word, similarity) for word, similarity in similar_words if word in mechanical_properties_words]

print("Thermal Properties:")
for item, sim in thermal_properties:
    print(f"{item}: {sim}")

print("\nMechanical Properties:")
for item, sim in mechanical_properties:
    print(f"{item}: {sim}")
# Out:
# Thermal Properties:
# temperature: 0.6296228170394897
# thermal: 0.5075404644012451
# characteristics: 0.4613122045993805
# thermal_shock_resistance: 0.44183188676834106
# thermal_shock: 0.43511268496513367
# kirkendall_voids: 0.4337150752544403
# electrical: 0.43168962001800537
# melting_point: 0.426423579454422
# thermal_stresses: 0.4148986339569092
# insulation: 0.4143483638763428
# solidus_temperature: 0.40726134181022644
# WC-10Ni-5Cr: 0.40583154559135437
# thermal_shocks: 0.4043861925601959
# electrical_insulation: 0.39722558856010437
# glass_transition_temperature: 0.38542667031288147
# thermal_expansion_coefficient: 0.37842056155204773
# penetration_depth: 0.3727165758609772
# glass_transition_temperature_t-g: 0.3689453899860382
# thermal_expansion: 0.3666866421699524
# liquidus_temperature: 0.36570337414741516
# spectral_emissivity: 0.3615858554840088
# t-g: 0.36127784848213196
# heat: 0.3578697741031647
# heat_insulation: 0.3541552722454071
# thermal_expansion_CTE: 0.35054031014442444
# hollow: 0.3480508625507355
# thermal_decomposition: 0.3465156853199005
# thermal_diffusivity: 0.34581100940704346
# glass_transition_temperature_tg: 0.34407031536102295
# heat_transfer_coefficient: 0.3437071442604065
# kirkendall: 0.340643972158432
# thermal_conductivity: 0.33726367354393005
# absorptivity: 0.3352527320384979
# heat_dissipation: 0.33443278074264526
# emittance: 0.3334909677505493
# kirkendall_effect: 0.3311831057071686
# thermal_insulation: 0.32700151205062866
# heat_transfer_coefficients: 0.3245142698287964
# emissivity: 0.320567786693573
# heat_transfer: 0.31974339485168457
# expansion_coefficient: 0.31943124532699585
# glass_transition: 0.3179456889629364
# stress: 0.317505419254303
# melting_points: 0.316739022731781
# thermal_expansion_coefficients: 0.31663259863853455
# CTE: 0.31595712900161743
# vaporization: 0.3144959509372711
# thermodynamic_stability: 0.3125293552875519
# stresses: 0.31147024035453796
# boiling_point: 0.31057095527648926
# thermophysical_properties: 0.30955690145492554
# specific_heat_capacity: 0.3092160224914551
# ferroelectric: 0.3091042935848236
# heat_flux: 0.306991308927536
# heat_losses: 0.30679333209991455
# waste_heat: 0.303698867559433
# normal_spectral_emissivity: 0.2990713119506836
# nanoscale_kirkendall_effect: 0.29809141159057617
# heat_sink: 0.2978433668613434
# kinematic_viscosity: 0.29581165313720703
#
# Mechanical Properties:
# corrosion_resistance: 0.6177290081977844
# hardness: 0.5931764245033264
# strength: 0.5928292870521545
# toughness: 0.589465856552124
# ductility: 0.5865709185600281
# wear_resistance: 0.5427303314208984
# yield_strength: 0.5384938716888428
# tensile_strength: 0.537013828754425
# fatigue_resistance: 0.5318567156791687
# fatigue_strength: 0.5154522657394409
# work_hardening: 0.5136703848838806
# fracture_toughness: 0.5099959373474121
# brittleness: 0.4962531626224518
# rockwell_hardness: 0.48687663674354553
# vickers_hardness: 0.48647192120552063
# ultimate_strength: 0.4821110665798187
# endurance_limit: 0.4776504635810852
# fatigue_limit: 0.4730188250541687
# strain_hardening: 0.47113290429115295
# work_hardening_rate: 0.4605816602706909
# damping_capacity: 0.45962297916412354
# elongation: 0.45088934898376465
# creep_resistance: 0.4465697109699249
# fatigue_life: 0.44642698764801025
# true_strain: 0.438926100730896
# shear_strength: 0.4329906105995178
# pressure: 0.4086982309818268
# creep_rupture_life: 0.40127700567245483
# compressive_strength: 0.39411982893943787
# flexural_strength: 0.39250653982162476
# elastic_recovery: 0.3885429799556732
# crack_growth_rate: 0.38294267654418945
# thermal_expansion_coefficient: 0.37842056155204773
# modulus: 0.37778323888778687
# strain: 0.3654910624027252
# elastic_limit: 0.36492061614990234
# strain_rate_sensitivity: 0.363913893699646
# recoverable_strain: 0.3505857586860657
# true_stress: 0.3482235372066498
# malleability: 0.34680691361427307
# thermal_conductivity: 0.33726367354393005
# knoop_hardness: 0.3190474510192871
# stress: 0.317505419254303
# specific_heat_capacity: 0.3092160224914551
# flexural_modulus: 0.30903977155685425
# elasticity: 0.297038197517395

# %% [markdown]
# **predict the context words of a list of words**

# %%
use_full_file_alloy = True
use_full_file_thermal_properties = True
use_full_file_mechanical_properties = True
use_full_file_process_general = True
use_full_file_process_melt_ded = True
use_full_process_melt_general= True
use_full_process_melt_pbf = True
use_full_process_solid_binder = True
use_full_process_solid_cold_spray = True
use_full_process_solid_extrusion = True
use_full_process_solid_field_assisted = True
use_full_process_solid_friction_based = True
use_full_process_solid_general = True

import numpy as np
from gensim import matutils

def predict_combined_context(w2v_model, words, topn=5000):
    vecs = [w2v_model.wv[word] for word in words if word in w2v_model.wv]
    if len(vecs) == 0:
        return []

    combined_vec = np.mean(vecs, axis=0)
    prob_values = np.exp(np.dot(combined_vec, w2v_model.trainables.syn1neg.T))
    prob_values /= np.sum(prob_values)
    top_indices = matutils.argsort(prob_values, topn=topn, reverse=True)
    return [(w2v_model.wv.index2word[index], prob_values[index]) for index in top_indices]

words_to_predict = ["steel", "annealing"]
top_context_words = predict_combined_context(w2v_model, words_to_predict, topn=500)
#top_context_words_string = '\n'.join(f"{word}: {similarity}" for word, similarity in top_context_words)

def read_keywords(file_paths, use_full):
    words_set = set()
    for file_path in file_paths:
        with open(file_path, 'r') as file:
            for line in file:
                # 处理整行数据，而不是仅仅处理前两列
                words = line.strip().replace('$@$@$', '_').split()  # 替换特殊字符并分割整行
                # 将处理后的词加入集合
                words_set.update(words)
    return list(words_set)


# 使用新函数和独立的开关读取关键词列表
#processed_alloy_words = read_keywords('/home/etica/Project/alloy2vec/keywords/similar_alloy.txt', use_full_file_alloy)
#thermal_properties_words = read_keywords('/home/etica/Project/alloy2vec/keywords/similar_thermal_properties.txt', use_full_file_thermal_properties)
#mechanical_properties_words = read_keywords('/home/etica/Project/alloy2vec/keywords/similar_mechanical_properties.txt', use_full_file_mechanical_properties)

alloy_files = [
    '/home/etica/Project/alloy2vec/new_keyword/similar_AA_family_all.txt',
    '/home/etica/Project/alloy2vec/new_keyword/similar_alloy.txt'
]
alloy_words = read_keywords(alloy_files, use_full_file_alloy)

thermal_properties_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_thermal_properties.txt']
thermal_properties_words = read_keywords(thermal_properties_file, use_full_file_thermal_properties)

mechanical_properties_file = ['/home/etica/Project/alloy2vec/new_keyword/mechanical_properties.txt']
mechanical_properties_words = read_keywords(mechanical_properties_file, use_full_file_mechanical_properties)

#process words
process_general_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_general.txt']
process_general_words = read_keywords(process_general_file, use_full_file_process_general)

process_melt_ded_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_melt_ded.txt']
process_melt_ded_words = read_keywords(process_melt_ded_file, use_full_file_process_melt_ded)

process_melt_general_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_melt_general.txt']
process_melt_pbf_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_melt_pbf.txt']
process_solid_binder_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_solid_binder.txt']
process_solid_cold_spray_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_solid_cold_spray.txt']
process_solid_extrusion_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_solid_extrusion.txt']
process_solid_field_assisted_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_solid_field_assisted.txt']
process_solid_friction_based_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_solid_friction_based.txt']
process_solid_general_file = ['/home/etica/Project/alloy2vec/new_keyword/similar_process_solid_general.txt']

process_melt_general_words = read_keywords(process_melt_general_file, use_full_process_melt_general)
process_melt_pbf_words = read_keywords(process_melt_pbf_file, use_full_process_melt_pbf)
process_solid_binder_words = read_keywords(process_solid_binder_file, use_full_process_solid_binder)
process_solid_cold_spray_words = read_keywords(process_solid_cold_spray_file, use_full_process_solid_cold_spray)
process_solid_extrusion_words = read_keywords(process_solid_extrusion_file, use_full_process_solid_extrusion)
process_solid_field_assisted_words = read_keywords(process_solid_field_assisted_file, use_full_process_solid_field_assisted)
process_solid_friction_based_words = read_keywords(process_solid_friction_based_file, use_full_process_solid_friction_based)
process_solid_general_words = read_keywords(process_solid_general_file, use_full_process_solid_general)

ELEMENTS = ["H", "He", "Li", "Be", "B", "C", "N", "O", "F", "Ne", "Na", "Mg", "Al", "Si", "P", "S", "Cl", "Ar", "K",
            "Ca", "Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga", "Ge", "As", "Se", "Br", "Kr",
            "Rb", "Sr", "Y", "Zr", "Nb", "Mo", "Tc", "Ru", "Rh", "Pd", "Ag", "Cd", "In", "Sn", "Sb", "Te", "I",
            "Xe", "Cs", "Ba", "La", "Ce", "Pr", "Nd", "Pm", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb",
            "Lu", "Hf", "Ta", "W", "Re", "Os", "Ir", "Pt", "Au", "Hg", "Tl", "Pb", "Bi", "Po", "At", "Rn", "Fr",
            "Ra", "Ac", "Th", "Pa", "U", "Np", "Pu", "Am", "Cm", "Bk", "Cf", "Es", "Fm", "Md", "No", "Lr", "Rf",
            "Db", "Sg", "Bh", "Hs", "Mt", "Ds", "Rg", "Cn", "Nh", "Fl", "Mc", "Lv", "Ts", "Og", "Uue"]

ELEMENT_NAMES = ["hydrogen", "helium", "lithium", "beryllium", "boron", "carbon", "nitrogen", "oxygen", "fluorine",
                 "neon", "sodium", "magnesium", "aluminum", "silicon", "phosphorus", "sulfur", "chlorine", "argon",
                 "potassium", "calcium", "scandium", "titanium", "vanadium", "chromium", "manganese", "iron",
                 "cobalt", "nickel", "copper", "zinc", "gallium", "germanium", "arsenic", "selenium", "bromine",
                 "krypton", "rubidium", "strontium", "yttrium", "zirconium", "niobium", "molybdenum", "technetium",
                 "ruthenium", "rhodium", "palladium", "silver", "cadmium", "indium", "tin", "antimony", "tellurium",
                 "iodine", "xenon", "cesium", "barium", "lanthanum", "cerium", "praseodymium", "neodymium",
                 "promethium", "samarium", "europium", "gadolinium", "terbium", "dysprosium", "holmium", "erbium",
                 "thulium", "ytterbium", "lutetium", "hafnium", "tantalum", "tungsten", "rhenium", "osmium",
                 "iridium", "platinum", "gold", "mercury", "thallium", "lead", "bismuth", "polonium", "astatine",
                 "radon", "francium", "radium", "actinium", "thorium", "protactinium", "uranium", "neptunium",
                 "plutonium", "americium", "curium", "berkelium", "californium", "einsteinium", "fermium",
                 "mendelevium", "nobelium", "lawrencium", "rutherfordium", "dubnium", "seaborgium", "bohrium",
                 "hassium", "meitnerium", "darmstadtium", "roentgenium", "copernicium", "nihonium", "flerovium",
                 "moscovium", "livermorium", "tennessine", "oganesson", "ununennium"]


metal = []
thermal_property = []
mechanical_property = []
process_general = []
process_melt_ded = []
process_melt_general= []
process_melt_pbf = []
process_solid_binder = []
process_solid_cold_spray = []
process_solid_extrusion = []
process_solid_field_assisted = []
process_solid_friction_based = []
process_solid_general = []

unfiltered_item = []


for item, similarity in top_context_words:
    # Find the item and its similarity in model_results
    similarity = next((sim for word, sim in top_context_words if word == item), None)
    # Step 1: Keep items that contain process keywords
        # Step 2: Keep items which contain elements (partial match)
    if any(element in item for element in ELEMENTS):
        metal.append((item, similarity))
    elif any(element in item for element in ELEMENT_NAMES):
        metal.append((item, similarity))
    # Step 3: Keep metal items that contain any word from alloy words (full match)
    elif item in alloy_words:
        metal.append((item, similarity))
    # Step 3: Keep metal items that contain both letters and digits （是否需要？）
    #elif any(char.isalpha() for char in item) and any(char.isdigit() for char in item):
        #metal.append((item, similarity))
    # Step 4: Keep metal items that contain "alloy"
    elif "alloy" in item:
        metal.append((item, similarity))
    elif "steel" in item:
        metal.append((item, similarity))
    elif any(word in item for word in process_general_words):
        process_general.append((item, similarity))
    elif any(word in item for word in process_melt_ded_words):
        process_melt_ded.append((item, similarity))
    elif any(word in item for word in process_melt_general_words):
        process_melt_general.append((item, similarity))
    elif any(word in item for word in process_melt_pbf_words):
        process_melt_pbf.append((item, similarity))
    # elif any(word in item for word in process_solid_binder_words):
    #     process_solid_binder.append((item, similarity))
    elif item in process_solid_binder_words:
        process_solid_binder.append((item, similarity))
    elif any(word in item for word in process_solid_cold_spray_words):
        process_solid_cold_spray.append((item, similarity))
    elif any(word in item for word in process_solid_extrusion_words):
        process_solid_extrusion.append((item, similarity))
    elif any(word in item for word in process_solid_field_assisted_words):
        process_solid_field_assisted.append((item, similarity))
    elif any(word in item for word in process_solid_friction_based_words):
        process_solid_friction_based.append((item, similarity))
    elif any(word in item for word in process_solid_general_words):
        process_solid_general.append((item, similarity))
  
    # Step 5: Keep property items that contain properties keywords    
    elif item in thermal_properties_words:
        thermal_property.append((item, similarity))
    elif item in mechanical_properties_words:
        mechanical_property.append((item, similarity))
    # Step 7: unfiltered items
    else:
        unfiltered_item.append((item, similarity))
    

print("\nThermal Properties:")
for item, sim in thermal_property:
    print(f"{item}: {sim}")

print("\nMechanical Properties:")
for item, sim in mechanical_property:
    print(f"{item}: {sim}")

print("\nProcess General:")
for item, sim in process_general:
    print(f"{item}: {sim}")

print("\nProcess Melt General:")
for item, sim in process_melt_general:
    print(f"{item}: {sim}")

print("\nProcess Melt Ded:")
for item, sim in process_melt_ded:
    print(f"{item}: {sim}")

print("\nProcess Melt PBF:")
for item, sim in process_melt_pbf:
    print(f"{item}: {sim}")

print("\nProcess Solid General:")
for item, sim in process_solid_general:
    print(f"{item}: {sim}")

print("\nProcess Solid Binder:")
for item, sim in process_solid_binder:
    print(f"{item}: {sim}")

print("\nProcess Solid Cold Spray:")
for item, sim in process_solid_cold_spray:
    print(f"{item}: {sim}")

print("\nProcess Solid Extrusion:")
for item, sim in process_solid_extrusion:
    print(f"{item}: {sim}")

print("\nProcess Solid Field Assisted:")
for item, sim in process_solid_field_assisted:
    print(f"{item}: {sim}")

print("\nProcess Solid Friction Based:")
for item, sim in process_solid_friction_based:
    print(f"{item}: {sim}")

print("\nMetal:")
for item, sim in metal:
    print(f"{item}: {sim}")

print("\nNon-Filtered Items:")
for item, sim in unfiltered_item:
    print(f"{item}: {sim}")
# Out:
# Thermal Properties:
#
# Mechanical Properties:
# corrosion_resistance: 0.00011806658585555851
# hardness: 6.573656719410792e-05
# wear_resistance: 6.24364911345765e-05
# toughness: 5.257755401544273e-05
#
# Process General:
#
# Process Melt General:
#
# Process Melt Ded:
#
# Process Melt PBF:
#
# Process Solid General:
#
# Process Solid Binder:
#
# Process Solid Cold Spray:
#
# Process Solid Extrusion:
#
# Process Solid Field Assisted:
# furnace_atmosphere: 6.724147533532232e-05
# shot_peening: 5.234298805589788e-05
# laser_shock_peening: 5.198050712351687e-05
#
# Process Solid Friction Based:
# multi-pass_cold_rolling: 5.479773608385585e-05
#
# Metal:
# grain_oriented_silicon: 0.0003431497607380152
# steel: 0.00024219440820161253
# interstitial_free_IF: 0.0002358048368478194
# steels: 0.00020392675651237369
# carbon_steel: 0.00020285388745833188
# cold_rolling: 0.0001648973993724212
# spring_steel: 0.0001611492334632203
# degreesC: 0.00016096299805212766
# continuous_galvanizing: 0.0001598287490196526
# Low-Carbon: 0.00015365707804448903
# hot_rolled_steel: 0.00014646965428255498
# alloyed_steel: 0.00014093492063693702
# AISI: 0.0001368181110592559
# medium_carbon_steel: 0.00013417763693723828
# austempering: 0.00012662194785661995
# galvanizing: 0.0001255777751794085
# low_alloyed_steels: 0.00012084807531209663
# medium-carbon: 0.00011708094098139554
# high-Mn_steel: 0.00011139728303533047
# low-carbon_steel: 0.0001095869520213455
# continuous_cooling: 0.00010343585017835721
# ferritic_stainless_steel: 0.00010084448149427772
# stainless_steel: 9.80774566414766e-05
# weathering_steel: 9.802552813198417e-05
# ULCB: 9.741551912156865e-05
# alloyed: 9.710156882647425e-05
# DEGC: 9.638600022299215e-05
# 450-600_degrees_C: 9.622430661693215e-05
# die_steel: 9.5095754659269e-05
# degrees_C: 9.399709961144254e-05
# strength_low_alloy_HSLA_steel: 9.378744289278984e-05
# 42CrMo: 9.355119982501492e-05
# phase_DP_steel: 9.228274575434625e-05
# cold_drawn_pearlitic_steel_wires: 9.124438656726852e-05
# 08Kh17T: 9.115823922911659e-05
# hot_forming: 9.070141095435247e-05
# dual_phase_DP_steels: 8.8256667368114e-05
# corrosion_behaviour: 8.773631270742044e-05
# alpha-Fe: 8.646786591270939e-05
# intercritical_annealing_IA: 8.637515566078946e-05
# 30CrMnSiA: 8.572861406719312e-05
# Low-Carbon_steel: 8.360442006960511e-05
# 600-degrees-C: 8.269968384411186e-05
# 500degreesC: 8.25578608782962e-05
# plain_carbon_steel: 8.235014684032649e-05
# treatment_SMAT: 8.223640907090157e-05
# super_duplex_stainless_steel: 8.146089385263622e-05
# heat_resistant_steel: 8.13829610706307e-05
# medium-Mn_steel: 8.116381650324911e-05
# cr-05_Mo: 8.054409408941865e-05
# 550-degrees-C: 8.02075446699746e-05
# steel_HSS: 8.002083632163703e-05
# 42CrMo4: 7.945342076709494e-05
# surface_nanocrystallization: 7.856584852561355e-05
# V-N: 7.785336492815986e-05
# austenitic_stainless_steel: 7.728616037638858e-05
# yttrium_implantation: 7.614341302542016e-05
# 500-degrees-C: 7.61337869334966e-05
# strength_low_alloy_HSLA_steels: 7.602609548484907e-05
# 42CrMo_steel: 7.589079905301332e-05
# austenitic_stainless_steel_ASS: 6.187758117448539e-05
# Al-Si_coating: 6.17938203504309e-05
# 1150-degrees-C: 6.179241609061137e-05
# T91_steel: 6.1779712268617e-05
# CMnSi: 6.176120223244652e-05
# In_this_work: 6.170666893012822e-05
# aluminum_alloys: 6.167830724734813e-05
# an_argon_atmosphere: 6.0945134464418516e-05
# medium-carbon_steel: 6.089725502533838e-05
# high_strength_steel_AHSS: 6.0640853916993365e-05
# In_this_paper: 6.0280068282736465e-05
# armco_iron: 6.022540765115991e-05
# 900-degrees-C: 6.018310159561224e-05
# hydrogen_charging: 6.015668623149395e-05
# pre-alloying: 6.00183084316086e-05
# ductile_brittle_transition_temperature_DBTT: 5.977850378258154e-05
# HTGN: 5.9562888054642826e-05
# alloying_elements: 5.926032463321462e-05
# 450degreesC: 5.9081216022605076e-05
# microalloying: 5.904058343730867e-05
# galvannealed_coating: 5.8945355704054236e-05
# 20CrMo: 5.880710159544833e-05
# 800-degrees-C: 5.840815356350504e-05
# 18Cr2Ni4WA: 5.823867104481906e-05
# steel_st3: 5.807019624626264e-05
# TWIP_steel: 5.8005818573292345e-05
# EUROFER: 5.8003002777695656e-05
# hydrogen_embrittlement: 5.769292693003081e-05
# nitrogen_ion_implantation: 5.765177047578618e-05
# 300-degrees-C: 5.757566759712063e-05
# In_order: 5.750580385210924e-05
# Medium-Carbon: 5.7268487580586225e-05
# static_recrystallization_SRX: 5.7265020586783066e-05
# AlCrFe_alloy: 5.7246972573921084e-05
# Ti-4Al-2V: 5.7119428674923256e-05
# 30CrMnSi: 5.706621959689073e-05
# High-Nitrogen: 5.697170490748249e-05
# CF8: 5.6760622101137415e-05
# Al-Mg-Si-Cu_alloy: 5.6677185057196766e-05
# fire_resistant_steel: 5.643879194394685e-05
# H-2-N-2: 5.6427783420076594e-05
# F55: 5.633467299048789e-05
# sparingly_alloyed: 5.63059002161026e-05
# stainless: 5.623350807582028e-05
# 950-degrees-C: 5.61810375074856e-05
# advanced_high_strength_steels_AHSS: 5.6099157518474385e-05
# cupronickel_alloy: 5.5850814533187076e-05
# strength_low_alloy_HSLA: 5.570469147642143e-05
# UFG: 5.560442150454037e-05
# fretting_wear_behavior: 5.5479296861449257e-05
# ultra-high_strength_steel: 5.547354157897644e-05
# austenitic_ferritic_steel: 5.542573126149364e-05
# 650degreesC: 5.534904630621895e-05
# Fe-C_alloy: 5.510338451131247e-05
# cold_rolling_CR: 5.5097785661928356e-05
# fe-65_wt_Si: 5.494051583809778e-05
# X18H10T: 5.4906522564124316e-05
# chromized_coating: 5.444242924568243e-05
# N-2_atmosphere: 5.443335248855874e-05
# 700-750_degrees_C: 5.434563718154095e-05
# X2CrNiMoN22-5-3: 5.423204493126832e-05
# ultralow-carbon: 5.419060107669793e-05
# martensitic_steels: 5.417652573669329e-05
# ST37: 5.4092324717203155e-05
# martensitic_stainless_steel: 5.408159995567985e-05
# HSLA_steels: 5.406323180068284e-05
# aluminized_steel: 5.3983272664481774e-05
# micro-alloyed: 5.3942967497278005e-05
# B-Mn: 5.390320438891649e-05
# 900-1000_degrees_C: 5.378312926040962e-05
# hydrogen_permeation: 5.373817475629039e-05
# aluminized_coating: 5.3660751291317865e-05
# austempered: 5.3430510888574645e-05
# press_hardened_steel: 5.3402342018671334e-05
# chromium: 5.3304083849070594e-05
# High-Mn: 5.326899190549739e-05
# 450-550_degrees_C: 5.3224674047669396e-05
# 1050-degrees-C: 5.313214205671102e-05
# CGHAZ: 5.289358887239359e-05
# 18Cr: 5.282371785142459e-05
# transformation_CCT: 5.265533400233835e-05
# non-alloyed: 5.257797602098435e-05
# HSLA: 5.247472654446028e-05
# non-oriented_electrical_steel: 5.2461939048953354e-05
# thin_slab_casting: 5.2438870625337586e-05
# ductile_iron: 5.2421746659092605e-05
# 09CuPCrNi: 5.239397432887927e-05
# 500-650_degrees_C: 5.2378953114384785e-05
# 35CrMo_steel: 5.2345978474477306e-05
# high_entropy_alloy: 5.2218449127394706e-05
# 350-degrees-C: 5.19395834999159e-05
# austenitic_AISI: 5.192903336137533e-05
# 800-1000_degrees_C: 5.182179302209988e-05
# ODS_RAF: 5.167533163330518e-05
# titanium_alloy: 5.157408304512501e-05
# 22MnB5: 5.1547791372286156e-05
#
# Non-Filtered Items:
# annealing: 0.0002959824341814965
# tempering: 0.00023137364769354463
# austenitized_at: 0.00022447497758548707
# cold_deformation: 0.00022029387764632702
# grain_oriented_electrical: 0.00018501105660106987
# austenitization: 0.00018471151997800916
# cold_deformed: 0.00018294290930498391
# hot_rolling: 0.00018162404012400657
# heat_treatment: 0.00017235640552826226
# galvannealing: 0.00016536994371563196
# annealed: 0.00016061357746366411
# cold_rolled: 0.00015823003195691854
# hot_dip_galvanizing: 0.00013666454469785094
# warm_rolling: 0.0001355038839392364
# hot_rolled: 0.00013521304936148226
# hot_rolled_plate: 0.00013116543414071202
# tensile_properties: 0.00012674172467086464
# intercritical_heat_treatment: 0.00012569036334753036
# inter-critical_annealing: 0.00012025613978039473
# corrosion_behavior: 0.00011920573888346553
# decarburization: 0.00011821788211818784
# cold_radial_forging: 0.00011792825534939766
# rolled: 0.0001174201097455807
# austenitizing: 0.00011735225416487083
# different_durations: 0.00011448353325249627
# impact_toughness: 0.00011412818275857717
# ar-3: 0.0001138716033892706
# vacuum_annealing: 0.00010953500168398023
# heat_treatments: 0.00010935658792732283
# tempered: 0.00010847670637303963
# hot_deformed: 0.00010763885074993595
# nanobainitic: 0.00010727927292464301
# air_cooling: 0.00010571962775429711
# subsequent_annealing: 0.0001023518925649114
# hot_dipping: 0.00010166037827730179
# nitriding: 0.000100000346719753
# thermomechanical_treatment: 9.866845357464626e-05
# tempforming: 9.828856855165213e-05
# quenching_tempering: 9.806836897041649e-05
# intercritical: 9.7667369118426e-05
# at_temperatures_ranging: 9.734231571201235e-05
# different_austenitizing_temperatures: 9.647299884818494e-05
# pct: 9.427967597730458e-05
# nitrocarburized: 9.339700773125514e-05
# galvanizability: 9.284025145461783e-05
# hot_dip_aluminizing: 9.273735486203805e-05
# hot_rolled_plates: 6.655084871454164e-05
# heat_treated: 6.646851397817954e-05
# severely_cold_rolled: 6.644423410762101e-05
# hot_strip: 6.633077282458544e-05
# wt_pct: 6.631698488490656e-05
# aluminizing: 6.615149322897196e-05
# tempering_QT: 6.591855344595388e-05
# at_room_temperature_RT: 6.582563946722075e-05
# tempering_heat_treatments: 6.570557889062911e-05
# electropulsing: 6.550287798745558e-05
# salt_bath: 6.546296935994178e-05
# cementite_particles: 6.515876884805039e-05
# soft_magnetic_properties: 6.491383101092651e-05
# duplex: 6.4897867559921e-05
# ultrahigh_strength: 6.489753286587074e-05
# bainite: 6.479382864199579e-05
# ferrite_grain_size: 6.471064261859283e-05
# finishing_rolling: 6.459493306465447e-05
# hot_rolling_cold_rolling: 6.458780990215018e-05
# galvanized: 6.457277049776167e-05
# fe-19: 6.446341285482049e-05
# nitrocarburising: 6.430785288102925e-05
# nitrided: 6.430369830923155e-05
# anneal: 6.411254435079172e-05
# pre-oxidation: 6.407196633517742e-05
# deep_cryogenic_treatment: 6.388016481650993e-05
# warm_deformation: 6.385430606314912e-05
# thermo_mechanical_treatments: 6.340767868096009e-05
# subsequent_heat_treatment: 6.326717266347259e-05
# intercritically_annealed: 6.293420301517472e-05
# ductile_brittle_transition_temperature: 6.288631266215816e-05
# results_showed: 6.267229036893696e-05
# pre-annealing: 6.263304385356605e-05
# Q195: 6.258856592467055e-05
# twinning_induced_plasticity: 6.256740016397089e-05
# during_isothermal_annealing: 6.225269316928461e-05
# cryorolling: 6.207924889167771e-05
# pickling: 6.207141996128485e-05
# cementite: 6.181681965244934e-05
# vanadis: 6.176558963488787e-05
# reversed_austenite: 6.134290742920712e-05
# plasma_nitrocarburizing: 6.128688983153552e-05
# long_time: 6.10016577411443e-05
# mechanical_properties: 6.088913869461976e-05
# quenching: 6.0734619182767347e-05
# alpha'-martensite: 6.07319270784501e-05
# precipitates: 6.0612532251980156e-05
# third_generation_advanced: 6.051934906281531e-05
# cold_swaging: 6.0485417634481564e-05
# cold_rolled_sheet: 6.0465616115834564e-05
# cold_forged: 6.039420986780897e-05
# hardening: 6.031960583641194e-05
# diffusion_bonding: 6.023995592840947e-05
# embrittlement: 6.0231959650991485e-05
# pseudo-carburizing: 6.022589877829887e-05
# post-oxidation: 6.0222500906093046e-05
# oxynitriding: 6.021574154146947e-05
# carburization: 5.9975151089020073e-05
# ferritic_heat_resistant: 5.984790186630562e-05
# pack_aluminization: 5.971842983854003e-05
# plasma_nitrided: 5.970311030978337e-05
# as-rolled: 5.9500882343854755e-05
# room_temperature_RT: 5.938952017459087e-05
# as-deposited: 5.932065687375143e-05
# ferritic_pearlitic: 5.931634223088622e-05
# cementite_precipitation: 5.92093747400213e-05
# annealings: 5.901026452193037e-05
# diffuses_into: 5.897676237509586e-05
# cold_drawing: 5.8831163187278435e-05
# coiling: 5.86080968787428e-05
# ferrite_martensite: 5.8497709687799215e-05
# explosion_welded: 5.848893488291651e-05
# rough_rolling: 5.8314391935709864e-05
# finish_rolling_temperature: 5.810340735479258e-05
# microstructures: 5.8010173233924434e-05
# ferrite: 5.798977144877426e-05
# subsequent_warm_rolling: 5.789658462163061e-05
# aging: 5.778136619483121e-05
# hot_forging: 5.7733785070013255e-05
# chromization: 5.7708642998477444e-05
# tempered_bainite: 5.7604906032793224e-05
# quenched: 5.7578887208364904e-05
# lower_than: 5.728940959670581e-05
# thermal_ageing: 5.72158423892688e-05
# ion_irradiation: 5.7056899095186964e-05
# charpy_v-notch_impact_energy: 5.692221020581201e-05
# t-a: 5.679844616679475e-05
# microhardness: 5.6670494814170524e-05
# isothermal_annealing: 5.664987475029193e-05
# isothermal_heat_treatment: 5.662663534167223e-05
# heat_preservation: 5.65975860808976e-05
# dew_point: 5.654124834109098e-05
# tempered_martensite: 5.652984691550955e-05
# ultrafine_grain_structure: 5.652041727444157e-05
# martensitic: 5.651564788422547e-05
# during_isothermal_holding: 5.6268818298121914e-05
# chromized: 5.624021650874056e-05
# cold_stamping: 5.619958756142296e-05
# cold_worked: 5.600912118097767e-05
# grain_oriented: 5.600397344096564e-05
# finish_rolling: 5.550952846533619e-05
# ultra-high_strength: 5.550713467528112e-05
# m-s: 5.548922490561381e-05
# deoxidized: 5.530906128115021e-05
# austenitisation: 5.510475966730155e-05
# as-received: 5.509161201189272e-05
# depending_on: 5.503949796548113e-05
# sigma_phase: 5.487260932568461e-05
# austenitic_heat_resistant: 5.470282485475764e-05
# fresh_martensite: 5.457862789626233e-05
# cross-rolling: 5.4406398703577e-05
# hot_rolled_sheet: 5.435626007965766e-05
# galvanizing_bath: 5.428493386716582e-05
# better_corrosion_resistance: 5.4134456149768084e-05
# line_pipe: 5.4108088079374284e-05
# electrical_resistance: 5.3911182476440445e-05
# yield_strength_tensile_strength: 5.390269143390469e-05
# hot_dip_galvanized: 5.389874058892019e-05
# neutron_irradiation: 5.340622738003731e-05
# isothermal_holding: 5.33951424586121e-05
# retained_austenite_RA: 5.325221718521789e-05
# grain_size: 5.319861156749539e-05
# rolled_sheets: 5.3182218834990636e-05
# pre-oxidized: 5.300520933815278e-05
# warm_caliber_rolling: 5.285677980282344e-05
# A516: 5.282347046886571e-05
# sigma-phase: 5.2779330871999264e-05
# press_hardening: 5.2773175411857665e-05
# ultrafine_grained: 5.252556366031058e-05
# normalizing: 5.251545735518448e-05
# higher_than: 5.250707545201294e-05
# transformation_induced_plasticity: 5.24517527082935e-05
# microstructural_changes: 5.2356426749611273e-05
# severe_plastic_deformation: 5.204688204685226e-05
# thermomechanically_treated: 5.2000406867591664e-05
# warm_rolled: 5.1964128942927346e-05
# hot_dip_galvanised: 5.186507769394666e-05
# nitrocarburizing: 5.1824230467900634e-05
# alpha_-martensite: 5.170521035324782e-05
# intercritical_ferrite: 5.160235377843492e-05
# fe-9: 5.157386476639658e-05
# as-quenched: 5.153212259756401e-05
# transformed_into: 5.148165291757323e-05
# aging_treatments: 5.143164889886975e-05
# M50_bearing: 5.141015935805626e-05
# vacuum_carburizing: 5.138736014487222e-05
